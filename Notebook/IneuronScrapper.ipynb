# %%
#Import packages
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
from fpdf import FPDF

# %%
def run_drive(wd): 
    option = webdriver.ChromeOptions()
    #option.binary_location = os.environ.get("GOOGLE_CHROME_BIN")  # For cloud
    option.add_argument('--headless')
    option.add_argument('-no-sandbox')
    option.add_argument("--mute-audio")
    option.add_argument("--disable-extensions")
    option.add_argument('-disable-dev-shm-usage')
    #driver = webdriver.Chrome(service = Service(executable_path = os.environ.get("CHROMEDRIVER_PATH")), options = option)  # For cloud
    driver = webdriver.Chrome(wd, options=option) # For testing in windows
    return driver

# %%
wd='C:/Users/Srikanta/Desktop/FullStackDataScience/Challenges/IneuronScrapper/chromedriver'
url='https://ineuron.ai/'
def course_name_and_link(url: str,wd):
    #driver = webdriver.Chrome(executable_path=wd)
    driver=run_drive(wd)
    driver.implicitly_wait(0.5)
    url_courses=url+'/courses'
    driver.get(url_courses)
    time.sleep(5)

    ## NOTE Some time infinte scoll stops before completing the scrolling, to avoid this we need give more time or good internet spped
    ## so that it can load. But in for looping the chances of stop before end of page is less.
    #infinity scroll
    current_height=driver.execute_script('return document.body.scrollHeight;')
    while True:
        driver.execute_script('window.scrollTo(0,arguments[0]);',current_height)
        time.sleep(30)
        new_height=driver.execute_script('return document.body.scrollHeight;')
        print(current_height,new_height)
        if new_height == current_height:
            break
        current_height = new_height


#     for i in range(100):
#         driver.execute_script('window.scrollBy(0,3000);')
#         time.sleep(20)
    html_content=driver.page_source
    

    
    #Data extraction using beautifulsoup
    data = BeautifulSoup(html_content, "html.parser")
    all_courses=data.find_all(class_="Course_right-area__JqFFV")
    course_names = []
    course_links = []
    result=[]
    
    for course in all_courses:
        name_link={}
        course_links.append(url + course.find('a')['href'])
        course_names.append(course.find(class_="Course_course-title__219gJ").text)
        name_link['Name'] = course.find(class_="Course_course-title__219gJ").text
        name_link['URL']=url + course.find('a')['href']
        result.append(name_link)
    
    
    
    driver.implicitly_wait(3)
    driver.close
    
    
    return result, course_names,course_links

# %%
result,X,Y=course_name_and_link(url,wd)
# Out:
# C:\Users\Srikanta\AppData\Local\Temp\ipykernel_2964\252071385.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(wd, options=option) # For testing in windows
# 2599 43162
# 43162 75317
# 75317 103914
# 103914 108781
# 108781 108781

# %%
len(X)
# Out:
# 894

# %%
Y
# Out:
# ['https://ineuron.ai//course/Complete-DSA-in-Python',
#  'https://ineuron.ai//course/Tableau-Foundation-Course',
#  'https://ineuron.ai//course/Complete-Excel-Course',
#  'https://ineuron.ai//course/Automatic-Number-Plate-Recognition',
#  'https://ineuron.ai//course/Build-Modern-ETL-Data-Pipeline-using-Informatica-cloud',
#  'https://ineuron.ai//course/Build-ETL-Data-Pipeline-on-AWS-EMR-Cluster',
#  'https://ineuron.ai//course/Create-A-Data-Pipeline-based-on-Messaging-Using-PySpark-and-Airflow',
#  'https://ineuron.ai//course/Hive-Project-to-build-a-data-warehouse-for-e-Commerce',
#  'https://ineuron.ai//course/House-Price-Prediction',
#  'https://ineuron.ai//course/MLFlow-Production-Server-Setup',
#  'https://ineuron.ai//course/Sensor-Fault-Prediction',
#  'https://ineuron.ai//course/Text-Summarization',
#  'https://ineuron.ai//course/The-Ultimate-Guide-To-OpenAI-GPT-3-&-Fine-Tune-with-Custom-Data',
#  'https://ineuron.ai//course/Industry-Safety-Detection-using-YOLO-v7',
#  'https://ineuron.ai//course/Shipment-Price-Prediction',
#  'https://ineuron.ai//course/Finance-Complaint',
#  'https://ineuron.ai//course/Deep-Authenticator',
#  'https://ineuron.ai//course/Language-Identification',
#  'https://ineuron.ai//course/Sign-Language-Detection',
#  'https://ineuron.ai//course/Text-To-Speech',
#  'https://ineuron.ai//course/Face-Swap-Application',
#  "https://ineuron.ai//course/Full-Stack-Data-Science-Nov'21-Tech-Neuron",
#  "https://ineuron.ai//course/Full-Stack-Data-Science-Feb'21-Tech-Neuron",
#  'https://ineuron.ai//course/Machine-Learning-Bootcamp-Tech-Neuron',
#  'https://ineuron.ai//course/Manual-Testing-Kickstart',
#  'https://ineuron.ai//course/Machine-Learning-Bootcamp',
#  'https://ineuron.ai//course/Azure-Machine-Learning-DP-100',
#  'https://ineuron.ai//course/Informatica-Cloud-(IICS)',
#  'https://ineuron.ai//course/DSA-in-C++,-Competitive-Programming-&-IOT-in-Hindi',
#  'https://ineuron.ai//course/Teradata',
#  'https://ineuron.ai//course/Full-Stack-Data-Analytics-2.0',
#  'https://ineuron.ai//course/Job-Guaranteed-BigData-Bootcamp-2.0',
#  'https://ineuron.ai//course/Web-Automation-Using-Selenium-Community-Class',
#  'https://ineuron.ai//course/Pre-Ethical-Hacking-Community-Class',
#  'https://ineuron.ai//course/TypeScript-Crash-Course',
#  'https://ineuron.ai//course/Full-Stack-JavaScript-Bootcamp-2.0',
#  'https://ineuron.ai//course/Java-Community-Class',
#  'https://ineuron.ai//course/C-Sharp-Programming',
#  'https://ineuron.ai//course/Complete-iOS-16-Developer-with-SwiftUI-and-8-Apps',
#  'https://ineuron.ai//course/Complete-iOS-16-Developer-with-Swift-and-8-Apps',
#  'https://ineuron.ai//course/Full-Stack-Java-Developer',
#  'https://ineuron.ai//course/Be-A-DevOps-Pro-Tech-Neuron',
#  'https://ineuron.ai//course/Be-A-DevOps-Pro',
#  'https://ineuron.ai//course/Prisma-Backend-Development',
#  'https://ineuron.ai//course/Data-Science-Interview-Tech-Neuron',
#  'https://ineuron.ai//course/Data-Science-Interview',
#  'https://ineuron.ai//course/Industry-Ready-Data-Science-Projects-Tech-Neuron',
#  'https://ineuron.ai//course/Data-Science-Industry-Ready-Projects',
#  'https://ineuron.ai//course/Web-Automation-Using-Selenium-With-Java-and-Cucumber-BDD-Tech-Neuron',
#  'https://ineuron.ai//course/DSA-for-FAANG-preparation-with-Python-and-JavaScript-Tech-Neuron',
#  'https://ineuron.ai//course/Full-Stack-Web-Development-with-Python-in-Hindi-Tech-Neuron',
#  'https://ineuron.ai//course/Big-Data-Masters-Tech-Neuron',
#  'https://ineuron.ai//course/Full-Stack-Data-Science-BootCamp-2.0',
#  'https://ineuron.ai//course/Reinforcement-Learning',
#  'https://ineuron.ai//course/Android-Technical-Interview-Preparation',
#  'https://ineuron.ai//course/C-Coding-Interview-Preparation',
#  'https://ineuron.ai//course/C++-Coding-Interview-Preparation',
#  'https://ineuron.ai//course/Data-Structure-and-Algorithm-Interview-Preparation',
#  'https://ineuron.ai//course/HTML-CSS-Coding-Interview-Preparation',
#  'https://ineuron.ai//course/Java-Coding-Interview-Preparation',
#  'https://ineuron.ai//course/JavaScript-Coding-Interview-Preparation',
#  'https://ineuron.ai//course/Machine-Learning-Interview-Preparation',
#  'https://ineuron.ai//course/Pro-Aptitude---C-Language',
#  'https://ineuron.ai//course/Pro-Aptitude---C++',
#  'https://ineuron.ai//course/Pro-Aptitude---Data-Structures-and-Algorithms',
#  'https://ineuron.ai//course/Pro-Aptitude---DBMS',
#  'https://ineuron.ai//course/Pro-Aptitude---Java',
#  'https://ineuron.ai//course/Pro-Aptitude---Operating-Systems',
#  'https://ineuron.ai//course/Pro-Aptitude---Python',
#  'https://ineuron.ai//course/Pro-Computer-Networking',
#  'https://ineuron.ai//course/Pro-C-Programming-Language',
#  'https://ineuron.ai//course/Pro-Max-Interview-Preparation-Edition-1',
#  'https://ineuron.ai//course/Pro-Max-Interview-Preparation-Edition-2',
#  'https://ineuron.ai//course/Pro-Max-Interview-Preparation-Edition-3',
#  'https://ineuron.ai//course/Pro-C++-Programming-Language',
#  'https://ineuron.ai//course/Pro-Database-Management-Systems',
#  'https://ineuron.ai//course/Pro-Data-Structure-and-Algorithms',
#  'https://ineuron.ai//course/Pro-Java-Programming-Language',
#  'https://ineuron.ai//course/Pro-JavaScript-Programming-Language',
#  'https://ineuron.ai//course/Pro-Operating-Systems',
#  'https://ineuron.ai//course/Pro-Python-Programming-Language',
#  'https://ineuron.ai//course/Python-Coding-Interview-Preparation',
#  'https://ineuron.ai//course/Aptitude-Test-Series',
#  'https://ineuron.ai//course/Mastering-DSA-with-Python',
#  'https://ineuron.ai//course/Mastering-DSA-with-Java',
#  'https://ineuron.ai//course/Mastering-DSA-with-C++',
#  'https://ineuron.ai//course/Android-P-with-Machine-Learning-Apps',
#  'https://ineuron.ai//course/Full-Stack-Django-and-React',
#  'https://ineuron.ai//course/Full-Stack-Django-with-React',
#  'https://ineuron.ai//course/Complete-Front-End-Web-Developer-Bootcamp',
#  'https://ineuron.ai//course/Complete-Backend-Development-with-Nodejs',
#  'https://ineuron.ai//course/Backend-Development-with-Django-8-Projects',
#  'https://ineuron.ai//course/Complete-Flutter-Course---iOS-Android-Apps',
#  'https://ineuron.ai//course/Dart-Language',
#  'https://ineuron.ai//course/Complete-ReactJs-Developer-Bootcamp',
#  'https://ineuron.ai//course/Complete-Bootstrap4---Build-5-Projects',
#  'https://ineuron.ai//course/Android-Chatapp-with-FireBase',
#  'https://ineuron.ai//course/C++-Bootcamp-for-Beginners',
#  'https://ineuron.ai//course/Complete-Angular-Developer-Bootcamp',
#  'https://ineuron.ai//course/Crack-the-Tech-Interviews',
#  'https://ineuron.ai//course/Complete-React-Native-Mobile-App-Developer',
#  'https://ineuron.ai//course/Complete-VueJS-Development',
#  'https://ineuron.ai//course/The-Pro-Backend-Developer',
#  'https://ineuron.ai//course/AWS-Architect-for-the-Real-World',
#  'https://ineuron.ai//course/HTML-and-CSS-for-Web-Development',
#  'https://ineuron.ai//course/JavaScript-Fundamentals',
#  'https://ineuron.ai//course/HTML-and-CSS',
#  'https://ineuron.ai//course/Ethical-Hacking-&-Penetration-Testing',
#  'https://ineuron.ai//course/Crack-the-Tech-Interview',
#  'https://ineuron.ai//course/Write-quicker-HTML5-and-CSS-3;-productivity-hacks-with-emmet4',
#  'https://ineuron.ai//course/The-Complete-Front-End-Web-Developer-Bootcamp',
#  'https://ineuron.ai//course/Machine-Learning-and-Data-Science-Bootcamp',
#  'https://ineuron.ai//course/Publishing-Custom-Cocoapads',
#  'https://ineuron.ai//course/Build-an-Ecommerce-with-ReactJS',
#  'https://ineuron.ai//course/Python3-Scratch-To-Pro',
#  'https://ineuron.ai//course/ReactJS-Crash-Course',
#  'https://ineuron.ai//course/Angular-Crash-Course',
#  'https://ineuron.ai//course/Python-Crash-Course-by-Hitesh',
#  'https://ineuron.ai//course/Stripe-with-React-and-Node-Crash-Course',
#  'https://ineuron.ai//course/Materialize-CSS-Crash-Course',
#  'https://ineuron.ai//course/VueJS-Crash-Course',
#  'https://ineuron.ai//course/Graph-QL-Crash-Course',
#  'https://ineuron.ai//course/AWS-Serverless',
#  'https://ineuron.ai//course/Fastify-Crash-Course',
#  'https://ineuron.ai//course/Socket-io-Crash-Course',
#  'https://ineuron.ai//course/NextJS-Full-stack-crash-course',
#  'https://ineuron.ai//course/DSA-for-FAANG-preparation-with-Python-and-JavaScript',
#  'https://ineuron.ai//course/DP-900-Microsoft-Azure-Data-Fundamentals',
#  'https://ineuron.ai//course/AWS-Big-Data-Analytics',
#  'https://ineuron.ai//course/Auto-Sklearn-and-Auto-TimeSeries',
#  'https://ineuron.ai//course/Blockchain-Foundations',
#  'https://ineuron.ai//course/Angular-JS-Course',
#  'https://ineuron.ai//course/Snowflake-Advanced',
#  'https://ineuron.ai//course/APIGEE',
#  'https://ineuron.ai//course/Yolo-X-and-Yolo-R',
#  'https://ineuron.ai//course/SAS-Programming',
#  'https://ineuron.ai//course/Job-Guaranteed-Big-Data-Bootcamp',
#  'https://ineuron.ai//course/Mulesoft',
#  'https://ineuron.ai//course/IOT',
#  'https://ineuron.ai//course/Full-Stack-Data-Analytics-Tech-Neuron',
#  'https://ineuron.ai//course/Full-Stack-Blockchain-Development-Tech-Neuron',
#  'https://ineuron.ai//course/Youtube-Mastery-Course-in-Hindi-Tech-Neuron',
#  'https://ineuron.ai//course/Job-Ready-Automation-Tester-with-JavaScript-Tech-Neuron',
#  'https://ineuron.ai//course/System-Design-with-Design-Patterns-Tech-Neuron',
#  'https://ineuron.ai//course/Cyber-Security-Masters-Tech-Neuron',
#  'https://ineuron.ai//course/Digital-Marketing-Bootcamp-in-Hindi-Tech-Neuron',
#  'https://ineuron.ai//course/A-Job-Ready-Bootcamp-in--C++,-DSA-and-IOT-Tech-Neuron',
#  'https://ineuron.ai//course/Enterprise-Java-with-Spring-Boot-Tech-Neuron',
#  'https://ineuron.ai//course/Data-Engineering-with-Google-Cloud',
#  'https://ineuron.ai//course/Explainable-AI',
#  'https://ineuron.ai//course/Full-Stack-Blockchain-Development',
#  'https://ineuron.ai//course/JavaScript-Marathon',
#  'https://ineuron.ai//course/AIOPS-Course',
#  'https://ineuron.ai//course/C-language-for-Absolute-Beginners',
#  'https://ineuron.ai//course/MSBI',
#  'https://ineuron.ai//course/Web-Automation-Foundations',
#  'https://ineuron.ai//course/Digital-Marketing-and-Youtube-Niche-Foundations',
#  'https://ineuron.ai//course/Java-Foundations',
#  'https://ineuron.ai//course/NLP-Foundations',
#  'https://ineuron.ai//course/SQL-Foundations',
#  'https://ineuron.ai//course/ML-and-DL-Foundations',
#  'https://ineuron.ai//course/Scala',
#  'https://ineuron.ai//course/Manual-Testing-Foundations',
#  'https://ineuron.ai//course/Cyber-Security-Foundations',
#  'https://ineuron.ai//course/Salesforce-Developer',
#  'https://ineuron.ai//course/Golang',
#  'https://ineuron.ai//course/Tibco-Business-Works',
#  'https://ineuron.ai//course/GCP-Machine-Learning-Certification',
#  'https://ineuron.ai//course/System-Design-Foundations',
#  'https://ineuron.ai//course/Informatica-Powercenter',
#  'https://ineuron.ai//course/Talend',
#  'https://ineuron.ai//course/Machine-Learning-in-R',
#  'https://ineuron.ai//course/Pro-Live-Classes',
#  'https://ineuron.ai//course/MongoDB-Course',
#  'https://ineuron.ai//course/Spring-Boot',
#  'https://ineuron.ai//course/System-Design-with-Design-Patterns',
#  'https://ineuron.ai//course/Enterprise-Java-with-Spring-Boot',
#  'https://ineuron.ai//course/Apache-Atlas',
#  'https://ineuron.ai//course/Apache-Druid',
#  'https://ineuron.ai//course/Cyber-Security-Masters',
#  'https://ineuron.ai//course/Bash-Scripting',
#  'https://ineuron.ai//course/Deep-Learning-Foundations',
#  'https://ineuron.ai//course/Data-Analytics-Bootcamp',
#  'https://ineuron.ai//course/MERN-Stack-Bootcamp',
#  'https://ineuron.ai//course/Certified-Ethical-Hacker-Bootcamp',
#  'https://ineuron.ai//course/Latex',
#  'https://ineuron.ai//course/Julia-Programming',
#  'https://ineuron.ai//course/Matlab-Basic-to-Advance',
#  'https://ineuron.ai//course/Salesforce-Administrator',
#  'https://ineuron.ai//course/Full-Stack-Data-Science-Bootcamp',
#  'https://ineuron.ai//course/AWS-Data-Engineering',
#  'https://ineuron.ai//course/Big-Data-Foundations',
#  'https://ineuron.ai//course/Reasoning-Live-Class',
#  'https://ineuron.ai//course/Spark-AR-Live-Class',
#  'https://ineuron.ai//course/Power-BI-Foundations',
#  'https://ineuron.ai//course/Foundations-of-English-Language',
#  'https://ineuron.ai//course/Android-Programming-with-Machine-Learning-Apps',
#  'https://ineuron.ai//course/Pro-Backend-Developer',
#  'https://ineuron.ai//course/Android-Chat-app-with-FireBase',
#  'https://ineuron.ai//course/AWS-Architect-for-Real-World',
#  'https://ineuron.ai//course/Complete-ReactJS-Developer-Bootcamp',
#  'https://ineuron.ai//course/Complete-Bootstrap---5-Projects',
#  'https://ineuron.ai//course/Django-Course',
#  'https://ineuron.ai//course/Back-end-development-with-Django-8-Projects',
#  'https://ineuron.ai//course/React-Native',
#  'https://ineuron.ai//course/Java-Bootcamp',
#  'https://ineuron.ai//course/Kotlin',
#  'https://ineuron.ai//course/Vuejs',
#  'https://ineuron.ai//course/Git-and-GitHub',
#  'https://ineuron.ai//course/Docker-Course',
#  'https://ineuron.ai//course/MySQL',
#  'https://ineuron.ai//course/Dart-Programming',
#  'https://ineuron.ai//course/Flutter',
#  'https://ineuron.ai//course/C++-Bootcamp',
#  'https://ineuron.ai//course/Tableau-Course',
#  'https://ineuron.ai//course/Power-BI-Course',
#  'https://ineuron.ai//course/Alteryx-Course',
#  'https://ineuron.ai//course/C-Programming',
#  'https://ineuron.ai//course/FastAPI',
#  'https://ineuron.ai//course/Career-Counselling',
#  'https://ineuron.ai//course/Power-Automate',
#  'https://ineuron.ai//course/R-Shiny',
#  'https://ineuron.ai//course/ELK-Stack',
#  'https://ineuron.ai//course/DOMO-BI',
#  'https://ineuron.ai//course/Stored-Procedures-in-SQL',
#  'https://ineuron.ai//course/Fivetran',
#  'https://ineuron.ai//course/Data-Warehouse',
#  'https://ineuron.ai//course/Azure-Synapse',
#  'https://ineuron.ai//course/Azure-Databricks',
#  'https://ineuron.ai//course/Azure-Data-Factory',
#  'https://ineuron.ai//course/Azure-Data-Engineering',
#  'https://ineuron.ai//course/AWS-Interview-Preparation',
#  'https://ineuron.ai//course/DBT',
#  'https://ineuron.ai//course/SQL-Server-Integration-Services',
#  'https://ineuron.ai//course/Tech-Awareness',
#  'https://ineuron.ai//course/Blockchain-for-Beginners',
#  'https://ineuron.ai//course/Node-JS-Foundation',
#  'https://ineuron.ai//course/AIOPS-Live-Projects',
#  'https://ineuron.ai//course/PL-SQL',
#  'https://ineuron.ai//course/Airflow',
#  'https://ineuron.ai//course/Alteryx',
#  'https://ineuron.ai//course/RPA-Foundation',
#  'https://ineuron.ai//course/Marketing-Mix-Modelling',
#  'https://ineuron.ai//course/Graph-ML',
#  'https://ineuron.ai//course/Complete-Backend-development-with-Nodejs',
#  'https://ineuron.ai//course/DSA-with-Python',
#  'https://ineuron.ai//course/DSA-with-C++',
#  'https://ineuron.ai//course/DSA-with-Java',
#  'https://ineuron.ai//course/Email-Marketing',
#  'https://ineuron.ai//course/MLflow',
#  'https://ineuron.ai//course/PostgreSQL',
#  'https://ineuron.ai//course/RPA---UiPath',
#  'https://ineuron.ai//course/MS-SQL-Server-and-T-SQL',
#  'https://ineuron.ai//course/Snowflake-Beginners',
#  'https://ineuron.ai//course/Tibco-Spotfire',
#  'https://ineuron.ai//course/PyTorch-Basics',
#  'https://ineuron.ai//course/Streamlit',
#  'https://ineuron.ai//course/Dask',
#  'https://ineuron.ai//course/AWS-QuickSight',
#  'https://ineuron.ai//course/AWS-Sagemaker',
#  'https://ineuron.ai//course/Trifacta',
#  'https://ineuron.ai//course/System-Design',
#  'https://ineuron.ai//course/Mathematics-for-Machine-Learning',
#  'https://ineuron.ai//course/Class-10th-Chemistry',
#  'https://ineuron.ai//course/Class-9th-Chemistry',
#  'https://ineuron.ai//course/Class-8th-Chemistry',
#  'https://ineuron.ai//course/Class-6th-Chemistry',
#  'https://ineuron.ai//course/Solidity-Live-Class',
#  'https://ineuron.ai//course/MLOPS-Live-Class',
#  'https://ineuron.ai//course/SPARK-Augmented-Reality-Live-Class',
#  'https://ineuron.ai//course/Statistics-Live-Class',
#  'https://ineuron.ai//course/Machine-Learning-Live-Class',
#  'https://ineuron.ai//course/Linux-Live-Class',
#  'https://ineuron.ai//course/Drone-Live-Class',
#  'https://ineuron.ai//course/Data-Structures-and-Algorithms-Live-Class',
#  'https://ineuron.ai//course/Arduino-Live-Class',
#  'https://ineuron.ai//course/Aptitude-Live-Class',
#  'https://ineuron.ai//course/Microsoft-PowerApps',
#  'https://ineuron.ai//course/Advanced-Web-Development',
#  'https://ineuron.ai//course/Robotics',
#  'https://ineuron.ai//course/Artificial-Intelligence-for-Kids',
#  'https://ineuron.ai//course/Deep-Learning-for-Kids',
#  'https://ineuron.ai//course/Image-Processing',
#  'https://ineuron.ai//course/Statistics-using-Python',
#  'https://ineuron.ai//course/Raspberry-Pi',
#  'https://ineuron.ai//course/Fundamentals-of-Web-Designing',
#  'https://ineuron.ai//course/Class-8th-Math',
#  'https://ineuron.ai//course/Class-7th-Math',
#  'https://ineuron.ai//course/Class-6th-Math',
#  'https://ineuron.ai//course/Class-9th-Physics',
#  'https://ineuron.ai//course/Class-10th-Physics',
#  'https://ineuron.ai//course/Class-8th-Physics',
#  'https://ineuron.ai//course/Class-7th-Physics',
#  'https://ineuron.ai//course/Class-6th-Physics',
#  'https://ineuron.ai//course/Class-7th-Biology',
#  'https://ineuron.ai//course/Class-10th-Math',
#  'https://ineuron.ai//course/Class-9th-Math',
#  'https://ineuron.ai//course/Class-8th-Biology',
#  'https://ineuron.ai//course/Class-6th-Biology',
#  'https://ineuron.ai//course/Class-10th-Biology',
#  'https://ineuron.ai//course/Game-Development-using-Unity',
#  'https://ineuron.ai//course/Scratch-Programming-for-kids',
#  'https://ineuron.ai//course/Interactive-Visualization-using-Seaborn',
#  'https://ineuron.ai//course/OpenCV-using-Python',
#  'https://ineuron.ai//course/Mathematics-using-Python',
#  'https://ineuron.ai//course/Data-Analysis-Using-Python',
#  'https://ineuron.ai//course/UI-Designing-using-Figma',
#  'https://ineuron.ai//course/Getting-started-with-Cloud',
#  'https://ineuron.ai//course/Fundamentals-of-Database',
#  'https://ineuron.ai//course/Video-editing-with-Adobe-Premiere-Pro',
#  'https://ineuron.ai//course/Numerical-Computation-with-Python',
#  'https://ineuron.ai//course/Natural-Language-Processing',
#  'https://ineuron.ai//course/Data-Visualization-using-Matplotlib',
#  'https://ineuron.ai//course/Data-Processing-using-Dask',
#  'https://ineuron.ai//course/Data-Manipulation-using-Pandas',
#  'https://ineuron.ai//course/Character-Recognition-using-Python',
#  'https://ineuron.ai//course/Web-Designing-using-Wordpress',
#  'https://ineuron.ai//course/Vedic-Math',
#  'https://ineuron.ai//course/Fundamentals-of-Game-Development',
#  'https://ineuron.ai//course/Fundamentals-of-Electronics',
#  'https://ineuron.ai//course/App-Building-Using-Android',
#  'https://ineuron.ai//course/Advanced-Python',
#  'https://ineuron.ai//course/Building-Chatbot-using-Google-DialogFlow',
#  'https://ineuron.ai//course/Programming-in-Python',
#  'https://ineuron.ai//course/Graphics-Design-with-PhotoShop',
#  'https://ineuron.ai//course/Basics-of-Computer-Education',
#  'https://ineuron.ai//course/Class-9th-Biology',
#  'https://ineuron.ai//course/Jenkins',
#  'https://ineuron.ai//course/ParlAI-Chatbot',
#  'https://ineuron.ai//course/Qlik-Sense',
#  'https://ineuron.ai//course/ONNX',
#  'https://ineuron.ai//course/Solidity',
#  'https://ineuron.ai//course/Mega-Project-Foundation',
#  'https://ineuron.ai//course/Data-Science-Masters',
#  'https://ineuron.ai//course/Angular',
#  'https://ineuron.ai//course/DART',
#  'https://ineuron.ai//course/JAX',
#  'https://ineuron.ai//course/Recommender-System',
#  'https://ineuron.ai//course/Blockchain',
#  'https://ineuron.ai//course/DevOps-Master',
#  'https://ineuron.ai//course/Machine-Learning-Masters',
#  'https://ineuron.ai//course/Interview-ready-DSA-course-in-Python-Level-2',
#  'https://ineuron.ai//course/DLCV-with-NLP',
#  'https://ineuron.ai//course/Big-Data-Masters-Crash-Course',
#  'https://ineuron.ai//course/Business-Analytics-Crash-Course',
#  'https://ineuron.ai//course/Full-Stack-Data-Science',
#  'https://ineuron.ai//course/R-Programming-Projects',
#  'https://ineuron.ai//course/AIOps-Interview-Questions',
#  'https://ineuron.ai//course/AIOps',
#  'https://ineuron.ai//course/Django',
#  'https://ineuron.ai//course/Python-advance-with-projects',
#  'https://ineuron.ai//course/NLP-Interview-Questions',
#  'https://ineuron.ai//course/Deep-Learning-ANN',
#  'https://ineuron.ai//course/Data-Structures-and-Algorithms-using-python',
#  'https://ineuron.ai//course/Introduction-to-AIOps',
#  'https://ineuron.ai//course/RASA',
#  'https://ineuron.ai//course/Data-Science-Project',
#  'https://ineuron.ai//course/ML-Interview-Prepration',
#  'https://ineuron.ai//course/Power-BI-Projects',
#  'https://ineuron.ai//course/OpenCV-Job-Preparation',
#  'https://ineuron.ai//course/Ansible',
#  'https://ineuron.ai//course/C++-Job-Preparation',
#  'https://ineuron.ai//course/Digital-Marketing-Projects',
#  'https://ineuron.ai//course/Google-Cloud-Platform',
#  'https://ineuron.ai//course/Interview-ready-DSA-course-in-Python',
#  'https://ineuron.ai//course/NLP-Crash-Course',
#  'https://ineuron.ai//course/Machine-Learning',
#  'https://ineuron.ai//course/Stats-for-Data-Science',
#  'https://ineuron.ai//course/Python-Crash-Course',
#  'https://ineuron.ai//course/Python-for-Beginner',
#  'https://ineuron.ai//course/Machine-Learning-Projects',
#  'https://ineuron.ai//course/Data-Structure-and-Algorithm-Job-Preparation',
#  'https://ineuron.ai//course/NLP-Projects',
#  'https://ineuron.ai//course/Data-Structure-and-Algorithm-Projects',
#  'https://ineuron.ai//course/Advance-Excel',
#  'https://ineuron.ai//course/OpenCV-Projects',
#  'https://ineuron.ai//course/Computer-Vision-Projects',
#  'https://ineuron.ai//course/Computer-Vision',
#  'https://ineuron.ai//course/GCP-Interview',
#  'https://ineuron.ai//course/Azure-Luis',
#  "https://ineuron.ai//course/Full-Stack-Data-Science-Nov'21-Batch",
#  'https://ineuron.ai//course/MLDL',
#  'https://ineuron.ai//course/Business-Analytics',
#  'https://ineuron.ai//course/AI-Operations',
#  'https://ineuron.ai//course/AWS-Cloud-Master',
#  'https://ineuron.ai//course/Big-Data-Masters',
#  'https://ineuron.ai//course/30-days-Fast-Track-Data-Science-Interview-Preparation',
#  'https://ineuron.ai//course/End-to-End-Object-Detection',
#  'https://ineuron.ai//course/Class-10-Biology',
#  'https://ineuron.ai//course/Class-10-Chemistry',
#  'https://ineuron.ai//course/Class-10-Physics',
#  'https://ineuron.ai//course/Class-10-Mathematics',
#  'https://ineuron.ai//course/Mega-Community',
#  'https://ineuron.ai//course/Data-Structure-and-Algorithms-with-competitive-programming',
#  'https://ineuron.ai//course/MERN-Stack-Beginner-to-Advance-with-Internship',
#  'https://ineuron.ai//course/Deep-Learning-With-Computer-Vision-and-Advanced-NLP',
#  'https://ineuron.ai//course/Business-Analytics-Masters-with-3-month-Internship',
#  'https://ineuron.ai//course/Machine-Learning-And-Deep-Learning-Masters',
#  "https://ineuron.ai//course/Full-Stack-Data-Science-Feb'21-Batch",
#  'https://ineuron.ai//course/Digital-Marketing-Foundation',
#  'https://ineuron.ai//course/Live-Virtual-Interview',
#  'https://ineuron.ai//course/Chatbot-using-Rasa-NLU',
#  'https://ineuron.ai//course/Chatbot-using-Azure-Luis',
#  'https://ineuron.ai//course/Chatbot-Using-Google-Dialogflow',
#  'https://ineuron.ai//course/Amazon-Lex-Chatbot',
#  'https://ineuron.ai//course/Stats-for-Beginners',
#  'https://ineuron.ai//course/Machine-Learning-Foundation',
#  'https://ineuron.ai//course/Deep-Learning-Foundation',
#  'https://ineuron.ai//course/React-JS',
#  'https://ineuron.ai//course/Angular-JS',
#  'https://ineuron.ai//course/Node-JS',
#  'https://ineuron.ai//course/DSAR',
#  'https://ineuron.ai//course/Tableau-Foundation',
#  'https://ineuron.ai//course/PowerBI-Foundation',
#  'https://ineuron.ai//course/DevOps-Foundation',
#  'https://ineuron.ai//course/Data-Structure-and-Algorithm-Foundation',
#  'https://ineuron.ai//course/Tableau-Job-Preparation',
#  'https://ineuron.ai//course/Artificial-Neural-Network',
#  'https://ineuron.ai//course/Computer-Vision-Crash-Course',
#  'https://ineuron.ai//course/AWS-Crash-Course',
#  'https://ineuron.ai//course/Advance-Computer-Vision',
#  'https://ineuron.ai//course/AIOPS-Crash-Course',
#  'https://ineuron.ai//course/SQL-Projects',
#  'https://ineuron.ai//course/R-Programming-Job-Preparation',
#  'https://ineuron.ai//course/AIOps-Projects',
#  'https://ineuron.ai//course/Mern-Stack-Projects',
#  'https://ineuron.ai//course/SQL-Job-Preparation',
#  'https://ineuron.ai//course/Tableau-Projects',
#  'https://ineuron.ai//course/GCP-Projects',
#  'https://ineuron.ai//course/Kubernetes',
#  'https://ineuron.ai//course/Google-Dialogflow',
#  'https://ineuron.ai//course/Aptitude-Test',
#  'https://ineuron.ai//course/Azure-Certification-Road-Map',
#  'https://ineuron.ai//course/Mern-Stack',
#  'https://ineuron.ai//course/AWS',
#  'https://ineuron.ai//course/OpenCV',
#  'https://ineuron.ai//course/Statistics',
#  'https://ineuron.ai//course/Azure-Fundamentals',
#  'https://ineuron.ai//course/Amazon-Lex',
#  'https://ineuron.ai//course/Docker',
#  'https://ineuron.ai//course/Complete-Interview-Preparation-For-Data-Structure-and-Algorithm-in-Python',
#  'https://ineuron.ai//course/Mern-stack-job-preparation',
#  'https://ineuron.ai//course/Azure-Data-scientist-Associate-DP100',
#  'https://ineuron.ai//course/Digital-Marketing',
#  'https://ineuron.ai//course/GIT',
#  'https://ineuron.ai//course/Linux',
#  'https://ineuron.ai//course/R-Programming',
#  'https://ineuron.ai//course/Complete-DSA-in-Python',
#  'https://ineuron.ai//course/Tableau-Foundation-Course',
#  'https://ineuron.ai//course/Complete-Excel-Course',
#  'https://ineuron.ai//course/Automatic-Number-Plate-Recognition',
#  'https://ineuron.ai//course/Build-Modern-ETL-Data-Pipeline-using-Informatica-cloud',
#  'https://ineuron.ai//course/Build-ETL-Data-Pipeline-on-AWS-EMR-Cluster',
#  'https://ineuron.ai//course/Create-A-Data-Pipeline-based-on-Messaging-Using-PySpark-and-Airflow',
#  'https://ineuron.ai//course/Hive-Project-to-build-a-data-warehouse-for-e-Commerce',
#  'https://ineuron.ai//course/House-Price-Prediction',
#  'https://ineuron.ai//course/MLFlow-Production-Server-Setup',
#  'https://ineuron.ai//course/Sensor-Fault-Prediction',
#  'https://ineuron.ai//course/Text-Summarization',
#  'https://ineuron.ai//course/The-Ultimate-Guide-To-OpenAI-GPT-3-&-Fine-Tune-with-Custom-Data',
#  'https://ineuron.ai//course/Industry-Safety-Detection-using-YOLO-v7',
#  'https://ineuron.ai//course/Shipment-Price-Prediction',
#  'https://ineuron.ai//course/Finance-Complaint',
#  'https://ineuron.ai//course/Deep-Authenticator',
#  'https://ineuron.ai//course/Language-Identification',
#  'https://ineuron.ai//course/Sign-Language-Detection',
#  'https://ineuron.ai//course/Text-To-Speech',
#  'https://ineuron.ai//course/Face-Swap-Application',
#  "https://ineuron.ai//course/Full-Stack-Data-Science-Nov'21-Tech-Neuron",
#  "https://ineuron.ai//course/Full-Stack-Data-Science-Feb'21-Tech-Neuron",
#  'https://ineuron.ai//course/Machine-Learning-Bootcamp-Tech-Neuron',
#  'https://ineuron.ai//course/Manual-Testing-Kickstart',
#  'https://ineuron.ai//course/Machine-Learning-Bootcamp',
#  'https://ineuron.ai//course/Azure-Machine-Learning-DP-100',
#  'https://ineuron.ai//course/Informatica-Cloud-(IICS)',
#  'https://ineuron.ai//course/DSA-in-C++,-Competitive-Programming-&-IOT-in-Hindi',
#  'https://ineuron.ai//course/Teradata',
#  'https://ineuron.ai//course/Full-Stack-Data-Analytics-2.0',
#  'https://ineuron.ai//course/Job-Guaranteed-BigData-Bootcamp-2.0',
#  'https://ineuron.ai//course/Web-Automation-Using-Selenium-Community-Class',
#  'https://ineuron.ai//course/Pre-Ethical-Hacking-Community-Class',
#  'https://ineuron.ai//course/TypeScript-Crash-Course',
#  'https://ineuron.ai//course/Full-Stack-JavaScript-Bootcamp-2.0',
#  'https://ineuron.ai//course/Java-Community-Class',
#  'https://ineuron.ai//course/C-Sharp-Programming',
#  'https://ineuron.ai//course/Complete-iOS-16-Developer-with-SwiftUI-and-8-Apps',
#  'https://ineuron.ai//course/Complete-iOS-16-Developer-with-Swift-and-8-Apps',
#  'https://ineuron.ai//course/Full-Stack-Java-Developer',
#  'https://ineuron.ai//course/Be-A-DevOps-Pro-Tech-Neuron',
#  'https://ineuron.ai//course/Be-A-DevOps-Pro',
#  'https://ineuron.ai//course/Prisma-Backend-Development',
#  'https://ineuron.ai//course/Data-Science-Interview-Tech-Neuron',
#  'https://ineuron.ai//course/Data-Science-Interview',
#  'https://ineuron.ai//course/Industry-Ready-Data-Science-Projects-Tech-Neuron',
#  'https://ineuron.ai//course/Data-Science-Industry-Ready-Projects',
#  'https://ineuron.ai//course/Web-Automation-Using-Selenium-With-Java-and-Cucumber-BDD-Tech-Neuron',
#  'https://ineuron.ai//course/DSA-for-FAANG-preparation-with-Python-and-JavaScript-Tech-Neuron',
#  'https://ineuron.ai//course/Full-Stack-Web-Development-with-Python-in-Hindi-Tech-Neuron',
#  'https://ineuron.ai//course/Big-Data-Masters-Tech-Neuron',
#  'https://ineuron.ai//course/Full-Stack-Data-Science-BootCamp-2.0',
#  'https://ineuron.ai//course/Reinforcement-Learning',
#  'https://ineuron.ai//course/Android-Technical-Interview-Preparation',
#  'https://ineuron.ai//course/C-Coding-Interview-Preparation',
#  'https://ineuron.ai//course/C++-Coding-Interview-Preparation',
#  'https://ineuron.ai//course/Data-Structure-and-Algorithm-Interview-Preparation',
#  'https://ineuron.ai//course/HTML-CSS-Coding-Interview-Preparation',
#  'https://ineuron.ai//course/Java-Coding-Interview-Preparation',
#  'https://ineuron.ai//course/JavaScript-Coding-Interview-Preparation',
#  'https://ineuron.ai//course/Machine-Learning-Interview-Preparation',
#  'https://ineuron.ai//course/Pro-Aptitude---C-Language',
#  'https://ineuron.ai//course/Pro-Aptitude---C++',
#  'https://ineuron.ai//course/Pro-Aptitude---Data-Structures-and-Algorithms',
#  'https://ineuron.ai//course/Pro-Aptitude---DBMS',
#  'https://ineuron.ai//course/Pro-Aptitude---Java',
#  'https://ineuron.ai//course/Pro-Aptitude---Operating-Systems',
#  'https://ineuron.ai//course/Pro-Aptitude---Python',
#  'https://ineuron.ai//course/Pro-Computer-Networking',
#  'https://ineuron.ai//course/Pro-C-Programming-Language',
#  'https://ineuron.ai//course/Pro-Max-Interview-Preparation-Edition-1',
#  'https://ineuron.ai//course/Pro-Max-Interview-Preparation-Edition-2',
#  'https://ineuron.ai//course/Pro-Max-Interview-Preparation-Edition-3',
#  'https://ineuron.ai//course/Pro-C++-Programming-Language',
#  'https://ineuron.ai//course/Pro-Database-Management-Systems',
#  'https://ineuron.ai//course/Pro-Data-Structure-and-Algorithms',
#  'https://ineuron.ai//course/Pro-Java-Programming-Language',
#  'https://ineuron.ai//course/Pro-JavaScript-Programming-Language',
#  'https://ineuron.ai//course/Pro-Operating-Systems',
#  'https://ineuron.ai//course/Pro-Python-Programming-Language',
#  'https://ineuron.ai//course/Python-Coding-Interview-Preparation',
#  'https://ineuron.ai//course/Aptitude-Test-Series',
#  'https://ineuron.ai//course/Mastering-DSA-with-Python',
#  'https://ineuron.ai//course/Mastering-DSA-with-Java',
#  'https://ineuron.ai//course/Mastering-DSA-with-C++',
#  'https://ineuron.ai//course/Android-P-with-Machine-Learning-Apps',
#  'https://ineuron.ai//course/Full-Stack-Django-and-React',
#  'https://ineuron.ai//course/Full-Stack-Django-with-React',
#  'https://ineuron.ai//course/Complete-Front-End-Web-Developer-Bootcamp',
#  'https://ineuron.ai//course/Complete-Backend-Development-with-Nodejs',
#  'https://ineuron.ai//course/Backend-Development-with-Django-8-Projects',
#  'https://ineuron.ai//course/Complete-Flutter-Course---iOS-Android-Apps',
#  'https://ineuron.ai//course/Dart-Language',
#  'https://ineuron.ai//course/Complete-ReactJs-Developer-Bootcamp',
#  'https://ineuron.ai//course/Complete-Bootstrap4---Build-5-Projects',
#  'https://ineuron.ai//course/Android-Chatapp-with-FireBase',
#  'https://ineuron.ai//course/C++-Bootcamp-for-Beginners',
#  'https://ineuron.ai//course/Complete-Angular-Developer-Bootcamp',
#  'https://ineuron.ai//course/Crack-the-Tech-Interviews',
#  'https://ineuron.ai//course/Complete-React-Native-Mobile-App-Developer',
#  'https://ineuron.ai//course/Complete-VueJS-Development',
#  'https://ineuron.ai//course/The-Pro-Backend-Developer',
#  'https://ineuron.ai//course/AWS-Architect-for-the-Real-World',
#  'https://ineuron.ai//course/HTML-and-CSS-for-Web-Development',
#  'https://ineuron.ai//course/JavaScript-Fundamentals',
#  'https://ineuron.ai//course/HTML-and-CSS',
#  'https://ineuron.ai//course/Ethical-Hacking-&-Penetration-Testing',
#  'https://ineuron.ai//course/Crack-the-Tech-Interview',
#  'https://ineuron.ai//course/Write-quicker-HTML5-and-CSS-3;-productivity-hacks-with-emmet4',
#  'https://ineuron.ai//course/The-Complete-Front-End-Web-Developer-Bootcamp',
#  'https://ineuron.ai//course/Machine-Learning-and-Data-Science-Bootcamp',
#  'https://ineuron.ai//course/Publishing-Custom-Cocoapads',
#  'https://ineuron.ai//course/Build-an-Ecommerce-with-ReactJS',
#  'https://ineuron.ai//course/Python3-Scratch-To-Pro',
#  'https://ineuron.ai//course/ReactJS-Crash-Course',
#  'https://ineuron.ai//course/Angular-Crash-Course',
#  'https://ineuron.ai//course/Python-Crash-Course-by-Hitesh',
#  'https://ineuron.ai//course/Stripe-with-React-and-Node-Crash-Course',
#  'https://ineuron.ai//course/Materialize-CSS-Crash-Course',
#  'https://ineuron.ai//course/VueJS-Crash-Course',
#  'https://ineuron.ai//course/Graph-QL-Crash-Course',
#  'https://ineuron.ai//course/AWS-Serverless',
#  'https://ineuron.ai//course/Fastify-Crash-Course',
#  'https://ineuron.ai//course/Socket-io-Crash-Course',
#  'https://ineuron.ai//course/NextJS-Full-stack-crash-course',
#  'https://ineuron.ai//course/DSA-for-FAANG-preparation-with-Python-and-JavaScript',
#  'https://ineuron.ai//course/DP-900-Microsoft-Azure-Data-Fundamentals',
#  'https://ineuron.ai//course/AWS-Big-Data-Analytics',
#  'https://ineuron.ai//course/Auto-Sklearn-and-Auto-TimeSeries',
#  'https://ineuron.ai//course/Blockchain-Foundations',
#  'https://ineuron.ai//course/Angular-JS-Course',
#  'https://ineuron.ai//course/Snowflake-Advanced',
#  'https://ineuron.ai//course/APIGEE',
#  'https://ineuron.ai//course/Yolo-X-and-Yolo-R',
#  'https://ineuron.ai//course/SAS-Programming',
#  'https://ineuron.ai//course/Job-Guaranteed-Big-Data-Bootcamp',
#  'https://ineuron.ai//course/Mulesoft',
#  'https://ineuron.ai//course/IOT',
#  'https://ineuron.ai//course/Full-Stack-Data-Analytics-Tech-Neuron',
#  'https://ineuron.ai//course/Full-Stack-Blockchain-Development-Tech-Neuron',
#  'https://ineuron.ai//course/Youtube-Mastery-Course-in-Hindi-Tech-Neuron',
#  'https://ineuron.ai//course/Job-Ready-Automation-Tester-with-JavaScript-Tech-Neuron',
#  'https://ineuron.ai//course/System-Design-with-Design-Patterns-Tech-Neuron',
#  'https://ineuron.ai//course/Cyber-Security-Masters-Tech-Neuron',
#  'https://ineuron.ai//course/Digital-Marketing-Bootcamp-in-Hindi-Tech-Neuron',
#  'https://ineuron.ai//course/A-Job-Ready-Bootcamp-in--C++,-DSA-and-IOT-Tech-Neuron',
#  'https://ineuron.ai//course/Enterprise-Java-with-Spring-Boot-Tech-Neuron',
#  'https://ineuron.ai//course/Data-Engineering-with-Google-Cloud',
#  'https://ineuron.ai//course/Explainable-AI',
#  'https://ineuron.ai//course/Full-Stack-Blockchain-Development',
#  'https://ineuron.ai//course/JavaScript-Marathon',
#  'https://ineuron.ai//course/AIOPS-Course',
#  'https://ineuron.ai//course/C-language-for-Absolute-Beginners',
#  'https://ineuron.ai//course/MSBI',
#  'https://ineuron.ai//course/Web-Automation-Foundations',
#  'https://ineuron.ai//course/Digital-Marketing-and-Youtube-Niche-Foundations',
#  'https://ineuron.ai//course/Java-Foundations',
#  'https://ineuron.ai//course/NLP-Foundations',
#  'https://ineuron.ai//course/SQL-Foundations',
#  'https://ineuron.ai//course/ML-and-DL-Foundations',
#  'https://ineuron.ai//course/Scala',
#  'https://ineuron.ai//course/Manual-Testing-Foundations',
#  'https://ineuron.ai//course/Cyber-Security-Foundations',
#  'https://ineuron.ai//course/Salesforce-Developer',
#  'https://ineuron.ai//course/Golang',
#  'https://ineuron.ai//course/Tibco-Business-Works',
#  'https://ineuron.ai//course/GCP-Machine-Learning-Certification',
#  'https://ineuron.ai//course/System-Design-Foundations',
#  'https://ineuron.ai//course/Informatica-Powercenter',
#  'https://ineuron.ai//course/Talend',
#  'https://ineuron.ai//course/Machine-Learning-in-R',
#  'https://ineuron.ai//course/Pro-Live-Classes',
#  'https://ineuron.ai//course/MongoDB-Course',
#  'https://ineuron.ai//course/Spring-Boot',
#  'https://ineuron.ai//course/System-Design-with-Design-Patterns',
#  'https://ineuron.ai//course/Enterprise-Java-with-Spring-Boot',
#  'https://ineuron.ai//course/Apache-Atlas',
#  'https://ineuron.ai//course/Apache-Druid',
#  'https://ineuron.ai//course/Cyber-Security-Masters',
#  'https://ineuron.ai//course/Bash-Scripting',
#  'https://ineuron.ai//course/Deep-Learning-Foundations',
#  'https://ineuron.ai//course/Data-Analytics-Bootcamp',
#  'https://ineuron.ai//course/MERN-Stack-Bootcamp',
#  'https://ineuron.ai//course/Certified-Ethical-Hacker-Bootcamp',
#  'https://ineuron.ai//course/Latex',
#  'https://ineuron.ai//course/Julia-Programming',
#  'https://ineuron.ai//course/Matlab-Basic-to-Advance',
#  'https://ineuron.ai//course/Salesforce-Administrator',
#  'https://ineuron.ai//course/Full-Stack-Data-Science-Bootcamp',
#  'https://ineuron.ai//course/AWS-Data-Engineering',
#  'https://ineuron.ai//course/Big-Data-Foundations',
#  'https://ineuron.ai//course/Reasoning-Live-Class',
#  'https://ineuron.ai//course/Spark-AR-Live-Class',
#  'https://ineuron.ai//course/Power-BI-Foundations',
#  'https://ineuron.ai//course/Foundations-of-English-Language',
#  'https://ineuron.ai//course/Android-Programming-with-Machine-Learning-Apps',
#  'https://ineuron.ai//course/Pro-Backend-Developer',
#  'https://ineuron.ai//course/Android-Chat-app-with-FireBase',
#  'https://ineuron.ai//course/AWS-Architect-for-Real-World',
#  'https://ineuron.ai//course/Complete-ReactJS-Developer-Bootcamp',
#  'https://ineuron.ai//course/Complete-Bootstrap---5-Projects',
#  'https://ineuron.ai//course/Django-Course',
#  'https://ineuron.ai//course/Back-end-development-with-Django-8-Projects',
#  'https://ineuron.ai//course/React-Native',
#  'https://ineuron.ai//course/Java-Bootcamp',
#  'https://ineuron.ai//course/Kotlin',
#  'https://ineuron.ai//course/Vuejs',
#  'https://ineuron.ai//course/Git-and-GitHub',
#  'https://ineuron.ai//course/Docker-Course',
#  'https://ineuron.ai//course/MySQL',
#  'https://ineuron.ai//course/Dart-Programming',
#  'https://ineuron.ai//course/Flutter',
#  'https://ineuron.ai//course/C++-Bootcamp',
#  'https://ineuron.ai//course/Tableau-Course',
#  'https://ineuron.ai//course/Power-BI-Course',
#  'https://ineuron.ai//course/Alteryx-Course',
#  'https://ineuron.ai//course/C-Programming',
#  'https://ineuron.ai//course/FastAPI',
#  'https://ineuron.ai//course/Career-Counselling',
#  'https://ineuron.ai//course/Power-Automate',
#  'https://ineuron.ai//course/R-Shiny',
#  'https://ineuron.ai//course/ELK-Stack',
#  'https://ineuron.ai//course/DOMO-BI',
#  'https://ineuron.ai//course/Stored-Procedures-in-SQL',
#  'https://ineuron.ai//course/Fivetran',
#  'https://ineuron.ai//course/Data-Warehouse',
#  'https://ineuron.ai//course/Azure-Synapse',
#  'https://ineuron.ai//course/Azure-Databricks',
#  'https://ineuron.ai//course/Azure-Data-Factory',
#  'https://ineuron.ai//course/Azure-Data-Engineering',
#  'https://ineuron.ai//course/AWS-Interview-Preparation',
#  'https://ineuron.ai//course/DBT',
#  'https://ineuron.ai//course/SQL-Server-Integration-Services',
#  'https://ineuron.ai//course/Tech-Awareness',
#  'https://ineuron.ai//course/Blockchain-for-Beginners',
#  'https://ineuron.ai//course/Node-JS-Foundation',
#  'https://ineuron.ai//course/AIOPS-Live-Projects',
#  'https://ineuron.ai//course/PL-SQL',
#  'https://ineuron.ai//course/Airflow',
#  'https://ineuron.ai//course/Alteryx',
#  'https://ineuron.ai//course/RPA-Foundation',
#  'https://ineuron.ai//course/Marketing-Mix-Modelling',
#  'https://ineuron.ai//course/Graph-ML',
#  'https://ineuron.ai//course/Complete-Backend-development-with-Nodejs',
#  'https://ineuron.ai//course/DSA-with-Python',
#  'https://ineuron.ai//course/DSA-with-C++',
#  'https://ineuron.ai//course/DSA-with-Java',
#  'https://ineuron.ai//course/Email-Marketing',
#  'https://ineuron.ai//course/MLflow',
#  'https://ineuron.ai//course/PostgreSQL',
#  'https://ineuron.ai//course/RPA---UiPath',
#  'https://ineuron.ai//course/MS-SQL-Server-and-T-SQL',
#  'https://ineuron.ai//course/Snowflake-Beginners',
#  'https://ineuron.ai//course/Tibco-Spotfire',
#  'https://ineuron.ai//course/PyTorch-Basics',
#  'https://ineuron.ai//course/Streamlit',
#  'https://ineuron.ai//course/Dask',
#  'https://ineuron.ai//course/AWS-QuickSight',
#  'https://ineuron.ai//course/AWS-Sagemaker',
#  'https://ineuron.ai//course/Trifacta',
#  'https://ineuron.ai//course/System-Design',
#  'https://ineuron.ai//course/Mathematics-for-Machine-Learning',
#  'https://ineuron.ai//course/Class-10th-Chemistry',
#  'https://ineuron.ai//course/Class-9th-Chemistry',
#  'https://ineuron.ai//course/Class-8th-Chemistry',
#  'https://ineuron.ai//course/Class-6th-Chemistry',
#  'https://ineuron.ai//course/Solidity-Live-Class',
#  'https://ineuron.ai//course/MLOPS-Live-Class',
#  'https://ineuron.ai//course/SPARK-Augmented-Reality-Live-Class',
#  'https://ineuron.ai//course/Statistics-Live-Class',
#  'https://ineuron.ai//course/Machine-Learning-Live-Class',
#  'https://ineuron.ai//course/Linux-Live-Class',
#  'https://ineuron.ai//course/Drone-Live-Class',
#  'https://ineuron.ai//course/Data-Structures-and-Algorithms-Live-Class',
#  'https://ineuron.ai//course/Arduino-Live-Class',
#  'https://ineuron.ai//course/Aptitude-Live-Class',
#  'https://ineuron.ai//course/Microsoft-PowerApps',
#  'https://ineuron.ai//course/Advanced-Web-Development',
#  'https://ineuron.ai//course/Robotics',
#  'https://ineuron.ai//course/Artificial-Intelligence-for-Kids',
#  'https://ineuron.ai//course/Deep-Learning-for-Kids',
#  'https://ineuron.ai//course/Image-Processing',
#  'https://ineuron.ai//course/Statistics-using-Python',
#  'https://ineuron.ai//course/Raspberry-Pi',
#  'https://ineuron.ai//course/Fundamentals-of-Web-Designing',
#  'https://ineuron.ai//course/Class-8th-Math',
#  'https://ineuron.ai//course/Class-7th-Math',
#  'https://ineuron.ai//course/Class-6th-Math',
#  'https://ineuron.ai//course/Class-9th-Physics',
#  'https://ineuron.ai//course/Class-10th-Physics',
#  'https://ineuron.ai//course/Class-8th-Physics',
#  'https://ineuron.ai//course/Class-7th-Physics',
#  'https://ineuron.ai//course/Class-6th-Physics',
#  'https://ineuron.ai//course/Class-7th-Biology',
#  'https://ineuron.ai//course/Class-10th-Math',
#  'https://ineuron.ai//course/Class-9th-Math',
#  'https://ineuron.ai//course/Class-8th-Biology',
#  'https://ineuron.ai//course/Class-6th-Biology',
#  'https://ineuron.ai//course/Class-10th-Biology',
#  'https://ineuron.ai//course/Game-Development-using-Unity',
#  'https://ineuron.ai//course/Scratch-Programming-for-kids',
#  'https://ineuron.ai//course/Interactive-Visualization-using-Seaborn',
#  'https://ineuron.ai//course/OpenCV-using-Python',
#  'https://ineuron.ai//course/Mathematics-using-Python',
#  'https://ineuron.ai//course/Data-Analysis-Using-Python',
#  'https://ineuron.ai//course/UI-Designing-using-Figma',
#  'https://ineuron.ai//course/Getting-started-with-Cloud',
#  'https://ineuron.ai//course/Fundamentals-of-Database',
#  'https://ineuron.ai//course/Video-editing-with-Adobe-Premiere-Pro',
#  'https://ineuron.ai//course/Numerical-Computation-with-Python',
#  'https://ineuron.ai//course/Natural-Language-Processing',
#  'https://ineuron.ai//course/Data-Visualization-using-Matplotlib',
#  'https://ineuron.ai//course/Data-Processing-using-Dask',
#  'https://ineuron.ai//course/Data-Manipulation-using-Pandas',
#  'https://ineuron.ai//course/Character-Recognition-using-Python',
#  'https://ineuron.ai//course/Web-Designing-using-Wordpress',
#  'https://ineuron.ai//course/Vedic-Math',
#  'https://ineuron.ai//course/Fundamentals-of-Game-Development',
#  'https://ineuron.ai//course/Fundamentals-of-Electronics',
#  'https://ineuron.ai//course/App-Building-Using-Android',
#  'https://ineuron.ai//course/Advanced-Python',
#  'https://ineuron.ai//course/Building-Chatbot-using-Google-DialogFlow',
#  'https://ineuron.ai//course/Programming-in-Python',
#  'https://ineuron.ai//course/Graphics-Design-with-PhotoShop',
#  'https://ineuron.ai//course/Basics-of-Computer-Education',
#  'https://ineuron.ai//course/Class-9th-Biology',
#  'https://ineuron.ai//course/Jenkins',
#  'https://ineuron.ai//course/ParlAI-Chatbot',
#  'https://ineuron.ai//course/Qlik-Sense',
#  'https://ineuron.ai//course/ONNX',
#  'https://ineuron.ai//course/Solidity',
#  'https://ineuron.ai//course/Mega-Project-Foundation',
#  'https://ineuron.ai//course/Data-Science-Masters',
#  'https://ineuron.ai//course/Angular',
#  'https://ineuron.ai//course/DART',
#  'https://ineuron.ai//course/JAX',
#  'https://ineuron.ai//course/Recommender-System',
#  'https://ineuron.ai//course/Blockchain',
#  'https://ineuron.ai//course/DevOps-Master',
#  'https://ineuron.ai//course/Machine-Learning-Masters',
#  'https://ineuron.ai//course/Interview-ready-DSA-course-in-Python-Level-2',
#  'https://ineuron.ai//course/DLCV-with-NLP',
#  'https://ineuron.ai//course/Big-Data-Masters-Crash-Course',
#  'https://ineuron.ai//course/Business-Analytics-Crash-Course',
#  'https://ineuron.ai//course/Full-Stack-Data-Science',
#  'https://ineuron.ai//course/R-Programming-Projects',
#  'https://ineuron.ai//course/AIOps-Interview-Questions',
#  'https://ineuron.ai//course/AIOps',
#  'https://ineuron.ai//course/Django',
#  'https://ineuron.ai//course/Python-advance-with-projects',
#  'https://ineuron.ai//course/NLP-Interview-Questions',
#  'https://ineuron.ai//course/Deep-Learning-ANN',
#  'https://ineuron.ai//course/Data-Structures-and-Algorithms-using-python',
#  'https://ineuron.ai//course/Introduction-to-AIOps',
#  'https://ineuron.ai//course/RASA',
#  'https://ineuron.ai//course/Data-Science-Project',
#  'https://ineuron.ai//course/ML-Interview-Prepration',
#  'https://ineuron.ai//course/Power-BI-Projects',
#  'https://ineuron.ai//course/OpenCV-Job-Preparation',
#  'https://ineuron.ai//course/Ansible',
#  'https://ineuron.ai//course/C++-Job-Preparation',
#  'https://ineuron.ai//course/Digital-Marketing-Projects',
#  'https://ineuron.ai//course/Google-Cloud-Platform',
#  'https://ineuron.ai//course/Interview-ready-DSA-course-in-Python',
#  'https://ineuron.ai//course/NLP-Crash-Course',
#  'https://ineuron.ai//course/Machine-Learning',
#  'https://ineuron.ai//course/Stats-for-Data-Science',
#  'https://ineuron.ai//course/Python-Crash-Course',
#  'https://ineuron.ai//course/Python-for-Beginner',
#  'https://ineuron.ai//course/Machine-Learning-Projects',
#  'https://ineuron.ai//course/Data-Structure-and-Algorithm-Job-Preparation',
#  'https://ineuron.ai//course/NLP-Projects',
#  'https://ineuron.ai//course/Data-Structure-and-Algorithm-Projects',
#  'https://ineuron.ai//course/Advance-Excel',
#  'https://ineuron.ai//course/OpenCV-Projects',
#  'https://ineuron.ai//course/Computer-Vision-Projects',
#  'https://ineuron.ai//course/Computer-Vision',
#  'https://ineuron.ai//course/GCP-Interview',
#  'https://ineuron.ai//course/Azure-Luis',
#  "https://ineuron.ai//course/Full-Stack-Data-Science-Nov'21-Batch",
#  'https://ineuron.ai//course/MLDL',
#  'https://ineuron.ai//course/Business-Analytics',
#  'https://ineuron.ai//course/AI-Operations',
#  'https://ineuron.ai//course/AWS-Cloud-Master',
#  'https://ineuron.ai//course/Big-Data-Masters',
#  'https://ineuron.ai//course/30-days-Fast-Track-Data-Science-Interview-Preparation',
#  'https://ineuron.ai//course/End-to-End-Object-Detection',
#  'https://ineuron.ai//course/Class-10-Biology',
#  'https://ineuron.ai//course/Class-10-Chemistry',
#  'https://ineuron.ai//course/Class-10-Physics',
#  'https://ineuron.ai//course/Class-10-Mathematics',
#  'https://ineuron.ai//course/Mega-Community',
#  'https://ineuron.ai//course/Data-Structure-and-Algorithms-with-competitive-programming',
#  'https://ineuron.ai//course/MERN-Stack-Beginner-to-Advance-with-Internship',
#  'https://ineuron.ai//course/Deep-Learning-With-Computer-Vision-and-Advanced-NLP',
#  'https://ineuron.ai//course/Business-Analytics-Masters-with-3-month-Internship',
#  'https://ineuron.ai//course/Machine-Learning-And-Deep-Learning-Masters',
#  "https://ineuron.ai//course/Full-Stack-Data-Science-Feb'21-Batch",
#  'https://ineuron.ai//course/Digital-Marketing-Foundation',
#  'https://ineuron.ai//course/Live-Virtual-Interview',
#  'https://ineuron.ai//course/Chatbot-using-Rasa-NLU',
#  'https://ineuron.ai//course/Chatbot-using-Azure-Luis',
#  'https://ineuron.ai//course/Chatbot-Using-Google-Dialogflow',
#  'https://ineuron.ai//course/Amazon-Lex-Chatbot',
#  'https://ineuron.ai//course/Stats-for-Beginners',
#  'https://ineuron.ai//course/Machine-Learning-Foundation',
#  'https://ineuron.ai//course/Deep-Learning-Foundation',
#  'https://ineuron.ai//course/React-JS',
#  'https://ineuron.ai//course/Angular-JS',
#  'https://ineuron.ai//course/Node-JS',
#  'https://ineuron.ai//course/DSAR',
#  'https://ineuron.ai//course/Tableau-Foundation',
#  'https://ineuron.ai//course/PowerBI-Foundation',
#  'https://ineuron.ai//course/DevOps-Foundation',
#  'https://ineuron.ai//course/Data-Structure-and-Algorithm-Foundation',
#  'https://ineuron.ai//course/Tableau-Job-Preparation',
#  'https://ineuron.ai//course/Artificial-Neural-Network',
#  'https://ineuron.ai//course/Computer-Vision-Crash-Course',
#  'https://ineuron.ai//course/AWS-Crash-Course',
#  'https://ineuron.ai//course/Advance-Computer-Vision',
#  'https://ineuron.ai//course/AIOPS-Crash-Course',
#  'https://ineuron.ai//course/SQL-Projects',
#  'https://ineuron.ai//course/R-Programming-Job-Preparation',
#  'https://ineuron.ai//course/AIOps-Projects',
#  'https://ineuron.ai//course/Mern-Stack-Projects',
#  'https://ineuron.ai//course/SQL-Job-Preparation',
#  'https://ineuron.ai//course/Tableau-Projects',
#  'https://ineuron.ai//course/GCP-Projects',
#  'https://ineuron.ai//course/Kubernetes',
#  'https://ineuron.ai//course/Google-Dialogflow',
#  'https://ineuron.ai//course/Aptitude-Test',
#  'https://ineuron.ai//course/Azure-Certification-Road-Map',
#  'https://ineuron.ai//course/Mern-Stack',
#  'https://ineuron.ai//course/AWS',
#  'https://ineuron.ai//course/OpenCV',
#  'https://ineuron.ai//course/Statistics',
#  'https://ineuron.ai//course/Azure-Fundamentals',
#  'https://ineuron.ai//course/Amazon-Lex',
#  'https://ineuron.ai//course/Docker',
#  'https://ineuron.ai//course/Complete-Interview-Preparation-For-Data-Structure-and-Algorithm-in-Python',
#  'https://ineuron.ai//course/Mern-stack-job-preparation',
#  'https://ineuron.ai//course/Azure-Data-scientist-Associate-DP100',
#  'https://ineuron.ai//course/Digital-Marketing',
#  'https://ineuron.ai//course/GIT',
#  'https://ineuron.ai//course/Linux',
#  'https://ineuron.ai//course/R-Programming']

# %%
result
# Out:
# [{'Name': 'Complete DSA in Python',
#   'URL': 'https://ineuron.ai//course/Complete-DSA-in-Python'},
#  {'Name': 'Tableau Foundation Course',
#   'URL': 'https://ineuron.ai//course/Tableau-Foundation-Course'},
#  {'Name': 'Complete Excel Course',
#   'URL': 'https://ineuron.ai//course/Complete-Excel-Course'},
#  {'Name': 'Automatic Number Plate Recognition',
#   'URL': 'https://ineuron.ai//course/Automatic-Number-Plate-Recognition'},
#  {'Name': 'Build Modern ETL Data Pipeline using Informatica cloud',
#   'URL': 'https://ineuron.ai//course/Build-Modern-ETL-Data-Pipeline-using-Informatica-cloud'},
#  {'Name': 'Build ETL Data Pipeline on AWS EMR Cluster',
#   'URL': 'https://ineuron.ai//course/Build-ETL-Data-Pipeline-on-AWS-EMR-Cluster'},
#  {'Name': 'Create A Data Pipeline based on Messaging Using PySpark and Airflow',
#   'URL': 'https://ineuron.ai//course/Create-A-Data-Pipeline-based-on-Messaging-Using-PySpark-and-Airflow'},
#  {'Name': 'Hive Project to build a data warehouse for e-Commerce',
#   'URL': 'https://ineuron.ai//course/Hive-Project-to-build-a-data-warehouse-for-e-Commerce'},
#  {'Name': 'House Price Prediction',
#   'URL': 'https://ineuron.ai//course/House-Price-Prediction'},
#  {'Name': 'MLFlow Production Server Setup',
#   'URL': 'https://ineuron.ai//course/MLFlow-Production-Server-Setup'},
#  {'Name': 'Sensor Fault Prediction',
#   'URL': 'https://ineuron.ai//course/Sensor-Fault-Prediction'},
#  {'Name': 'Text Summarization',
#   'URL': 'https://ineuron.ai//course/Text-Summarization'},
#  {'Name': 'The Ultimate Guide To OpenAI GPT-3 & Fine Tune with Custom Data',
#   'URL': 'https://ineuron.ai//course/The-Ultimate-Guide-To-OpenAI-GPT-3-&-Fine-Tune-with-Custom-Data'},
#  {'Name': 'Industry Safety Detection using YOLO v7',
#   'URL': 'https://ineuron.ai//course/Industry-Safety-Detection-using-YOLO-v7'},
#  {'Name': 'Shipment Price Prediction',
#   'URL': 'https://ineuron.ai//course/Shipment-Price-Prediction'},
#  {'Name': 'Finance Complaint',
#   'URL': 'https://ineuron.ai//course/Finance-Complaint'},
#  {'Name': 'Deep Authenticator',
#   'URL': 'https://ineuron.ai//course/Deep-Authenticator'},
#  {'Name': 'Language Identification',
#   'URL': 'https://ineuron.ai//course/Language-Identification'},
#  {'Name': 'Sign Language Detection',
#   'URL': 'https://ineuron.ai//course/Sign-Language-Detection'},
#  {'Name': 'Text To Speech',
#   'URL': 'https://ineuron.ai//course/Text-To-Speech'},
#  {'Name': 'Face Swap Application',
#   'URL': 'https://ineuron.ai//course/Face-Swap-Application'},
#  {'Name': "Full Stack Data Science Nov'21 Tech Neuron",
#   'URL': "https://ineuron.ai//course/Full-Stack-Data-Science-Nov'21-Tech-Neuron"},
#  {'Name': "Full Stack Data Science Feb'21 Tech Neuron",
#   'URL': "https://ineuron.ai//course/Full-Stack-Data-Science-Feb'21-Tech-Neuron"},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai//course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Manual Testing Kickstart',
#   'URL': 'https://ineuron.ai//course/Manual-Testing-Kickstart'},
#  {'Name': 'Machine Learning Bootcamp',
#   'URL': 'https://ineuron.ai//course/Machine-Learning-Bootcamp'},
#  {'Name': 'Azure Machine Learning DP 100',
#   'URL': 'https://ineuron.ai//course/Azure-Machine-Learning-DP-100'},
#  {'Name': 'Informatica Cloud (IICS)',
#   'URL': 'https://ineuron.ai//course/Informatica-Cloud-(IICS)'},
#  {'Name': 'DSA in C++, Competitive Programming & IOT in Hindi',
#   'URL': 'https://ineuron.ai//course/DSA-in-C++,-Competitive-Programming-&-IOT-in-Hindi'},
#  {'Name': 'Teradata', 'URL': 'https://ineuron.ai//course/Teradata'},
#  {'Name': 'Full Stack Data Analytics 2.0',
#   'URL': 'https://ineuron.ai//course/Full-Stack-Data-Analytics-2.0'},
#  {'Name': 'Job Guaranteed BigData Bootcamp 2.0',
#   'URL': 'https://ineuron.ai//course/Job-Guaranteed-BigData-Bootcamp-2.0'},
#  {'Name': 'Web Automation Using Selenium Community Class',
#   'URL': 'https://ineuron.ai//course/Web-Automation-Using-Selenium-Community-Class'},
#  {'Name': 'Pre Ethical Hacking Community Class',
#   'URL': 'https://ineuron.ai//course/Pre-Ethical-Hacking-Community-Class'},
#  {'Name': 'TypeScript Crash Course',
#   'URL': 'https://ineuron.ai//course/TypeScript-Crash-Course'},
#  {'Name': 'Full Stack JavaScript Bootcamp 2.0',
#   'URL': 'https://ineuron.ai//course/Full-Stack-JavaScript-Bootcamp-2.0'},
#  {'Name': 'Java Community Class',
#   'URL': 'https://ineuron.ai//course/Java-Community-Class'},
#  {'Name': 'C Sharp Programming',
#   'URL': 'https://ineuron.ai//course/C-Sharp-Programming'},
#  {'Name': 'Complete iOS 16 Developer with SwiftUI and 8 Apps',
#   'URL': 'https://ineuron.ai//course/Complete-iOS-16-Developer-with-SwiftUI-and-8-Apps'},
#  {'Name': 'Complete iOS 16 Developer with Swift and 8 Apps',
#   'URL': 'https://ineuron.ai//course/Complete-iOS-16-Developer-with-Swift-and-8-Apps'},
#  {'Name': 'Full Stack Java Developer',
#   'URL': 'https://ineuron.ai//course/Full-Stack-Java-Developer'},
#  {'Name': 'Be A DevOps Pro Tech Neuron',
#   'URL': 'https://ineuron.ai//course/Be-A-DevOps-Pro-Tech-Neuron'},
#  {'Name': 'Be A DevOps Pro',
#   'URL': 'https://ineuron.ai//course/Be-A-DevOps-Pro'},
#  {'Name': 'Prisma Backend Development',
#   'URL': 'https://ineuron.ai//course/Prisma-Backend-Development'},
#  {'Name': 'Data Science Interview Tech Neuron',
#   'URL': 'https://ineuron.ai//course/Data-Science-Interview-Tech-Neuron'},
#  {'Name': 'Data Science Interview',
#   'URL': 'https://ineuron.ai//course/Data-Science-Interview'},
#  {'Name': 'Industry Ready Data Science Projects Tech Neuron',
#   'URL': 'https://ineuron.ai//course/Industry-Ready-Data-Science-Projects-Tech-Neuron'},
#  {'Name': 'Data Science Industry Ready Projects',
#   'URL': 'https://ineuron.ai//course/Data-Science-Industry-Ready-Projects'},
#  {'Name': 'Web Automation Using Selenium With Java and Cucumber BDD Tech Neuron',
#   'URL': 'https://ineuron.ai//course/Web-Automation-Using-Selenium-With-Java-and-Cucumber-BDD-Tech-Neuron'},
#  {'Name': 'DSA for FAANG preparation with Python and JavaScript Tech Neuron',
#   'URL': 'https://ineuron.ai//course/DSA-for-FAANG-preparation-with-Python-and-JavaScript-Tech-Neuron'},
#  {'Name': 'Full Stack Web Development with Python in Hindi Tech Neuron',
#   'URL': 'https://ineuron.ai//course/Full-Stack-Web-Development-with-Python-in-Hindi-Tech-Neuron'},
#  {'Name': 'Big Data Masters Tech Neuron',
#   'URL': 'https://ineuron.ai//course/Big-Data-Masters-Tech-Neuron'},
#  {'Name': 'Full Stack Data Science BootCamp 2.0',
#   'URL': 'https://ineuron.ai//course/Full-Stack-Data-Science-BootCamp-2.0'},
#  {'Name': 'Reinforcement Learning',
#   'URL': 'https://ineuron.ai//course/Reinforcement-Learning'},
#  {'Name': 'Android Technical Interview Preparation',
#   'URL': 'https://ineuron.ai//course/Android-Technical-Interview-Preparation'},
#  {'Name': 'C Coding Interview Preparation',
#   'URL': 'https://ineuron.ai//course/C-Coding-Interview-Preparation'},
#  {'Name': 'C++ Coding Interview Preparation',
#   'URL': 'https://ineuron.ai//course/C++-Coding-Interview-Preparation'},
#  {'Name': 'Data Structure and Algorithm Interview Preparation',
#   'URL': 'https://ineuron.ai//course/Data-Structure-and-Algorithm-Interview-Preparation'},
#  {'Name': 'HTML CSS Coding Interview Preparation',
#   'URL': 'https://ineuron.ai//course/HTML-CSS-Coding-Interview-Preparation'},
#  {'Name': 'Java Coding Interview Preparation',
#   'URL': 'https://ineuron.ai//course/Java-Coding-Interview-Preparation'},
#  {'Name': 'JavaScript Coding Interview Preparation',
#   'URL': 'https://ineuron.ai//course/JavaScript-Coding-Interview-Preparation'},
#  {'Name': 'Machine Learning Interview Preparation',
#   'URL': 'https://ineuron.ai//course/Machine-Learning-Interview-Preparation'},
#  {'Name': 'Pro Aptitude - C Language',
#   'URL': 'https://ineuron.ai//course/Pro-Aptitude---C-Language'},
#  {'Name': 'Pro Aptitude - C++',
#   'URL': 'https://ineuron.ai//course/Pro-Aptitude---C++'},
#  {'Name': 'Pro Aptitude - Data Structures and Algorithms',
#   'URL': 'https://ineuron.ai//course/Pro-Aptitude---Data-Structures-and-Algorithms'},
#  {'Name': 'Pro Aptitude - DBMS',
#   'URL': 'https://ineuron.ai//course/Pro-Aptitude---DBMS'},
#  {'Name': 'Pro Aptitude - Java',
#   'URL': 'https://ineuron.ai//course/Pro-Aptitude---Java'},
#  {'Name': 'Pro Aptitude - Operating Systems',
#   'URL': 'https://ineuron.ai//course/Pro-Aptitude---Operating-Systems'},
#  {'Name': 'Pro Aptitude - Python',
#   'URL': 'https://ineuron.ai//course/Pro-Aptitude---Python'},
#  {'Name': 'Pro Computer Networking',
#   'URL': 'https://ineuron.ai//course/Pro-Computer-Networking'},
#  {'Name': 'Pro C Programming Language',
#   'URL': 'https://ineuron.ai//course/Pro-C-Programming-Language'},
#  {'Name': 'Pro Max Interview Preparation Edition 1',
#   'URL': 'https://ineuron.ai//course/Pro-Max-Interview-Preparation-Edition-1'},
#  {'Name': 'Pro Max Interview Preparation Edition 2',
#   'URL': 'https://ineuron.ai//course/Pro-Max-Interview-Preparation-Edition-2'},
#  {'Name': 'Pro Max Interview Preparation Edition 3',
#   'URL': 'https://ineuron.ai//course/Pro-Max-Interview-Preparation-Edition-3'},
#  {'Name': 'Pro C++ Programming Language',
#   'URL': 'https://ineuron.ai//course/Pro-C++-Programming-Language'},
#  {'Name': 'Pro Database Management Systems',
#   'URL': 'https://ineuron.ai//course/Pro-Database-Management-Systems'},
#  {'Name': 'Pro Data Structure and Algorithms',
#   'URL': 'https://ineuron.ai//course/Pro-Data-Structure-and-Algorithms'},
#  {'Name': 'Pro Java Programming Language',
#   'URL': 'https://ineuron.ai//course/Pro-Java-Programming-Language'},
#  {'Name': 'Pro JavaScript Programming Language',
#   'URL': 'https://ineuron.ai//course/Pro-JavaScript-Programming-Language'},
#  {'Name': 'Pro Operating Systems',
#   'URL': 'https://ineuron.ai//course/Pro-Operating-Systems'},
#  {'Name': 'Pro Python Programming Language',
#   'URL': 'https://ineuron.ai//course/Pro-Python-Programming-Language'},
#  {'Name': 'Python Coding Interview Preparation',
#   'URL': 'https://ineuron.ai//course/Python-Coding-Interview-Preparation'},
#  {'Name': 'Aptitude Test Series',
#   'URL': 'https://ineuron.ai//course/Aptitude-Test-Series'},
#  {'Name': 'Mastering DSA with Python',
#   'URL': 'https://ineuron.ai//course/Mastering-DSA-with-Python'},
#  {'Name': 'Mastering DSA with Java',
#   'URL': 'https://ineuron.ai//course/Mastering-DSA-with-Java'},
#  {'Name': 'Mastering DSA with C++',
#   'URL': 'https://ineuron.ai//course/Mastering-DSA-with-C++'},
#  {'Name': 'Android P with Machine Learning Apps',
#   'URL': 'https://ineuron.ai//course/Android-P-with-Machine-Learning-Apps'},
#  {'Name': 'Full Stack Django and React',
#   'URL': 'https://ineuron.ai//course/Full-Stack-Django-and-React'},
#  {'Name': 'Full Stack Django with React',
#   'URL': 'https://ineuron.ai//course/Full-Stack-Django-with-React'},
#  {'Name': 'Complete Front End Web Developer Bootcamp',
#   'URL': 'https://ineuron.ai//course/Complete-Front-End-Web-Developer-Bootcamp'},
#  {'Name': 'Complete Backend Development with Nodejs',
#   'URL': 'https://ineuron.ai//course/Complete-Backend-Development-with-Nodejs'},
#  {'Name': 'Backend Development with Django-8 Projects',
#   'URL': 'https://ineuron.ai//course/Backend-Development-with-Django-8-Projects'},
#  {'Name': 'Complete Flutter Course - iOS Android Apps',
#   'URL': 'https://ineuron.ai//course/Complete-Flutter-Course---iOS-Android-Apps'},
#  {'Name': 'Dart Language', 'URL': 'https://ineuron.ai//course/Dart-Language'},
#  {'Name': 'Complete ReactJs Developer Bootcamp',
#   'URL': 'https://ineuron.ai//course/Complete-ReactJs-Developer-Bootcamp'},
#  {'Name': 'Complete Bootstrap4 - Build 5 Projects',
#   'URL': 'https://ineuron.ai//course/Complete-Bootstrap4---Build-5-Projects'},
#  {'Name': 'Android Chatapp with FireBase',
#   'URL': 'https://ineuron.ai//course/Android-Chatapp-with-FireBase'},
#  {'Name': 'C++ Bootcamp for Beginners',
#   'URL': 'https://ineuron.ai//course/C++-Bootcamp-for-Beginners'},
#  {'Name': 'Complete Angular Developer Bootcamp',
#   'URL': 'https://ineuron.ai//course/Complete-Angular-Developer-Bootcamp'},
#  {'Name': 'Crack the Tech Interviews',
#   'URL': 'https://ineuron.ai//course/Crack-the-Tech-Interviews'},
#  {'Name': 'Complete React Native Mobile App Developer',
#   'URL': 'https://ineuron.ai//course/Complete-React-Native-Mobile-App-Developer'},
#  {'Name': 'Complete VueJS Development',
#   'URL': 'https://ineuron.ai//course/Complete-VueJS-Development'},
#  {'Name': 'The Pro Backend Developer',
#   'URL': 'https://ineuron.ai//course/The-Pro-Backend-Developer'},
#  {'Name': 'AWS Architect for the Real World',
#   'URL': 'https://ineuron.ai//course/AWS-Architect-for-the-Real-World'},
#  {'Name': 'HTML and CSS for Web Development',
#   'URL': 'https://ineuron.ai//course/HTML-and-CSS-for-Web-Development'},
#  {'Name': 'JavaScript Fundamentals',
#   'URL': 'https://ineuron.ai//course/JavaScript-Fundamentals'},
#  {'Name': 'HTML and CSS', 'URL': 'https://ineuron.ai//course/HTML-and-CSS'},
#  {'Name': 'Ethical Hacking & Penetration Testing',
#   'URL': 'https://ineuron.ai//course/Ethical-Hacking-&-Penetration-Testing'},
#  {'Name': 'Crack the Tech Interview',
#   'URL': 'https://ineuron.ai//course/Crack-the-Tech-Interview'},
#  {'Name': 'Write quicker HTML5 and CSS 3; productivity hacks with emmet4',
#   'URL': 'https://ineuron.ai//course/Write-quicker-HTML5-and-CSS-3;-productivity-hacks-with-emmet4'},
#  {'Name': 'The Complete Front End Web Developer Bootcamp',
#   'URL': 'https://ineuron.ai//course/The-Complete-Front-End-Web-Developer-Bootcamp'},
#  {'Name': 'Machine Learning and Data Science Bootcamp',
#   'URL': 'https://ineuron.ai//course/Machine-Learning-and-Data-Science-Bootcamp'},
#  {'Name': 'Publishing Custom Cocoapads',
#   'URL': 'https://ineuron.ai//course/Publishing-Custom-Cocoapads'},
#  {'Name': 'Build an Ecommerce with ReactJS',
#   'URL': 'https://ineuron.ai//course/Build-an-Ecommerce-with-ReactJS'},
#  {'Name': 'Python3 Scratch To Pro',
#   'URL': 'https://ineuron.ai//course/Python3-Scratch-To-Pro'},
#  {'Name': 'ReactJS Crash Course',
#   'URL': 'https://ineuron.ai//course/ReactJS-Crash-Course'},
#  {'Name': 'Angular Crash Course',
#   'URL': 'https://ineuron.ai//course/Angular-Crash-Course'},
#  {'Name': 'Python Crash Course by Hitesh',
#   'URL': 'https://ineuron.ai//course/Python-Crash-Course-by-Hitesh'},
#  {'Name': 'Stripe with React and Node Crash Course',
#   'URL': 'https://ineuron.ai//course/Stripe-with-React-and-Node-Crash-Course'},
#  {'Name': 'Materialize CSS Crash Course',
#   'URL': 'https://ineuron.ai//course/Materialize-CSS-Crash-Course'},
#  {'Name': 'VueJS Crash Course',
#   'URL': 'https://ineuron.ai//course/VueJS-Crash-Course'},
#  {'Name': 'Graph QL Crash Course',
#   'URL': 'https://ineuron.ai//course/Graph-QL-Crash-Course'},
#  {'Name': 'AWS Serverless',
#   'URL': 'https://ineuron.ai//course/AWS-Serverless'},
#  {'Name': 'Fastify Crash Course',
#   'URL': 'https://ineuron.ai//course/Fastify-Crash-Course'},
#  {'Name': 'Socket io Crash Course',
#   'URL': 'https://ineuron.ai//course/Socket-io-Crash-Course'},
#  {'Name': 'NextJS Full stack crash course',
#   'URL': 'https://ineuron.ai//course/NextJS-Full-stack-crash-course'},
#  {'Name': 'DSA for FAANG preparation with Python and JavaScript',
#   'URL': 'https://ineuron.ai//course/DSA-for-FAANG-preparation-with-Python-and-JavaScript'},
#  {'Name': 'DP 900 Microsoft Azure Data Fundamentals',
#   'URL': 'https://ineuron.ai//course/DP-900-Microsoft-Azure-Data-Fundamentals'},
#  {'Name': 'AWS Big Data Analytics',
#   'URL': 'https://ineuron.ai//course/AWS-Big-Data-Analytics'},
#  {'Name': 'Auto Sklearn and Auto TimeSeries',
#   'URL': 'https://ineuron.ai//course/Auto-Sklearn-and-Auto-TimeSeries'},
#  {'Name': 'Blockchain Foundations',
#   'URL': 'https://ineuron.ai//course/Blockchain-Foundations'},
#  {'Name': 'Angular JS Course',
#   'URL': 'https://ineuron.ai//course/Angular-JS-Course'},
#  {'Name': 'Snowflake Advanced',
#   'URL': 'https://ineuron.ai//course/Snowflake-Advanced'},
#  {'Name': 'APIGEE', 'URL': 'https://ineuron.ai//course/APIGEE'},
#  {'Name': 'Yolo X and Yolo R',
#   'URL': 'https://ineuron.ai//course/Yolo-X-and-Yolo-R'},
#  {'Name': 'SAS Programming',
#   'URL': 'https://ineuron.ai//course/SAS-Programming'},
#  {'Name': 'Job Guaranteed Big Data Bootcamp',
#   'URL': 'https://ineuron.ai//course/Job-Guaranteed-Big-Data-Bootcamp'},
#  {'Name': 'Mulesoft', 'URL': 'https://ineuron.ai//course/Mulesoft'},
#  {'Name': 'IOT', 'URL': 'https://ineuron.ai//course/IOT'},
#  {'Name': 'Full Stack Data Analytics Tech Neuron',
#   'URL': 'https://ineuron.ai//course/Full-Stack-Data-Analytics-Tech-Neuron'},
#  {'Name': 'Full Stack Blockchain Development Tech Neuron',
#   'URL': 'https://ineuron.ai//course/Full-Stack-Blockchain-Development-Tech-Neuron'},
#  {'Name': 'Youtube Mastery Course in Hindi Tech Neuron',
#   'URL': 'https://ineuron.ai//course/Youtube-Mastery-Course-in-Hindi-Tech-Neuron'},
#  {'Name': 'Job Ready Automation Tester with JavaScript Tech Neuron',
#   'URL': 'https://ineuron.ai//course/Job-Ready-Automation-Tester-with-JavaScript-Tech-Neuron'},
#  {'Name': 'System Design with Design Patterns Tech Neuron',
#   'URL': 'https://ineuron.ai//course/System-Design-with-Design-Patterns-Tech-Neuron'},
#  {'Name': 'Cyber Security Masters Tech Neuron',
#   'URL': 'https://ineuron.ai//course/Cyber-Security-Masters-Tech-Neuron'},
#  {'Name': 'Digital Marketing Bootcamp in Hindi Tech Neuron',
#   'URL': 'https://ineuron.ai//course/Digital-Marketing-Bootcamp-in-Hindi-Tech-Neuron'},
#  {'Name': 'A Job Ready Bootcamp in  C++, DSA and IOT Tech Neuron',
#   'URL': 'https://ineuron.ai//course/A-Job-Ready-Bootcamp-in--C++,-DSA-and-IOT-Tech-Neuron'},
#  {'Name': 'Enterprise Java with Spring Boot Tech Neuron',
#   'URL': 'https://ineuron.ai//course/Enterprise-Java-with-Spring-Boot-Tech-Neuron'},
#  {'Name': 'Data Engineering with Google Cloud',
#   'URL': 'https://ineuron.ai//course/Data-Engineering-with-Google-Cloud'},
#  {'Name': 'Explainable AI',
#   'URL': 'https://ineuron.ai//course/Explainable-AI'},
#  {'Name': 'Full Stack Blockchain Development',
#   'URL': 'https://ineuron.ai//course/Full-Stack-Blockchain-Development'},
#  {'Name': 'JavaScript Marathon',
#   'URL': 'https://ineuron.ai//course/JavaScript-Marathon'},
#  {'Name': 'AIOPS Course', 'URL': 'https://ineuron.ai//course/AIOPS-Course'},
#  {'Name': 'C language for Absolute Beginners',
#   'URL': 'https://ineuron.ai//course/C-language-for-Absolute-Beginners'},
#  {'Name': 'MSBI', 'URL': 'https://ineuron.ai//course/MSBI'},
#  {'Name': 'Web Automation Foundations',
#   'URL': 'https://ineuron.ai//course/Web-Automation-Foundations'},
#  {'Name': 'Digital Marketing and Youtube Niche Foundations',
#   'URL': 'https://ineuron.ai//course/Digital-Marketing-and-Youtube-Niche-Foundations'},
#  {'Name': 'Java Foundations',
#   'URL': 'https://ineuron.ai//course/Java-Foundations'},
#  {'Name': 'NLP Foundations',
#   'URL': 'https://ineuron.ai//course/NLP-Foundations'},
#  {'Name': 'SQL Foundations',
#   'URL': 'https://ineuron.ai//course/SQL-Foundations'},
#  {'Name': 'ML and DL Foundations',
#   'URL': 'https://ineuron.ai//course/ML-and-DL-Foundations'},
#  {'Name': 'Scala', 'URL': 'https://ineuron.ai//course/Scala'},
#  {'Name': 'Manual Testing Foundations',
#   'URL': 'https://ineuron.ai//course/Manual-Testing-Foundations'},
#  {'Name': 'Cyber Security Foundations',
#   'URL': 'https://ineuron.ai//course/Cyber-Security-Foundations'},
#  {'Name': 'Salesforce Developer',
#   'URL': 'https://ineuron.ai//course/Salesforce-Developer'},
#  {'Name': 'Golang', 'URL': 'https://ineuron.ai//course/Golang'},
#  {'Name': 'Tibco Business Works',
#   'URL': 'https://ineuron.ai//course/Tibco-Business-Works'},
#  {'Name': 'GCP Machine Learning Certification',
#   'URL': 'https://ineuron.ai//course/GCP-Machine-Learning-Certification'},
#  {'Name': 'System Design Foundations',
#   'URL': 'https://ineuron.ai//course/System-Design-Foundations'},
#  {'Name': 'Informatica Powercenter',
#   'URL': 'https://ineuron.ai//course/Informatica-Powercenter'},
#  {'Name': 'Talend', 'URL': 'https://ineuron.ai//course/Talend'},
#  {'Name': 'Machine Learning in R',
#   'URL': 'https://ineuron.ai//course/Machine-Learning-in-R'},
#  {'Name': 'Pro Live Classes',
#   'URL': 'https://ineuron.ai//course/Pro-Live-Classes'},
#  {'Name': 'MongoDB Course',
#   'URL': 'https://ineuron.ai//course/MongoDB-Course'},
#  {'Name': 'Spring Boot', 'URL': 'https://ineuron.ai//course/Spring-Boot'},
#  {'Name': 'System Design with Design Patterns',
#   'URL': 'https://ineuron.ai//course/System-Design-with-Design-Patterns'},
#  {'Name': 'Enterprise Java with Spring Boot',
#   'URL': 'https://ineuron.ai//course/Enterprise-Java-with-Spring-Boot'},
#  {'Name': 'Apache Atlas', 'URL': 'https://ineuron.ai//course/Apache-Atlas'},
#  {'Name': 'Apache Druid', 'URL': 'https://ineuron.ai//course/Apache-Druid'},
#  {'Name': 'Cyber Security Masters',
#   'URL': 'https://ineuron.ai//course/Cyber-Security-Masters'},
#  {'Name': 'Bash Scripting',
#   'URL': 'https://ineuron.ai//course/Bash-Scripting'},
#  {'Name': 'Deep Learning Foundations',
#   'URL': 'https://ineuron.ai//course/Deep-Learning-Foundations'},
#  {'Name': 'Data Analytics Bootcamp',
#   'URL': 'https://ineuron.ai//course/Data-Analytics-Bootcamp'},
#  {'Name': 'MERN Stack Bootcamp',
#   'URL': 'https://ineuron.ai//course/MERN-Stack-Bootcamp'},
#  {'Name': 'Certified Ethical Hacker Bootcamp',
#   'URL': 'https://ineuron.ai//course/Certified-Ethical-Hacker-Bootcamp'},
#  {'Name': 'Latex', 'URL': 'https://ineuron.ai//course/Latex'},
#  {'Name': 'Julia Programming',
#   'URL': 'https://ineuron.ai//course/Julia-Programming'},
#  {'Name': 'Matlab Basic to Advance',
#   'URL': 'https://ineuron.ai//course/Matlab-Basic-to-Advance'},
#  {'Name': 'Salesforce Administrator',
#   'URL': 'https://ineuron.ai//course/Salesforce-Administrator'},
#  {'Name': 'Full Stack Data Science Bootcamp',
#   'URL': 'https://ineuron.ai//course/Full-Stack-Data-Science-Bootcamp'},
#  {'Name': 'AWS Data Engineering',
#   'URL': 'https://ineuron.ai//course/AWS-Data-Engineering'},
#  {'Name': 'Big Data Foundations',
#   'URL': 'https://ineuron.ai//course/Big-Data-Foundations'},
#  {'Name': 'Reasoning Live Class',
#   'URL': 'https://ineuron.ai//course/Reasoning-Live-Class'},
#  {'Name': 'Spark AR Live Class',
#   'URL': 'https://ineuron.ai//course/Spark-AR-Live-Class'},
#  {'Name': 'Power BI Foundations',
#   'URL': 'https://ineuron.ai//course/Power-BI-Foundations'},
#  {'Name': 'Foundations of English Language',
#   'URL': 'https://ineuron.ai//course/Foundations-of-English-Language'},
#  {'Name': 'Android Programming with Machine Learning Apps',
#   'URL': 'https://ineuron.ai//course/Android-Programming-with-Machine-Learning-Apps'},
#  {'Name': 'Pro Backend Developer',
#   'URL': 'https://ineuron.ai//course/Pro-Backend-Developer'},
#  {'Name': 'Android Chat app with FireBase',
#   'URL': 'https://ineuron.ai//course/Android-Chat-app-with-FireBase'},
#  {'Name': 'AWS Architect for Real World',
#   'URL': 'https://ineuron.ai//course/AWS-Architect-for-Real-World'},
#  {'Name': 'Complete ReactJS Developer Bootcamp',
#   'URL': 'https://ineuron.ai//course/Complete-ReactJS-Developer-Bootcamp'},
#  {'Name': 'Complete Bootstrap - 5 Projects',
#   'URL': 'https://ineuron.ai//course/Complete-Bootstrap---5-Projects'},
#  {'Name': 'Django Course', 'URL': 'https://ineuron.ai//course/Django-Course'},
#  {'Name': 'Back-end development with Django-8 Projects',
#   'URL': 'https://ineuron.ai//course/Back-end-development-with-Django-8-Projects'},
#  {'Name': 'React Native', 'URL': 'https://ineuron.ai//course/React-Native'},
#  {'Name': 'Java Bootcamp', 'URL': 'https://ineuron.ai//course/Java-Bootcamp'},
#  {'Name': 'Kotlin', 'URL': 'https://ineuron.ai//course/Kotlin'},
#  {'Name': 'Vuejs', 'URL': 'https://ineuron.ai//course/Vuejs'},
#  {'Name': 'Git and GitHub',
#   'URL': 'https://ineuron.ai//course/Git-and-GitHub'},
#  {'Name': 'Docker Course', 'URL': 'https://ineuron.ai//course/Docker-Course'},
#  {'Name': 'MySQL', 'URL': 'https://ineuron.ai//course/MySQL'},
#  {'Name': 'Dart Programming',
#   'URL': 'https://ineuron.ai//course/Dart-Programming'},
#  {'Name': 'Flutter', 'URL': 'https://ineuron.ai//course/Flutter'},
#  {'Name': 'C++ Bootcamp', 'URL': 'https://ineuron.ai//course/C++-Bootcamp'},
#  {'Name': 'Tableau Course',
#   'URL': 'https://ineuron.ai//course/Tableau-Course'},
#  {'Name': 'Power BI Course',
#   'URL': 'https://ineuron.ai//course/Power-BI-Course'},
#  {'Name': 'Alteryx Course',
#   'URL': 'https://ineuron.ai//course/Alteryx-Course'},
#  {'Name': 'C Programming', 'URL': 'https://ineuron.ai//course/C-Programming'},
#  {'Name': 'FastAPI', 'URL': 'https://ineuron.ai//course/FastAPI'},
#  {'Name': 'Career Counselling',
#   'URL': 'https://ineuron.ai//course/Career-Counselling'},
#  {'Name': 'Power Automate',
#   'URL': 'https://ineuron.ai//course/Power-Automate'},
#  {'Name': 'R Shiny', 'URL': 'https://ineuron.ai//course/R-Shiny'},
#  {'Name': 'ELK Stack', 'URL': 'https://ineuron.ai//course/ELK-Stack'},
#  {'Name': 'DOMO BI', 'URL': 'https://ineuron.ai//course/DOMO-BI'},
#  {'Name': 'Stored Procedures in SQL',
#   'URL': 'https://ineuron.ai//course/Stored-Procedures-in-SQL'},
#  {'Name': 'Fivetran', 'URL': 'https://ineuron.ai//course/Fivetran'},
#  {'Name': 'Data Warehouse',
#   'URL': 'https://ineuron.ai//course/Data-Warehouse'},
#  {'Name': 'Azure Synapse', 'URL': 'https://ineuron.ai//course/Azure-Synapse'},
#  {'Name': 'Azure Databricks',
#   'URL': 'https://ineuron.ai//course/Azure-Databricks'},
#  {'Name': 'Azure Data Factory',
#   'URL': 'https://ineuron.ai//course/Azure-Data-Factory'},
#  {'Name': 'Azure Data Engineering',
#   'URL': 'https://ineuron.ai//course/Azure-Data-Engineering'},
#  {'Name': 'AWS Interview Preparation',
#   'URL': 'https://ineuron.ai//course/AWS-Interview-Preparation'},
#  {'Name': 'DBT', 'URL': 'https://ineuron.ai//course/DBT'},
#  {'Name': 'SQL Server Integration Services',
#   'URL': 'https://ineuron.ai//course/SQL-Server-Integration-Services'},
#  {'Name': 'Tech Awareness',
#   'URL': 'https://ineuron.ai//course/Tech-Awareness'},
#  {'Name': 'Blockchain for Beginners',
#   'URL': 'https://ineuron.ai//course/Blockchain-for-Beginners'},
#  {'Name': 'Node JS Foundation',
#   'URL': 'https://ineuron.ai//course/Node-JS-Foundation'},
#  {'Name': 'AIOPS Live Projects',
#   'URL': 'https://ineuron.ai//course/AIOPS-Live-Projects'},
#  {'Name': 'PL SQL', 'URL': 'https://ineuron.ai//course/PL-SQL'},
#  {'Name': 'Airflow', 'URL': 'https://ineuron.ai//course/Airflow'},
#  {'Name': 'Alteryx', 'URL': 'https://ineuron.ai//course/Alteryx'},
#  {'Name': 'RPA Foundation',
#   'URL': 'https://ineuron.ai//course/RPA-Foundation'},
#  {'Name': 'Marketing Mix Modelling',
#   'URL': 'https://ineuron.ai//course/Marketing-Mix-Modelling'},
#  {'Name': 'Graph ML', 'URL': 'https://ineuron.ai//course/Graph-ML'},
#  {'Name': 'Complete Backend development with Nodejs',
#   'URL': 'https://ineuron.ai//course/Complete-Backend-development-with-Nodejs'},
#  {'Name': 'DSA with Python',
#   'URL': 'https://ineuron.ai//course/DSA-with-Python'},
#  {'Name': 'DSA with C++', 'URL': 'https://ineuron.ai//course/DSA-with-C++'},
#  {'Name': 'DSA with Java', 'URL': 'https://ineuron.ai//course/DSA-with-Java'},
#  {'Name': 'Email Marketing',
#   'URL': 'https://ineuron.ai//course/Email-Marketing'},
#  {'Name': 'MLflow', 'URL': 'https://ineuron.ai//course/MLflow'},
#  {'Name': 'PostgreSQL', 'URL': 'https://ineuron.ai//course/PostgreSQL'},
#  {'Name': 'RPA - UiPath', 'URL': 'https://ineuron.ai//course/RPA---UiPath'},
#  {'Name': 'MS SQL Server and T-SQL',
#   'URL': 'https://ineuron.ai//course/MS-SQL-Server-and-T-SQL'},
#  {'Name': 'Snowflake Beginners',
#   'URL': 'https://ineuron.ai//course/Snowflake-Beginners'},
#  {'Name': 'Tibco Spotfire',
#   'URL': 'https://ineuron.ai//course/Tibco-Spotfire'},
#  {'Name': 'PyTorch Basics',
#   'URL': 'https://ineuron.ai//course/PyTorch-Basics'},
#  {'Name': 'Streamlit', 'URL': 'https://ineuron.ai//course/Streamlit'},
#  {'Name': 'Dask', 'URL': 'https://ineuron.ai//course/Dask'},
#  {'Name': 'AWS QuickSight',
#   'URL': 'https://ineuron.ai//course/AWS-QuickSight'},
#  {'Name': 'AWS Sagemaker', 'URL': 'https://ineuron.ai//course/AWS-Sagemaker'},
#  {'Name': 'Trifacta', 'URL': 'https://ineuron.ai//course/Trifacta'},
#  {'Name': 'System Design', 'URL': 'https://ineuron.ai//course/System-Design'},
#  {'Name': 'Mathematics for Machine Learning',
#   'URL': 'https://ineuron.ai//course/Mathematics-for-Machine-Learning'},
#  {'Name': 'Class 10th Chemistry',
#   'URL': 'https://ineuron.ai//course/Class-10th-Chemistry'},
#  {'Name': 'Class 9th Chemistry',
#   'URL': 'https://ineuron.ai//course/Class-9th-Chemistry'},
#  {'Name': 'Class 8th Chemistry',
#   'URL': 'https://ineuron.ai//course/Class-8th-Chemistry'},
#  {'Name': 'Class 6th Chemistry',
#   'URL': 'https://ineuron.ai//course/Class-6th-Chemistry'},
#  {'Name': 'Solidity Live Class',
#   'URL': 'https://ineuron.ai//course/Solidity-Live-Class'},
#  {'Name': 'MLOPS Live Class',
#   'URL': 'https://ineuron.ai//course/MLOPS-Live-Class'},
#  {'Name': 'SPARK Augmented Reality Live Class',
#   'URL': 'https://ineuron.ai//course/SPARK-Augmented-Reality-Live-Class'},
#  {'Name': 'Statistics Live Class',
#   'URL': 'https://ineuron.ai//course/Statistics-Live-Class'},
#  {'Name': 'Machine Learning Live Class',
#   'URL': 'https://ineuron.ai//course/Machine-Learning-Live-Class'},
#  {'Name': 'Linux Live Class',
#   'URL': 'https://ineuron.ai//course/Linux-Live-Class'},
#  {'Name': 'Drone Live Class',
#   'URL': 'https://ineuron.ai//course/Drone-Live-Class'},
#  {'Name': 'Data Structures and Algorithms Live Class',
#   'URL': 'https://ineuron.ai//course/Data-Structures-and-Algorithms-Live-Class'},
#  {'Name': 'Arduino Live Class',
#   'URL': 'https://ineuron.ai//course/Arduino-Live-Class'},
#  {'Name': 'Aptitude Live Class',
#   'URL': 'https://ineuron.ai//course/Aptitude-Live-Class'},
#  {'Name': 'Microsoft PowerApps',
#   'URL': 'https://ineuron.ai//course/Microsoft-PowerApps'},
#  {'Name': 'Advanced Web Development',
#   'URL': 'https://ineuron.ai//course/Advanced-Web-Development'},
#  {'Name': 'Robotics', 'URL': 'https://ineuron.ai//course/Robotics'},
#  {'Name': 'Artificial Intelligence for Kids',
#   'URL': 'https://ineuron.ai//course/Artificial-Intelligence-for-Kids'},
#  {'Name': 'Deep Learning for Kids',
#   'URL': 'https://ineuron.ai//course/Deep-Learning-for-Kids'},
#  {'Name': 'Image Processing',
#   'URL': 'https://ineuron.ai//course/Image-Processing'},
#  {'Name': 'Statistics using Python',
#   'URL': 'https://ineuron.ai//course/Statistics-using-Python'},
#  {'Name': 'Raspberry Pi', 'URL': 'https://ineuron.ai//course/Raspberry-Pi'},
#  {'Name': 'Fundamentals of Web Designing',
#   'URL': 'https://ineuron.ai//course/Fundamentals-of-Web-Designing'},
#  {'Name': 'Class 8th Math',
#   'URL': 'https://ineuron.ai//course/Class-8th-Math'},
#  {'Name': 'Class 7th Math',
#   'URL': 'https://ineuron.ai//course/Class-7th-Math'},
#  {'Name': 'Class 6th Math',
#   'URL': 'https://ineuron.ai//course/Class-6th-Math'},
#  {'Name': 'Class 9th Physics',
#   'URL': 'https://ineuron.ai//course/Class-9th-Physics'},
#  {'Name': 'Class 10th Physics',
#   'URL': 'https://ineuron.ai//course/Class-10th-Physics'},
#  {'Name': 'Class 8th Physics',
#   'URL': 'https://ineuron.ai//course/Class-8th-Physics'},
#  {'Name': 'Class 7th Physics',
#   'URL': 'https://ineuron.ai//course/Class-7th-Physics'},
#  {'Name': 'Class 6th Physics',
#   'URL': 'https://ineuron.ai//course/Class-6th-Physics'},
#  {'Name': 'Class 7th Biology',
#   'URL': 'https://ineuron.ai//course/Class-7th-Biology'},
#  {'Name': 'Class 10th Math',
#   'URL': 'https://ineuron.ai//course/Class-10th-Math'},
#  {'Name': 'Class 9th Math',
#   'URL': 'https://ineuron.ai//course/Class-9th-Math'},
#  {'Name': 'Class 8th Biology',
#   'URL': 'https://ineuron.ai//course/Class-8th-Biology'},
#  {'Name': 'Class 6th Biology',
#   'URL': 'https://ineuron.ai//course/Class-6th-Biology'},
#  {'Name': 'Class 10th Biology',
#   'URL': 'https://ineuron.ai//course/Class-10th-Biology'},
#  {'Name': 'Game Development using Unity',
#   'URL': 'https://ineuron.ai//course/Game-Development-using-Unity'},
#  {'Name': 'Scratch Programming for kids',
#   'URL': 'https://ineuron.ai//course/Scratch-Programming-for-kids'},
#  {'Name': 'Interactive Visualization using Seaborn',
#   'URL': 'https://ineuron.ai//course/Interactive-Visualization-using-Seaborn'},
#  {'Name': 'OpenCV using Python',
#   'URL': 'https://ineuron.ai//course/OpenCV-using-Python'},
#  {'Name': 'Mathematics using Python',
#   'URL': 'https://ineuron.ai//course/Mathematics-using-Python'},
#  {'Name': 'Data Analysis Using Python',
#   'URL': 'https://ineuron.ai//course/Data-Analysis-Using-Python'},
#  {'Name': 'UI Designing using Figma',
#   'URL': 'https://ineuron.ai//course/UI-Designing-using-Figma'},
#  {'Name': 'Getting started with Cloud',
#   'URL': 'https://ineuron.ai//course/Getting-started-with-Cloud'},
#  {'Name': 'Fundamentals of Database',
#   'URL': 'https://ineuron.ai//course/Fundamentals-of-Database'},
#  {'Name': 'Video editing with Adobe Premiere Pro',
#   'URL': 'https://ineuron.ai//course/Video-editing-with-Adobe-Premiere-Pro'},
#  {'Name': 'Numerical Computation with Python',
#   'URL': 'https://ineuron.ai//course/Numerical-Computation-with-Python'},
#  {'Name': 'Natural Language Processing',
#   'URL': 'https://ineuron.ai//course/Natural-Language-Processing'},
#  {'Name': 'Data Visualization using Matplotlib',
#   'URL': 'https://ineuron.ai//course/Data-Visualization-using-Matplotlib'},
#  {'Name': 'Data Processing using Dask',
#   'URL': 'https://ineuron.ai//course/Data-Processing-using-Dask'},
#  {'Name': 'Data Manipulation using Pandas',
#   'URL': 'https://ineuron.ai//course/Data-Manipulation-using-Pandas'},
#  {'Name': 'Character Recognition using Python',
#   'URL': 'https://ineuron.ai//course/Character-Recognition-using-Python'},
#  {'Name': 'Web Designing using Wordpress',
#   'URL': 'https://ineuron.ai//course/Web-Designing-using-Wordpress'},
#  {'Name': 'Vedic Math', 'URL': 'https://ineuron.ai//course/Vedic-Math'},
#  {'Name': 'Fundamentals of Game Development',
#   'URL': 'https://ineuron.ai//course/Fundamentals-of-Game-Development'},
#  {'Name': 'Fundamentals of Electronics',
#   'URL': 'https://ineuron.ai//course/Fundamentals-of-Electronics'},
#  {'Name': 'App Building Using Android',
#   'URL': 'https://ineuron.ai//course/App-Building-Using-Android'},
#  {'Name': 'Advanced Python',
#   'URL': 'https://ineuron.ai//course/Advanced-Python'},
#  {'Name': 'Building Chatbot using Google DialogFlow',
#   'URL': 'https://ineuron.ai//course/Building-Chatbot-using-Google-DialogFlow'},
#  {'Name': 'Programming in Python',
#   'URL': 'https://ineuron.ai//course/Programming-in-Python'},
#  {'Name': 'Graphics Design with PhotoShop',
#   'URL': 'https://ineuron.ai//course/Graphics-Design-with-PhotoShop'},
#  {'Name': 'Basics of Computer Education',
#   'URL': 'https://ineuron.ai//course/Basics-of-Computer-Education'},
#  {'Name': 'Class 9th Biology',
#   'URL': 'https://ineuron.ai//course/Class-9th-Biology'},
#  {'Name': 'Jenkins', 'URL': 'https://ineuron.ai//course/Jenkins'},
#  {'Name': 'ParlAI Chatbot',
#   'URL': 'https://ineuron.ai//course/ParlAI-Chatbot'},
#  {'Name': 'Qlik Sense', 'URL': 'https://ineuron.ai//course/Qlik-Sense'},
#  {'Name': 'ONNX', 'URL': 'https://ineuron.ai//course/ONNX'},
#  {'Name': 'Solidity', 'URL': 'https://ineuron.ai//course/Solidity'},
#  {'Name': 'Mega Project Foundation',
#   'URL': 'https://ineuron.ai//course/Mega-Project-Foundation'},
#  {'Name': 'Data Science Masters',
#   'URL': 'https://ineuron.ai//course/Data-Science-Masters'},
#  {'Name': 'Angular', 'URL': 'https://ineuron.ai//course/Angular'},
#  {'Name': 'DART', 'URL': 'https://ineuron.ai//course/DART'},
#  {'Name': 'JAX', 'URL': 'https://ineuron.ai//course/JAX'},
#  {'Name': 'Recommender System',
#   'URL': 'https://ineuron.ai//course/Recommender-System'},
#  {'Name': 'Blockchain', 'URL': 'https://ineuron.ai//course/Blockchain'},
#  {'Name': 'DevOps Master', 'URL': 'https://ineuron.ai//course/DevOps-Master'},
#  {'Name': 'Machine Learning Masters',
#   'URL': 'https://ineuron.ai//course/Machine-Learning-Masters'},
#  {'Name': 'Interview ready DSA course in Python Level 2',
#   'URL': 'https://ineuron.ai//course/Interview-ready-DSA-course-in-Python-Level-2'},
#  {'Name': 'DLCV with NLP', 'URL': 'https://ineuron.ai//course/DLCV-with-NLP'},
#  {'Name': 'Big Data Masters Crash Course',
#   'URL': 'https://ineuron.ai//course/Big-Data-Masters-Crash-Course'},
#  {'Name': 'Business Analytics Crash Course',
#   'URL': 'https://ineuron.ai//course/Business-Analytics-Crash-Course'},
#  {'Name': 'Full Stack Data Science',
#   'URL': 'https://ineuron.ai//course/Full-Stack-Data-Science'},
#  {'Name': 'R Programming Projects',
#   'URL': 'https://ineuron.ai//course/R-Programming-Projects'},
#  {'Name': 'AIOps Interview Questions',
#   'URL': 'https://ineuron.ai//course/AIOps-Interview-Questions'},
#  {'Name': 'AIOps', 'URL': 'https://ineuron.ai//course/AIOps'},
#  {'Name': 'Django', 'URL': 'https://ineuron.ai//course/Django'},
#  {'Name': 'Python advance with projects',
#   'URL': 'https://ineuron.ai//course/Python-advance-with-projects'},
#  {'Name': 'NLP Interview Questions',
#   'URL': 'https://ineuron.ai//course/NLP-Interview-Questions'},
#  {'Name': 'Deep Learning ANN',
#   'URL': 'https://ineuron.ai//course/Deep-Learning-ANN'},
#  {'Name': 'Data Structures and Algorithms using python',
#   'URL': 'https://ineuron.ai//course/Data-Structures-and-Algorithms-using-python'},
#  {'Name': 'Introduction to AIOps',
#   'URL': 'https://ineuron.ai//course/Introduction-to-AIOps'},
#  {'Name': 'RASA', 'URL': 'https://ineuron.ai//course/RASA'},
#  {'Name': 'Data Science Project',
#   'URL': 'https://ineuron.ai//course/Data-Science-Project'},
#  {'Name': 'ML Interview Prepration',
#   'URL': 'https://ineuron.ai//course/ML-Interview-Prepration'},
#  {'Name': 'Power BI Projects',
#   'URL': 'https://ineuron.ai//course/Power-BI-Projects'},
#  {'Name': 'OpenCV Job Preparation',
#   'URL': 'https://ineuron.ai//course/OpenCV-Job-Preparation'},
#  {'Name': 'Ansible', 'URL': 'https://ineuron.ai//course/Ansible'},
#  {'Name': 'C++ Job Preparation',
#   'URL': 'https://ineuron.ai//course/C++-Job-Preparation'},
#  {'Name': 'Digital Marketing Projects',
#   'URL': 'https://ineuron.ai//course/Digital-Marketing-Projects'},
#  {'Name': 'Google Cloud Platform',
#   'URL': 'https://ineuron.ai//course/Google-Cloud-Platform'},
#  {'Name': 'Interview ready DSA course in Python',
#   'URL': 'https://ineuron.ai//course/Interview-ready-DSA-course-in-Python'},
#  {'Name': 'NLP Crash Course',
#   'URL': 'https://ineuron.ai//course/NLP-Crash-Course'},
#  {'Name': 'Machine Learning',
#   'URL': 'https://ineuron.ai//course/Machine-Learning'},
#  {'Name': 'Stats for Data Science',
#   'URL': 'https://ineuron.ai//course/Stats-for-Data-Science'},
#  {'Name': 'Python Crash Course',
#   'URL': 'https://ineuron.ai//course/Python-Crash-Course'},
#  {'Name': 'Python for Beginner',
#   'URL': 'https://ineuron.ai//course/Python-for-Beginner'},
#  {'Name': 'Machine Learning Projects',
#   'URL': 'https://ineuron.ai//course/Machine-Learning-Projects'},
#  {'Name': 'Data Structure and Algorithm Job Preparation',
#   'URL': 'https://ineuron.ai//course/Data-Structure-and-Algorithm-Job-Preparation'},
#  {'Name': 'NLP Projects', 'URL': 'https://ineuron.ai//course/NLP-Projects'},
#  {'Name': 'Data Structure and Algorithm Projects',
#   'URL': 'https://ineuron.ai//course/Data-Structure-and-Algorithm-Projects'},
#  {'Name': 'Advance Excel', 'URL': 'https://ineuron.ai//course/Advance-Excel'},
#  {'Name': 'OpenCV Projects',
#   'URL': 'https://ineuron.ai//course/OpenCV-Projects'},
#  {'Name': 'Computer Vision Projects',
#   'URL': 'https://ineuron.ai//course/Computer-Vision-Projects'},
#  {'Name': 'Computer Vision',
#   'URL': 'https://ineuron.ai//course/Computer-Vision'},
#  {'Name': 'GCP Interview', 'URL': 'https://ineuron.ai//course/GCP-Interview'},
#  {'Name': 'Azure Luis', 'URL': 'https://ineuron.ai//course/Azure-Luis'},
#  {'Name': "Full Stack Data Science Nov'21 Batch",
#   'URL': "https://ineuron.ai//course/Full-Stack-Data-Science-Nov'21-Batch"},
#  {'Name': 'MLDL', 'URL': 'https://ineuron.ai//course/MLDL'},
#  {'Name': 'Business Analytics',
#   'URL': 'https://ineuron.ai//course/Business-Analytics'},
#  {'Name': 'AI Operations', 'URL': 'https://ineuron.ai//course/AI-Operations'},
#  {'Name': 'AWS Cloud Master',
#   'URL': 'https://ineuron.ai//course/AWS-Cloud-Master'},
#  {'Name': 'Big Data Masters',
#   'URL': 'https://ineuron.ai//course/Big-Data-Masters'},
#  {'Name': '30 days Fast Track Data Science Interview Preparation',
#   'URL': 'https://ineuron.ai//course/30-days-Fast-Track-Data-Science-Interview-Preparation'},
#  {'Name': 'End to End Object Detection',
#   'URL': 'https://ineuron.ai//course/End-to-End-Object-Detection'},
#  {'Name': 'Class 10 Biology',
#   'URL': 'https://ineuron.ai//course/Class-10-Biology'},
#  {'Name': 'Class 10 Chemistry',
#   'URL': 'https://ineuron.ai//course/Class-10-Chemistry'},
#  {'Name': 'Class 10 Physics',
#   'URL': 'https://ineuron.ai//course/Class-10-Physics'},
#  {'Name': 'Class 10 Mathematics',
#   'URL': 'https://ineuron.ai//course/Class-10-Mathematics'},
#  {'Name': 'Mega Community',
#   'URL': 'https://ineuron.ai//course/Mega-Community'},
#  {'Name': 'Data Structure and Algorithms with competitive programming',
#   'URL': 'https://ineuron.ai//course/Data-Structure-and-Algorithms-with-competitive-programming'},
#  {'Name': 'MERN Stack Beginner to Advance with Internship',
#   'URL': 'https://ineuron.ai//course/MERN-Stack-Beginner-to-Advance-with-Internship'},
#  {'Name': 'Deep Learning With Computer Vision and Advanced NLP',
#   'URL': 'https://ineuron.ai//course/Deep-Learning-With-Computer-Vision-and-Advanced-NLP'},
#  {'Name': 'Business Analytics Masters with 3 month Internship',
#   'URL': 'https://ineuron.ai//course/Business-Analytics-Masters-with-3-month-Internship'},
#  {'Name': 'Machine Learning And Deep Learning Masters',
#   'URL': 'https://ineuron.ai//course/Machine-Learning-And-Deep-Learning-Masters'},
#  {'Name': "Full Stack Data Science Feb'21 Batch",
#   'URL': "https://ineuron.ai//course/Full-Stack-Data-Science-Feb'21-Batch"},
#  {'Name': 'Digital Marketing Foundation',
#   'URL': 'https://ineuron.ai//course/Digital-Marketing-Foundation'},
#  {'Name': 'Live Virtual Interview',
#   'URL': 'https://ineuron.ai//course/Live-Virtual-Interview'},
#  {'Name': 'Chatbot using Rasa NLU',
#   'URL': 'https://ineuron.ai//course/Chatbot-using-Rasa-NLU'},
#  {'Name': 'Chatbot using Azure Luis',
#   'URL': 'https://ineuron.ai//course/Chatbot-using-Azure-Luis'},
#  {'Name': 'Chatbot Using Google Dialogflow',
#   'URL': 'https://ineuron.ai//course/Chatbot-Using-Google-Dialogflow'},
#  {'Name': 'Amazon Lex Chatbot',
#   'URL': 'https://ineuron.ai//course/Amazon-Lex-Chatbot'},
#  {'Name': 'Stats for Beginners',
#   'URL': 'https://ineuron.ai//course/Stats-for-Beginners'},
#  {'Name': 'Machine Learning Foundation',
#   'URL': 'https://ineuron.ai//course/Machine-Learning-Foundation'},
#  {'Name': 'Deep Learning Foundation',
#   'URL': 'https://ineuron.ai//course/Deep-Learning-Foundation'},
#  {'Name': 'React JS', 'URL': 'https://ineuron.ai//course/React-JS'},
#  {'Name': 'Angular JS', 'URL': 'https://ineuron.ai//course/Angular-JS'},
#  {'Name': 'Node JS', 'URL': 'https://ineuron.ai//course/Node-JS'},
#  {'Name': 'DSAR', 'URL': 'https://ineuron.ai//course/DSAR'},
#  {'Name': 'Tableau Foundation',
#   'URL': 'https://ineuron.ai//course/Tableau-Foundation'},
#  {'Name': 'PowerBI Foundation',
#   'URL': 'https://ineuron.ai//course/PowerBI-Foundation'},
#  {'Name': 'DevOps Foundation',
#   'URL': 'https://ineuron.ai//course/DevOps-Foundation'},
#  {'Name': 'Data Structure and Algorithm Foundation',
#   'URL': 'https://ineuron.ai//course/Data-Structure-and-Algorithm-Foundation'},
#  {'Name': 'Tableau Job Preparation',
#   'URL': 'https://ineuron.ai//course/Tableau-Job-Preparation'},
#  {'Name': 'Artificial Neural Network',
#   'URL': 'https://ineuron.ai//course/Artificial-Neural-Network'},
#  {'Name': 'Computer Vision Crash Course',
#   'URL': 'https://ineuron.ai//course/Computer-Vision-Crash-Course'},
#  {'Name': 'AWS Crash Course',
#   'URL': 'https://ineuron.ai//course/AWS-Crash-Course'},
#  {'Name': 'Advance Computer Vision',
#   'URL': 'https://ineuron.ai//course/Advance-Computer-Vision'},
#  {'Name': 'AIOPS Crash Course',
#   'URL': 'https://ineuron.ai//course/AIOPS-Crash-Course'},
#  {'Name': 'SQL Projects', 'URL': 'https://ineuron.ai//course/SQL-Projects'},
#  {'Name': 'R Programming Job Preparation',
#   'URL': 'https://ineuron.ai//course/R-Programming-Job-Preparation'},
#  {'Name': 'AIOps Projects',
#   'URL': 'https://ineuron.ai//course/AIOps-Projects'},
#  {'Name': 'Mern Stack Projects',
#   'URL': 'https://ineuron.ai//course/Mern-Stack-Projects'},
#  {'Name': 'SQL Job Preparation',
#   'URL': 'https://ineuron.ai//course/SQL-Job-Preparation'},
#  {'Name': 'Tableau Projects',
#   'URL': 'https://ineuron.ai//course/Tableau-Projects'},
#  {'Name': 'GCP Projects', 'URL': 'https://ineuron.ai//course/GCP-Projects'},
#  {'Name': 'Kubernetes', 'URL': 'https://ineuron.ai//course/Kubernetes'},
#  {'Name': 'Google Dialogflow',
#   'URL': 'https://ineuron.ai//course/Google-Dialogflow'},
#  {'Name': 'Aptitude Test', 'URL': 'https://ineuron.ai//course/Aptitude-Test'},
#  {'Name': 'Azure Certification Road Map',
#   'URL': 'https://ineuron.ai//course/Azure-Certification-Road-Map'},
#  {'Name': 'Mern Stack', 'URL': 'https://ineuron.ai//course/Mern-Stack'},
#  {'Name': 'AWS', 'URL': 'https://ineuron.ai//course/AWS'},
#  {'Name': 'OpenCV', 'URL': 'https://ineuron.ai//course/OpenCV'},
#  {'Name': 'Statistics', 'URL': 'https://ineuron.ai//course/Statistics'},
#  {'Name': 'Azure Fundamentals',
#   'URL': 'https://ineuron.ai//course/Azure-Fundamentals'},
#  {'Name': 'Amazon Lex', 'URL': 'https://ineuron.ai//course/Amazon-Lex'},
#  {'Name': 'Docker', 'URL': 'https://ineuron.ai//course/Docker'},
#  {'Name': 'Complete Interview Preparation For Data Structure and Algorithm in Python',
#   'URL': 'https://ineuron.ai//course/Complete-Interview-Preparation-For-Data-Structure-and-Algorithm-in-Python'},
#  {'Name': 'Mern stack job preparation',
#   'URL': 'https://ineuron.ai//course/Mern-stack-job-preparation'},
#  {'Name': 'Azure Data scientist Associate DP100',
#   'URL': 'https://ineuron.ai//course/Azure-Data-scientist-Associate-DP100'},
#  {'Name': 'Digital Marketing',
#   'URL': 'https://ineuron.ai//course/Digital-Marketing'},
#  {'Name': 'GIT', 'URL': 'https://ineuron.ai//course/GIT'},
#  {'Name': 'Linux', 'URL': 'https://ineuron.ai//course/Linux'},
#  {'Name': 'R Programming', 'URL': 'https://ineuron.ai//course/R-Programming'},
#  {'Name': 'Complete DSA in Python',
#   'URL': 'https://ineuron.ai//course/Complete-DSA-in-Python'},
#  {'Name': 'Tableau Foundation Course',
#   'URL': 'https://ineuron.ai//course/Tableau-Foundation-Course'},
#  {'Name': 'Complete Excel Course',
#   'URL': 'https://ineuron.ai//course/Complete-Excel-Course'},
#  {'Name': 'Automatic Number Plate Recognition',
#   'URL': 'https://ineuron.ai//course/Automatic-Number-Plate-Recognition'},
#  {'Name': 'Build Modern ETL Data Pipeline using Informatica cloud',
#   'URL': 'https://ineuron.ai//course/Build-Modern-ETL-Data-Pipeline-using-Informatica-cloud'},
#  {'Name': 'Build ETL Data Pipeline on AWS EMR Cluster',
#   'URL': 'https://ineuron.ai//course/Build-ETL-Data-Pipeline-on-AWS-EMR-Cluster'},
#  {'Name': 'Create A Data Pipeline based on Messaging Using PySpark and Airflow',
#   'URL': 'https://ineuron.ai//course/Create-A-Data-Pipeline-based-on-Messaging-Using-PySpark-and-Airflow'},
#  {'Name': 'Hive Project to build a data warehouse for e-Commerce',
#   'URL': 'https://ineuron.ai//course/Hive-Project-to-build-a-data-warehouse-for-e-Commerce'},
#  {'Name': 'House Price Prediction',
#   'URL': 'https://ineuron.ai//course/House-Price-Prediction'},
#  {'Name': 'MLFlow Production Server Setup',
#   'URL': 'https://ineuron.ai//course/MLFlow-Production-Server-Setup'},
#  {'Name': 'Sensor Fault Prediction',
#   'URL': 'https://ineuron.ai//course/Sensor-Fault-Prediction'},
#  {'Name': 'Text Summarization',
#   'URL': 'https://ineuron.ai//course/Text-Summarization'},
#  {'Name': 'The Ultimate Guide To OpenAI GPT-3 & Fine Tune with Custom Data',
#   'URL': 'https://ineuron.ai//course/The-Ultimate-Guide-To-OpenAI-GPT-3-&-Fine-Tune-with-Custom-Data'},
#  {'Name': 'Industry Safety Detection using YOLO v7',
#   'URL': 'https://ineuron.ai//course/Industry-Safety-Detection-using-YOLO-v7'},
#  {'Name': 'Shipment Price Prediction',
#   'URL': 'https://ineuron.ai//course/Shipment-Price-Prediction'},
#  {'Name': 'Finance Complaint',
#   'URL': 'https://ineuron.ai//course/Finance-Complaint'},
#  {'Name': 'Deep Authenticator',
#   'URL': 'https://ineuron.ai//course/Deep-Authenticator'},
#  {'Name': 'Language Identification',
#   'URL': 'https://ineuron.ai//course/Language-Identification'},
#  {'Name': 'Sign Language Detection',
#   'URL': 'https://ineuron.ai//course/Sign-Language-Detection'},
#  {'Name': 'Text To Speech',
#   'URL': 'https://ineuron.ai//course/Text-To-Speech'},
# ...
#  {'Name': 'Image Processing',
#   'URL': 'https://ineuron.ai//course/Image-Processing'},
#  {'Name': 'Statistics using Python',
#   'URL': 'https://ineuron.ai//course/Statistics-using-Python'},
#  {'Name': 'Raspberry Pi', 'URL': 'https://ineuron.ai//course/Raspberry-Pi'},
#  {'Name': 'Fundamentals of Web Designing',
#   'URL': 'https://ineuron.ai//course/Fundamentals-of-Web-Designing'},
#  {'Name': 'Class 8th Math',
#   'URL': 'https://ineuron.ai//course/Class-8th-Math'},
#  {'Name': 'Class 7th Math',
#   'URL': 'https://ineuron.ai//course/Class-7th-Math'},
#  {'Name': 'Class 6th Math',
#   'URL': 'https://ineuron.ai//course/Class-6th-Math'},
#  {'Name': 'Class 9th Physics',
#   'URL': 'https://ineuron.ai//course/Class-9th-Physics'},
#  {'Name': 'Class 10th Physics',
#   'URL': 'https://ineuron.ai//course/Class-10th-Physics'},
#  {'Name': 'Class 8th Physics',
#   'URL': 'https://ineuron.ai//course/Class-8th-Physics'},
#  {'Name': 'Class 7th Physics',
#   'URL': 'https://ineuron.ai//course/Class-7th-Physics'},
#  {'Name': 'Class 6th Physics',
#   'URL': 'https://ineuron.ai//course/Class-6th-Physics'},
#  {'Name': 'Class 7th Biology',
#   'URL': 'https://ineuron.ai//course/Class-7th-Biology'},
#  {'Name': 'Class 10th Math',
#   'URL': 'https://ineuron.ai//course/Class-10th-Math'},
#  {'Name': 'Class 9th Math',
#   'URL': 'https://ineuron.ai//course/Class-9th-Math'},
#  {'Name': 'Class 8th Biology',
#   'URL': 'https://ineuron.ai//course/Class-8th-Biology'},
#  {'Name': 'Class 6th Biology',
#   'URL': 'https://ineuron.ai//course/Class-6th-Biology'},
#  {'Name': 'Class 10th Biology',
#   'URL': 'https://ineuron.ai//course/Class-10th-Biology'},
#  {'Name': 'Game Development using Unity',
#   'URL': 'https://ineuron.ai//course/Game-Development-using-Unity'},
#  {'Name': 'Scratch Programming for kids',
#   'URL': 'https://ineuron.ai//course/Scratch-Programming-for-kids'},
#  {'Name': 'Interactive Visualization using Seaborn',
#   'URL': 'https://ineuron.ai//course/Interactive-Visualization-using-Seaborn'},
#  {'Name': 'OpenCV using Python',
#   'URL': 'https://ineuron.ai//course/OpenCV-using-Python'},
#  {'Name': 'Mathematics using Python',
#   'URL': 'https://ineuron.ai//course/Mathematics-using-Python'},
#  {'Name': 'Data Analysis Using Python',
#   'URL': 'https://ineuron.ai//course/Data-Analysis-Using-Python'},
#  {'Name': 'UI Designing using Figma',
#   'URL': 'https://ineuron.ai//course/UI-Designing-using-Figma'},
#  {'Name': 'Getting started with Cloud',
#   'URL': 'https://ineuron.ai//course/Getting-started-with-Cloud'},
#  {'Name': 'Fundamentals of Database',
#   'URL': 'https://ineuron.ai//course/Fundamentals-of-Database'},
#  {'Name': 'Video editing with Adobe Premiere Pro',
#   'URL': 'https://ineuron.ai//course/Video-editing-with-Adobe-Premiere-Pro'},
#  {'Name': 'Numerical Computation with Python',
#   'URL': 'https://ineuron.ai//course/Numerical-Computation-with-Python'},
#  {'Name': 'Natural Language Processing',
#   'URL': 'https://ineuron.ai//course/Natural-Language-Processing'},
#  {'Name': 'Data Visualization using Matplotlib',
#   'URL': 'https://ineuron.ai//course/Data-Visualization-using-Matplotlib'},
#  {'Name': 'Data Processing using Dask',
#   'URL': 'https://ineuron.ai//course/Data-Processing-using-Dask'},
#  {'Name': 'Data Manipulation using Pandas',
#   'URL': 'https://ineuron.ai//course/Data-Manipulation-using-Pandas'},
#  {'Name': 'Character Recognition using Python',
#   'URL': 'https://ineuron.ai//course/Character-Recognition-using-Python'},
#  {'Name': 'Web Designing using Wordpress',
#   'URL': 'https://ineuron.ai//course/Web-Designing-using-Wordpress'},
#  {'Name': 'Vedic Math', 'URL': 'https://ineuron.ai//course/Vedic-Math'},
#  {'Name': 'Fundamentals of Game Development',
#   'URL': 'https://ineuron.ai//course/Fundamentals-of-Game-Development'},
#  {'Name': 'Fundamentals of Electronics',
#   'URL': 'https://ineuron.ai//course/Fundamentals-of-Electronics'},
#  {'Name': 'App Building Using Android',
#   'URL': 'https://ineuron.ai//course/App-Building-Using-Android'},
#  {'Name': 'Advanced Python',
#   'URL': 'https://ineuron.ai//course/Advanced-Python'},
#  {'Name': 'Building Chatbot using Google DialogFlow',
#   'URL': 'https://ineuron.ai//course/Building-Chatbot-using-Google-DialogFlow'},
#  {'Name': 'Programming in Python',
#   'URL': 'https://ineuron.ai//course/Programming-in-Python'},
#  {'Name': 'Graphics Design with PhotoShop',
#   'URL': 'https://ineuron.ai//course/Graphics-Design-with-PhotoShop'},
#  {'Name': 'Basics of Computer Education',
#   'URL': 'https://ineuron.ai//course/Basics-of-Computer-Education'},
#  {'Name': 'Class 9th Biology',
#   'URL': 'https://ineuron.ai//course/Class-9th-Biology'},
#  {'Name': 'Jenkins', 'URL': 'https://ineuron.ai//course/Jenkins'},
#  {'Name': 'ParlAI Chatbot',
#   'URL': 'https://ineuron.ai//course/ParlAI-Chatbot'},
#  {'Name': 'Qlik Sense', 'URL': 'https://ineuron.ai//course/Qlik-Sense'},
#  {'Name': 'ONNX', 'URL': 'https://ineuron.ai//course/ONNX'},
#  {'Name': 'Solidity', 'URL': 'https://ineuron.ai//course/Solidity'},
#  {'Name': 'Mega Project Foundation',
#   'URL': 'https://ineuron.ai//course/Mega-Project-Foundation'},
#  {'Name': 'Data Science Masters',
#   'URL': 'https://ineuron.ai//course/Data-Science-Masters'},
#  {'Name': 'Angular', 'URL': 'https://ineuron.ai//course/Angular'},
#  {'Name': 'DART', 'URL': 'https://ineuron.ai//course/DART'},
#  {'Name': 'JAX', 'URL': 'https://ineuron.ai//course/JAX'},
#  {'Name': 'Recommender System',
#   'URL': 'https://ineuron.ai//course/Recommender-System'},
#  {'Name': 'Blockchain', 'URL': 'https://ineuron.ai//course/Blockchain'},
#  {'Name': 'DevOps Master', 'URL': 'https://ineuron.ai//course/DevOps-Master'},
#  {'Name': 'Machine Learning Masters',
#   'URL': 'https://ineuron.ai//course/Machine-Learning-Masters'},
#  {'Name': 'Interview ready DSA course in Python Level 2',
#   'URL': 'https://ineuron.ai//course/Interview-ready-DSA-course-in-Python-Level-2'},
#  {'Name': 'DLCV with NLP', 'URL': 'https://ineuron.ai//course/DLCV-with-NLP'},
#  {'Name': 'Big Data Masters Crash Course',
#   'URL': 'https://ineuron.ai//course/Big-Data-Masters-Crash-Course'},
#  {'Name': 'Business Analytics Crash Course',
#   'URL': 'https://ineuron.ai//course/Business-Analytics-Crash-Course'},
#  {'Name': 'Full Stack Data Science',
#   'URL': 'https://ineuron.ai//course/Full-Stack-Data-Science'},
#  {'Name': 'R Programming Projects',
#   'URL': 'https://ineuron.ai//course/R-Programming-Projects'},
#  {'Name': 'AIOps Interview Questions',
#   'URL': 'https://ineuron.ai//course/AIOps-Interview-Questions'},
#  {'Name': 'AIOps', 'URL': 'https://ineuron.ai//course/AIOps'},
#  {'Name': 'Django', 'URL': 'https://ineuron.ai//course/Django'},
#  {'Name': 'Python advance with projects',
#   'URL': 'https://ineuron.ai//course/Python-advance-with-projects'},
#  {'Name': 'NLP Interview Questions',
#   'URL': 'https://ineuron.ai//course/NLP-Interview-Questions'},
#  {'Name': 'Deep Learning ANN',
#   'URL': 'https://ineuron.ai//course/Deep-Learning-ANN'},
#  {'Name': 'Data Structures and Algorithms using python',
#   'URL': 'https://ineuron.ai//course/Data-Structures-and-Algorithms-using-python'},
#  {'Name': 'Introduction to AIOps',
#   'URL': 'https://ineuron.ai//course/Introduction-to-AIOps'},
#  {'Name': 'RASA', 'URL': 'https://ineuron.ai//course/RASA'},
#  {'Name': 'Data Science Project',
#   'URL': 'https://ineuron.ai//course/Data-Science-Project'},
#  {'Name': 'ML Interview Prepration',
#   'URL': 'https://ineuron.ai//course/ML-Interview-Prepration'},
#  {'Name': 'Power BI Projects',
#   'URL': 'https://ineuron.ai//course/Power-BI-Projects'},
#  {'Name': 'OpenCV Job Preparation',
#   'URL': 'https://ineuron.ai//course/OpenCV-Job-Preparation'},
#  {'Name': 'Ansible', 'URL': 'https://ineuron.ai//course/Ansible'},
#  {'Name': 'C++ Job Preparation',
#   'URL': 'https://ineuron.ai//course/C++-Job-Preparation'},
#  {'Name': 'Digital Marketing Projects',
#   'URL': 'https://ineuron.ai//course/Digital-Marketing-Projects'},
#  {'Name': 'Google Cloud Platform',
#   'URL': 'https://ineuron.ai//course/Google-Cloud-Platform'},
#  {'Name': 'Interview ready DSA course in Python',
#   'URL': 'https://ineuron.ai//course/Interview-ready-DSA-course-in-Python'},
#  {'Name': 'NLP Crash Course',
#   'URL': 'https://ineuron.ai//course/NLP-Crash-Course'},
#  {'Name': 'Machine Learning',
#   'URL': 'https://ineuron.ai//course/Machine-Learning'},
#  {'Name': 'Stats for Data Science',
#   'URL': 'https://ineuron.ai//course/Stats-for-Data-Science'},
#  {'Name': 'Python Crash Course',
#   'URL': 'https://ineuron.ai//course/Python-Crash-Course'},
#  {'Name': 'Python for Beginner',
#   'URL': 'https://ineuron.ai//course/Python-for-Beginner'},
#  {'Name': 'Machine Learning Projects',
#   'URL': 'https://ineuron.ai//course/Machine-Learning-Projects'},
#  {'Name': 'Data Structure and Algorithm Job Preparation',
#   'URL': 'https://ineuron.ai//course/Data-Structure-and-Algorithm-Job-Preparation'},
#  {'Name': 'NLP Projects', 'URL': 'https://ineuron.ai//course/NLP-Projects'},
#  {'Name': 'Data Structure and Algorithm Projects',
#   'URL': 'https://ineuron.ai//course/Data-Structure-and-Algorithm-Projects'},
#  {'Name': 'Advance Excel', 'URL': 'https://ineuron.ai//course/Advance-Excel'},
#  {'Name': 'OpenCV Projects',
#   'URL': 'https://ineuron.ai//course/OpenCV-Projects'},
#  {'Name': 'Computer Vision Projects',
#   'URL': 'https://ineuron.ai//course/Computer-Vision-Projects'},
#  {'Name': 'Computer Vision',
#   'URL': 'https://ineuron.ai//course/Computer-Vision'},
#  {'Name': 'GCP Interview', 'URL': 'https://ineuron.ai//course/GCP-Interview'},
#  {'Name': 'Azure Luis', 'URL': 'https://ineuron.ai//course/Azure-Luis'},
#  {'Name': "Full Stack Data Science Nov'21 Batch",
#   'URL': "https://ineuron.ai//course/Full-Stack-Data-Science-Nov'21-Batch"},
#  {'Name': 'MLDL', 'URL': 'https://ineuron.ai//course/MLDL'},
#  {'Name': 'Business Analytics',
#   'URL': 'https://ineuron.ai//course/Business-Analytics'},
#  {'Name': 'AI Operations', 'URL': 'https://ineuron.ai//course/AI-Operations'},
#  {'Name': 'AWS Cloud Master',
#   'URL': 'https://ineuron.ai//course/AWS-Cloud-Master'},
#  {'Name': 'Big Data Masters',
#   'URL': 'https://ineuron.ai//course/Big-Data-Masters'},
#  {'Name': '30 days Fast Track Data Science Interview Preparation',
#   'URL': 'https://ineuron.ai//course/30-days-Fast-Track-Data-Science-Interview-Preparation'},
#  {'Name': 'End to End Object Detection',
#   'URL': 'https://ineuron.ai//course/End-to-End-Object-Detection'},
#  {'Name': 'Class 10 Biology',
#   'URL': 'https://ineuron.ai//course/Class-10-Biology'},
#  {'Name': 'Class 10 Chemistry',
#   'URL': 'https://ineuron.ai//course/Class-10-Chemistry'},
#  {'Name': 'Class 10 Physics',
#   'URL': 'https://ineuron.ai//course/Class-10-Physics'},
#  {'Name': 'Class 10 Mathematics',
#   'URL': 'https://ineuron.ai//course/Class-10-Mathematics'},
#  {'Name': 'Mega Community',
#   'URL': 'https://ineuron.ai//course/Mega-Community'},
#  {'Name': 'Data Structure and Algorithms with competitive programming',
#   'URL': 'https://ineuron.ai//course/Data-Structure-and-Algorithms-with-competitive-programming'},
#  {'Name': 'MERN Stack Beginner to Advance with Internship',
#   'URL': 'https://ineuron.ai//course/MERN-Stack-Beginner-to-Advance-with-Internship'},
#  {'Name': 'Deep Learning With Computer Vision and Advanced NLP',
#   'URL': 'https://ineuron.ai//course/Deep-Learning-With-Computer-Vision-and-Advanced-NLP'},
#  {'Name': 'Business Analytics Masters with 3 month Internship',
#   'URL': 'https://ineuron.ai//course/Business-Analytics-Masters-with-3-month-Internship'},
#  {'Name': 'Machine Learning And Deep Learning Masters',
#   'URL': 'https://ineuron.ai//course/Machine-Learning-And-Deep-Learning-Masters'},
#  {'Name': "Full Stack Data Science Feb'21 Batch",
#   'URL': "https://ineuron.ai//course/Full-Stack-Data-Science-Feb'21-Batch"},
#  {'Name': 'Digital Marketing Foundation',
#   'URL': 'https://ineuron.ai//course/Digital-Marketing-Foundation'},
#  {'Name': 'Live Virtual Interview',
#   'URL': 'https://ineuron.ai//course/Live-Virtual-Interview'},
#  {'Name': 'Chatbot using Rasa NLU',
#   'URL': 'https://ineuron.ai//course/Chatbot-using-Rasa-NLU'},
#  {'Name': 'Chatbot using Azure Luis',
#   'URL': 'https://ineuron.ai//course/Chatbot-using-Azure-Luis'},
#  {'Name': 'Chatbot Using Google Dialogflow',
#   'URL': 'https://ineuron.ai//course/Chatbot-Using-Google-Dialogflow'},
#  {'Name': 'Amazon Lex Chatbot',
#   'URL': 'https://ineuron.ai//course/Amazon-Lex-Chatbot'},
#  {'Name': 'Stats for Beginners',
#   'URL': 'https://ineuron.ai//course/Stats-for-Beginners'},
#  {'Name': 'Machine Learning Foundation',
#   'URL': 'https://ineuron.ai//course/Machine-Learning-Foundation'},
#  {'Name': 'Deep Learning Foundation',
#   'URL': 'https://ineuron.ai//course/Deep-Learning-Foundation'},
#  {'Name': 'React JS', 'URL': 'https://ineuron.ai//course/React-JS'},
#  {'Name': 'Angular JS', 'URL': 'https://ineuron.ai//course/Angular-JS'},
#  {'Name': 'Node JS', 'URL': 'https://ineuron.ai//course/Node-JS'},
#  {'Name': 'DSAR', 'URL': 'https://ineuron.ai//course/DSAR'},
#  {'Name': 'Tableau Foundation',
#   'URL': 'https://ineuron.ai//course/Tableau-Foundation'},
#  {'Name': 'PowerBI Foundation',
#   'URL': 'https://ineuron.ai//course/PowerBI-Foundation'},
#  {'Name': 'DevOps Foundation',
#   'URL': 'https://ineuron.ai//course/DevOps-Foundation'},
#  {'Name': 'Data Structure and Algorithm Foundation',
#   'URL': 'https://ineuron.ai//course/Data-Structure-and-Algorithm-Foundation'},
#  {'Name': 'Tableau Job Preparation',
#   'URL': 'https://ineuron.ai//course/Tableau-Job-Preparation'},
#  {'Name': 'Artificial Neural Network',
#   'URL': 'https://ineuron.ai//course/Artificial-Neural-Network'},
#  {'Name': 'Computer Vision Crash Course',
#   'URL': 'https://ineuron.ai//course/Computer-Vision-Crash-Course'},
#  {'Name': 'AWS Crash Course',
#   'URL': 'https://ineuron.ai//course/AWS-Crash-Course'},
#  {'Name': 'Advance Computer Vision',
#   'URL': 'https://ineuron.ai//course/Advance-Computer-Vision'},
#  {'Name': 'AIOPS Crash Course',
#   'URL': 'https://ineuron.ai//course/AIOPS-Crash-Course'},
#  {'Name': 'SQL Projects', 'URL': 'https://ineuron.ai//course/SQL-Projects'},
#  {'Name': 'R Programming Job Preparation',
#   'URL': 'https://ineuron.ai//course/R-Programming-Job-Preparation'},
#  {'Name': 'AIOps Projects',
#   'URL': 'https://ineuron.ai//course/AIOps-Projects'},
#  {'Name': 'Mern Stack Projects',
#   'URL': 'https://ineuron.ai//course/Mern-Stack-Projects'},
#  {'Name': 'SQL Job Preparation',
#   'URL': 'https://ineuron.ai//course/SQL-Job-Preparation'},
#  {'Name': 'Tableau Projects',
#   'URL': 'https://ineuron.ai//course/Tableau-Projects'},
#  {'Name': 'GCP Projects', 'URL': 'https://ineuron.ai//course/GCP-Projects'},
#  {'Name': 'Kubernetes', 'URL': 'https://ineuron.ai//course/Kubernetes'},
#  {'Name': 'Google Dialogflow',
#   'URL': 'https://ineuron.ai//course/Google-Dialogflow'},
#  {'Name': 'Aptitude Test', 'URL': 'https://ineuron.ai//course/Aptitude-Test'},
#  {'Name': 'Azure Certification Road Map',
#   'URL': 'https://ineuron.ai//course/Azure-Certification-Road-Map'},
#  {'Name': 'Mern Stack', 'URL': 'https://ineuron.ai//course/Mern-Stack'},
#  {'Name': 'AWS', 'URL': 'https://ineuron.ai//course/AWS'},
#  {'Name': 'OpenCV', 'URL': 'https://ineuron.ai//course/OpenCV'},
#  {'Name': 'Statistics', 'URL': 'https://ineuron.ai//course/Statistics'},
#  {'Name': 'Azure Fundamentals',
#   'URL': 'https://ineuron.ai//course/Azure-Fundamentals'},
#  {'Name': 'Amazon Lex', 'URL': 'https://ineuron.ai//course/Amazon-Lex'},
#  {'Name': 'Docker', 'URL': 'https://ineuron.ai//course/Docker'},
#  {'Name': 'Complete Interview Preparation For Data Structure and Algorithm in Python',
#   'URL': 'https://ineuron.ai//course/Complete-Interview-Preparation-For-Data-Structure-and-Algorithm-in-Python'},
#  {'Name': 'Mern stack job preparation',
#   'URL': 'https://ineuron.ai//course/Mern-stack-job-preparation'},
#  {'Name': 'Azure Data scientist Associate DP100',
#   'URL': 'https://ineuron.ai//course/Azure-Data-scientist-Associate-DP100'},
#  {'Name': 'Digital Marketing',
#   'URL': 'https://ineuron.ai//course/Digital-Marketing'},
#  {'Name': 'GIT', 'URL': 'https://ineuron.ai//course/GIT'},
#  {'Name': 'Linux', 'URL': 'https://ineuron.ai//course/Linux'},
#  {'Name': 'R Programming', 'URL': 'https://ineuron.ai//course/R-Programming'}]

# %%
result[0]['URL']
# Out:
# 'https://ineuron.ai//course/Complete-DSA-in-Python'

# %%
course_urls=["https://ineuron.ai/course/Complete-DSA-in-Python","https://ineuron.ai/course/Tableau-Foundation-Course"]
course_url="https://ineuron.ai/course/Complete-DSA-in-Python"
def course_detail(course_url: str,wb):
    #Below are the information, need to extract from the course url
    course_name=''
    course_about=''
    course_image_link=''
    course_WYL=[]
    requirements=[]
#     course_curriculam_title=[]
#     course_curriculam_detail=[]
    course_curriculam_dict={}
#     course_mentors=[]
#     course_mentors_detail=[]
    mentors_detail={}
    all_data_dict={}
    
    
    driver = webdriver.Chrome(executable_path=wb)
    driver.implicitly_wait(10)
    
    driver.get(course_url)
    try:    
        view_more=driver.find_element(By.CLASS_NAME,"CurriculumAndProjects_view-more-btn__iZ72A")
        view_more.click()
        driver.implicitly_wait(2)     
    except Exception:
        pass
        
        
    html_content=driver.page_source
    data = BeautifulSoup(html_content,"html.parser")
    #Course Name
    course_name=data.find(class_ = "Hero_course-title__4JX81").text
    #Course About
    course_about=data.find(class_ = "Hero_course-desc__lcACM").text
    #Course Image Link
    course_image_link = data.find(class_ = "Hero_right___0PvZ").img['src']
    
    #What you will learn
    course_WYL_li=data.find(class_ = "CourseLearning_card__0SWov card").find_all('li')
    for li in course_WYL_li:
        course_WYL.append(li.text)
    
    #Requirements
    requirements_li=data.find(class_ = "CourseRequirement_card__lKmHf requirements card").find_all('li')
    for li in requirements_li:
        requirements.append(li.text)
    
    #Curriculam title and detail
    big_boxes=data.find_all(class_ = "CurriculumAndProjects_curriculum-accordion__fI8wj CurriculumAndProjects_card__rF6YN card")
    for big_box in big_boxes:
        title=big_box.find(class_ = "CurriculumAndProjects_accordion-header__ux_yj CurriculumAndProjects_flex__KmWUD flex").text
        #list format
        #course_curriculam_title.append(title)
        big_box_list=big_box.find(class_ = "CurriculumAndProjects_accordion-body__qQaIR").find_all('li')
        temp_list=[]
        for li in big_box_list:
            temp_list.append(li.text)
        #Dict format
        course_curriculam_dict[title]=temp_list
        #list format
        #course_curriculam_detail.append(temp_list)
    mentors_li=data.find_all(class_="InstructorDetails_mentor__P07Cj InstructorDetails_card__mwVrB InstructorDetails_flex__g8BFa card flex")
    for mentor in mentors_li:
        #list format
        #course_mentors.append(mentor.h5.text)
        #course_mentors_detail.append(mentor.a.text)
        #dict
        mentors_detail[mentor.h5.text]=mentor.p.text
        
    #convert all the data dictionary format
    all_data_dict['Course Name']=course_name
    all_data_dict['Course About']=course_about
    all_data_dict['course_image_link']=course_image_link
    all_data_dict["What you'll learn"]=course_WYL
    all_data_dict['Course Curriculum']=course_curriculam_dict
    all_data_dict['Mentors']=mentors_detail
    
    #driver.close
    driver.implicitly_wait(15)
        
    return all_data_dict

# %%
info=course_detail(course_url,wd)
# Out:
# C:\Users\Srikanta\AppData\Local\Temp\ipykernel_2964\1825710665.py:19: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=wb)

# %%
info
# Out:
# {'Course Name': 'Complete DSA in Python',
#  'Course About': 'A comprehensive chase to excel any intreview for the Data Structures and Algorithms. This course has been specifically designed to provide resources that would assist you in cracking problem-solving interviews. The presented problems in the course would suffice to look on to positive outcomes in the interviews.',
#  'course_image_link': 'https://cdn.ineuron.ai/assets/uploads/thumbnails/63bbd0863d8c5c05632becbc.jpg',
#  "What you'll learn": ['Introduction to Algorithms',
#   'Analysis in Algorithms',
#   'Array Data Structure',
#   'Heap Data Structure',
#   'Recursion',
#   'Divide and Conquer',
#   'Linked List Data Structure',
#   'Stack and Queue',
#   'Hashing Data Structure',
#   'Tree Data Structure',
#   'Binary Search Tree',
#   'Graph Traversal Algorithms',
#   'Application of greedy algorithm',
#   'Dynamic Programming',
#   'Research Area- P, NP, NP-Hard and NP-Complete Problems'],
#  'Course Curriculum': {'Introduction to Algorithms': ['Complete DSA Roadmap ',
#    'Why DSA required ',
#    'Algorithms Introduction ',
#    'Steps to construct an algo '],
#   'Analysis in Algorithms': ['Types of Analysis ',
#    'Asymptotic Notation - Big O Time Complexity ',
#    'Asymptotic Notation - Omega Time Complexity ',
#    'Asymptotic Notation - Theta Time Complexity ',
#    'Apriori Analysis - Time Complexity Analysis Part1 ',
#    'Apriori Analysis - Time Complexity Analysis Part2 ',
#    'Apriori Analysis - Time Complexity Analysis Part3 ',
#    'Practice Set - Asymptotic Notations ',
#    'Complexity Classes ',
#    'Recurrence Relation Introduction ',
#    'Substitution Method - Problem 1 ',
#    'Substitution Method - Problem 2 ',
#    'Substitution Method - Problem 3 ',
#    'Recursive Tree Approach - Problem 1 ',
#    'Recursive Tree Approach - Problem 2 ',
#    'Recursive Tree Approach - Problem 3 ',
#    'Practice Set - Substitution and Recursive Tree Approach ',
#    'Masters Theorem Case 1 ',
#    'Masters Theorem Case 2 ',
#    'Masters Theorem Case 3 ',
#    'Practice Set - Masters Theorem '],
#   'Array Data Structure': ['Introduction to Array Data Structure ',
#    'Array Data Structure Implementation ',
#    'Address of an element in 1D array ',
#    'Address of an element in 2D array ',
#    'Searching of an element - Linear Search ',
#    'Searching of an element - Binary Search ',
#    'Recurrence Relation of Binary Search ',
#    'Implementation of Binary Search ',
#    'Binary Search Interview Problem ',
#    'Search a 2D Matrix ',
#    'Searching of an element - Ternary Search ',
#    'Recurrence Relation of Ternary Search ',
#    'Implementation of Ternary Search ',
#    'Sorting in an array - Comparison and Non-Comparison ',
#    'Stable and Unstable sorting algorithms ',
#    'Inplace and Outplace Sorting algorithms ',
#    'Comparison Sort - Bubble Sort ',
#    'Comparison Sort - Bubble Sort Implementation ',
#    'Comparison Sort - Selection Sort ',
#    'Comparison Sort - Selection Sort Implementation ',
#    'Comparison Sort - Insertion Sort ',
#    'Comparison Sort - Insertion Sort Implementation ',
#    'FAANG Interview Question on Arrays - Best Time to Buy and Sell Stock ',
#    'FAANG Interview Question on Arrays - Collinear Points ',
#    'FAANG Interview Question on Arrays - Majority Element ',
#    'FAANG Interview Question on Arrays - Sort Colors '],
#   'Heap Data Structure': ['Basics of Heap Sort - Full Binary Tree vs Complete Binary Tree vs Almost Complete Binary Tree ',
#    'Concept of Minheap and Maxheap Tree ',
#    'Insertion in Minheap or Maxheap Tree ',
#    'Deletion in Minheap or Maxheap Tree ',
#    'Creation of Minheap or Maxheap Tree ',
#    'Time Complexity Derivation to build minheap or maxheap ',
#    'Comparison Sort - Heap Sort ',
#    'FAANG Interview Question on Heap - Top K frequent elements ',
#    'FAANG Interview Question on Heap - K Closest Points to Origin '],
#   'Recursion': ['Introduction to Recursion ',
#    'Factorial Finding using Recursion with its Implementation ',
#    'Fibonacci Series using Recursion with its Implementation ',
#    'Count Of number of ways to reach upstairs '],
#   'Divide and Conquer': ['Introduction to Divide and Conquer ',
#    'Applications of Divide and Conquer - Finding of maxima and minima ',
#    'Applications of Divide and Conquer - Implementation of finding of maxima and minima ',
#    'Applications of Divide and Conquer - Finding of power of an element with its Implementation ',
#    'Applications of Divide and Conquer - Binary Search ',
#    'Applications of Divide and Conquer - Recurrence relation of Binary Search ',
#    'Applications of Divide and Conquer - Implementation of Binary Search ',
#    'FAANG Interview Question- Two Pointers Problem ',
#    'Applications of Divide and Conquer - Merge Sort ',
#    'Applications of Divide and Conquer - Implementation of Merge Sort ',
#    'FAANG Interview Question on MergeSort - Finding of single sorted array complexity ',
#    'Applications of Divide and Conquer - Quick Sort ',
#    'Applications of Divide and Conquer - Implementation of Quick Sort ',
#    'FAANG Interview Scenario Based Question on QuickSort complexity ',
#    'Applications of Divide and Conquer - Randomized QuickSort ',
#    'Applications of Divide and Conquer - Selection Procedure ',
#    'Applications of Divide and Conquer - Implementation of Selection Procedure ',
#    'Applications of Divide and Conquer - Count Of number of an inversions ',
#    "Applications of Divide and Conquer - Strassen's Matrix Multiplication "],
#   'Linked List Data Structure': ['Introduction to Linked List ',
#    'Insertion of a node in Linked List - Front ',
#    'Insertion of a node in Linked List - After a given node ',
#    'Insertion of a node in Linked List - End ',
#    'Deletion of a node in Linked List ',
#    'Searching of a node in Linked List ',
#    'FAANG Interview Question - Reversal of a node in Linked List ',
#    'FAANG Interview Question - Count of all nodes in Linked List ',
#    "FAANG Interview Question - Floyd's Cycle Detection Algorithm ",
#    'FAANG Interview Question - Merge Of two Sorted Linked List '],
#   'Skip List Data Structure': ['Skip List- Motivation, Build-in, Search, Insertion and Deletion skip list '],
#   'Stack and Queue': ['Introduction to Stack Data Structure and Push Operation in depth ',
#    'Stack- Pop operation ',
#    'Implementation of Stack using array and linked list ',
#    'Queue- Insertion and Deletion operation ',
#    'Implementation of Queue using array and linked list ',
#    'FAANG Interview Question - Valid Parenthesis '],
#   'Hashing Data Structure': ['Introduction to Hashing Data Structure ',
#    'Hash Function and its types ',
#    'Implementation of Hash Functions ',
#    'Open addressing - Linear Probing and Primary Clustering ',
#    'Open addressing - Quadratic Probing and Secondary Clustering ',
#    'Open addressing - Double Hashing ',
#    'Chaining ',
#    'Load Factor and Rehashing '],
#   'Tree Data Structure': ['Basics of Tree - Full Binary Tree vs Complete Binary Tree vs Almost Complete Binary Tree '],
#   'Tree Traversal Algorithms': ['Tree Traversal Algorithms- Inorder, Preorder and PostOrder ',
#    'FAANG Interview Questions on Tree Traversal Algorithm '],
#   'Binary Search Tree': ['Introduction to Binary Search Tree ',
#    'Insertion and Inorder Traversal in BST ',
#    'FAANG Interview Question- Minimum value in BST ',
#    "FAANG Interview Question- Find unique possible BST's ",
#    'Searching in Binary Search Tree ',
#    'Deletion in Binary Search Tree '],
#   'Graph Traversal Algorithms': ['Basics Of Graph- Simple vs Multigraph, Null vs Complete Graph, Relationship between edges and vertices in Simple Graph ',
#    'Introduction to Graph Traversal Algorithms ',
#    'Introduction to Depth First Search ',
#    'DFS Psuedocode and illustration using an example ',
#    'DFS Coding Implementation ',
#    'BFS Intro, Psuedocode and illustration using an example ',
#    'BFS Coding Implementation '],
#   'Greedy Algorithm': ['Introduction to greedy algorithm '],
#   'Application of greedy algorithm': ['Fractional Knapsack Problem ',
#    'Implementation of Fractional Knapsack Problem ',
#    'Basics Of Graph- Simple vs Multigraph, Null vs Complete Graph, Relationship between edges and vertices in Simple Graph ',
#    'Introduction to Spanning Tree and Minimum Spanning Tree ',
#    "Minimum Spanning Tree- Kruskal 's Algorithm ",
#    "Minimum Spanning Tree- Prim's Algorithm ",
#    "Single Source Shortest Path- Dijkstra's algorithm ",
#    "Single Source Shortest Path- Dijkstra's algorithm Implementation ",
#    'Huffman Coding ',
#    'Optimal Merge Pattern ',
#    'Job Sequencing with Deadline '],
#   'Dynamic Programming': ['Introduction to Dynamic Programming '],
#   'Application of Dynamic Programming': ['Fibonacci Series using Dynamic Programming ',
#    '0-1 Knapsack Problem '],
#   'Research Area- P, NP, NP-Hard and NP-Complete Problems': ['Research Area- P, NP, NP-Hard and NP-Complete Problems '],
#   'Some ending tips for all students': ['Some ending tips for all students '],
#   'Detailed Interview Process to crack FAANG Companies(SDE Roles)': ['Detailed Interview Process to crack FAANG Companies ']},
#  'Mentors': {'Priya Bhatia': 'Expertise in data structure competitive programing and solving an analytical problems and implementing data structure algorithm in multiple programing language. I have done my M.Tech in Artificial Intelligence at IIT Hyderabad and have an experience of implementation in multiple projects.'}}

# %%
info['Course Name']
# Out:
# 'Complete DSA in Python'

# %%
info['Course About']
# Out:
# 'A comprehensive chase to excel any intreview for the Data Structures and Algorithms. This course has been specifically designed to provide resources that would assist you in cracking problem-solving interviews. The presented problems in the course would suffice to look on to positive outcomes in the interviews.'

# %%
import pymongo
import certifi
ca=certifi.where()
class MongodbOperation:
    def __init__(self):
        self.mongostring="mongodb+srv://srikanta:srikanta@data-science.kuyrwzp.mongodb.net/?retryWrites=true&w=majority"
        self.db_name = "ineuron"
        self.client=pymongo.MongoClient("mongodb+srv://srikanta:srikanta@data-science.kuyrwzp.mongodb.net/?retryWrites=true&w=majority")
    
    def insert_many(self,records: list):
        self.client[self.db_name]["ineuron_courses"].insert_many(records)

    def insert(self,record: dict):
        self.client[self.db_name]["ineuron_courses"].insert_one(record)

# %%
mongo_obj=MongodbOperation()
mongo_obj.insert(info)

# %% [markdown]
# # SQL DATABASE

# %%
import mysql.connector

# %%
#Ip address local host
test=mysql.connector.connect(    
    host="localhost",
    user="root",
    password = "srikanta",
    auth_plugin='mysql_native_password',
    autocommit=True
     )

# %%
print(test.is_connected())
# Out:
# True

# %%
cur = test.cursor()

# %%
try:
    cur.execute("create database ineuron_courses")
except Exception as e:
    print(e)
    print("Database exist")
# Out:
# 1007 (HY000): Can't create database 'ineuron_courses'; database exists
# Database exist

# %%
cur.execute("use ineuron_courses")

# %%
try:
    cur.execute('create table course_name_description (course_name  varchar(1000),  course_description varchar(5000))')
except:
    print("table exist")
# Out:
# table exist

# %%
p='Complete DSA in Python'

# %%
cur.execute(f'insert into course_name_description values ("{p}", "TEST2")')

# %%
info
# Out:
# {'Course Name': 'Complete DSA in Python',
#  'Course About': 'A comprehensive chase to excel any intreview for the Data Structures and Algorithms. This course has been specifically designed to provide resources that would assist you in cracking problem-solving interviews. The presented problems in the course would suffice to look on to positive outcomes in the interviews.',
#  'course_image_link': 'https://cdn.ineuron.ai/assets/uploads/thumbnails/63bbd0863d8c5c05632becbc.jpg',
#  "What you'll learn": ['Introduction to Algorithms',
#   'Analysis in Algorithms',
#   'Array Data Structure',
#   'Heap Data Structure',
#   'Recursion',
#   'Divide and Conquer',
#   'Linked List Data Structure',
#   'Stack and Queue',
#   'Hashing Data Structure',
#   'Tree Data Structure',
#   'Binary Search Tree',
#   'Graph Traversal Algorithms',
#   'Application of greedy algorithm',
#   'Dynamic Programming',
#   'Research Area- P, NP, NP-Hard and NP-Complete Problems'],
#  'Course Curriculum': {'Introduction to Algorithms': ['Complete DSA Roadmap ',
#    'Why DSA required ',
#    'Algorithms Introduction ',
#    'Steps to construct an algo '],
#   'Analysis in Algorithms': ['Types of Analysis ',
#    'Asymptotic Notation - Big O Time Complexity ',
#    'Asymptotic Notation - Omega Time Complexity ',
#    'Asymptotic Notation - Theta Time Complexity ',
#    'Apriori Analysis - Time Complexity Analysis Part1 ',
#    'Apriori Analysis - Time Complexity Analysis Part2 ',
#    'Apriori Analysis - Time Complexity Analysis Part3 ',
#    'Practice Set - Asymptotic Notations ',
#    'Complexity Classes ',
#    'Recurrence Relation Introduction ',
#    'Substitution Method - Problem 1 ',
#    'Substitution Method - Problem 2 ',
#    'Substitution Method - Problem 3 ',
#    'Recursive Tree Approach - Problem 1 ',
#    'Recursive Tree Approach - Problem 2 ',
#    'Recursive Tree Approach - Problem 3 ',
#    'Practice Set - Substitution and Recursive Tree Approach ',
#    'Masters Theorem Case 1 ',
#    'Masters Theorem Case 2 ',
#    'Masters Theorem Case 3 ',
#    'Practice Set - Masters Theorem '],
#   'Array Data Structure': ['Introduction to Array Data Structure ',
#    'Array Data Structure Implementation ',
#    'Address of an element in 1D array ',
#    'Address of an element in 2D array ',
#    'Searching of an element - Linear Search ',
#    'Searching of an element - Binary Search ',
#    'Recurrence Relation of Binary Search ',
#    'Implementation of Binary Search ',
#    'Binary Search Interview Problem ',
#    'Search a 2D Matrix ',
#    'Searching of an element - Ternary Search ',
#    'Recurrence Relation of Ternary Search ',
#    'Implementation of Ternary Search ',
#    'Sorting in an array - Comparison and Non-Comparison ',
#    'Stable and Unstable sorting algorithms ',
#    'Inplace and Outplace Sorting algorithms ',
#    'Comparison Sort - Bubble Sort ',
#    'Comparison Sort - Bubble Sort Implementation ',
#    'Comparison Sort - Selection Sort ',
#    'Comparison Sort - Selection Sort Implementation ',
#    'Comparison Sort - Insertion Sort ',
#    'Comparison Sort - Insertion Sort Implementation ',
#    'FAANG Interview Question on Arrays - Best Time to Buy and Sell Stock ',
#    'FAANG Interview Question on Arrays - Collinear Points ',
#    'FAANG Interview Question on Arrays - Majority Element ',
#    'FAANG Interview Question on Arrays - Sort Colors '],
#   'Heap Data Structure': ['Basics of Heap Sort - Full Binary Tree vs Complete Binary Tree vs Almost Complete Binary Tree ',
#    'Concept of Minheap and Maxheap Tree ',
#    'Insertion in Minheap or Maxheap Tree ',
#    'Deletion in Minheap or Maxheap Tree ',
#    'Creation of Minheap or Maxheap Tree ',
#    'Time Complexity Derivation to build minheap or maxheap ',
#    'Comparison Sort - Heap Sort ',
#    'FAANG Interview Question on Heap - Top K frequent elements ',
#    'FAANG Interview Question on Heap - K Closest Points to Origin '],
#   'Recursion': ['Introduction to Recursion ',
#    'Factorial Finding using Recursion with its Implementation ',
#    'Fibonacci Series using Recursion with its Implementation ',
#    'Count Of number of ways to reach upstairs '],
#   'Divide and Conquer': ['Introduction to Divide and Conquer ',
#    'Applications of Divide and Conquer - Finding of maxima and minima ',
#    'Applications of Divide and Conquer - Implementation of finding of maxima and minima ',
#    'Applications of Divide and Conquer - Finding of power of an element with its Implementation ',
#    'Applications of Divide and Conquer - Binary Search ',
#    'Applications of Divide and Conquer - Recurrence relation of Binary Search ',
#    'Applications of Divide and Conquer - Implementation of Binary Search ',
#    'FAANG Interview Question- Two Pointers Problem ',
#    'Applications of Divide and Conquer - Merge Sort ',
#    'Applications of Divide and Conquer - Implementation of Merge Sort ',
#    'FAANG Interview Question on MergeSort - Finding of single sorted array complexity ',
#    'Applications of Divide and Conquer - Quick Sort ',
#    'Applications of Divide and Conquer - Implementation of Quick Sort ',
#    'FAANG Interview Scenario Based Question on QuickSort complexity ',
#    'Applications of Divide and Conquer - Randomized QuickSort ',
#    'Applications of Divide and Conquer - Selection Procedure ',
#    'Applications of Divide and Conquer - Implementation of Selection Procedure ',
#    'Applications of Divide and Conquer - Count Of number of an inversions ',
#    "Applications of Divide and Conquer - Strassen's Matrix Multiplication "],
#   'Linked List Data Structure': ['Introduction to Linked List ',
#    'Insertion of a node in Linked List - Front ',
#    'Insertion of a node in Linked List - After a given node ',
#    'Insertion of a node in Linked List - End ',
#    'Deletion of a node in Linked List ',
#    'Searching of a node in Linked List ',
#    'FAANG Interview Question - Reversal of a node in Linked List ',
#    'FAANG Interview Question - Count of all nodes in Linked List ',
#    "FAANG Interview Question - Floyd's Cycle Detection Algorithm ",
#    'FAANG Interview Question - Merge Of two Sorted Linked List '],
#   'Skip List Data Structure': ['Skip List- Motivation, Build-in, Search, Insertion and Deletion skip list '],
#   'Stack and Queue': ['Introduction to Stack Data Structure and Push Operation in depth ',
#    'Stack- Pop operation ',
#    'Implementation of Stack using array and linked list ',
#    'Queue- Insertion and Deletion operation ',
#    'Implementation of Queue using array and linked list ',
#    'FAANG Interview Question - Valid Parenthesis '],
#   'Hashing Data Structure': ['Introduction to Hashing Data Structure ',
#    'Hash Function and its types ',
#    'Implementation of Hash Functions ',
#    'Open addressing - Linear Probing and Primary Clustering ',
#    'Open addressing - Quadratic Probing and Secondary Clustering ',
#    'Open addressing - Double Hashing ',
#    'Chaining ',
#    'Load Factor and Rehashing '],
#   'Tree Data Structure': ['Basics of Tree - Full Binary Tree vs Complete Binary Tree vs Almost Complete Binary Tree '],
#   'Tree Traversal Algorithms': ['Tree Traversal Algorithms- Inorder, Preorder and PostOrder ',
#    'FAANG Interview Questions on Tree Traversal Algorithm '],
#   'Binary Search Tree': ['Introduction to Binary Search Tree ',
#    'Insertion and Inorder Traversal in BST ',
#    'FAANG Interview Question- Minimum value in BST ',
#    "FAANG Interview Question- Find unique possible BST's ",
#    'Searching in Binary Search Tree ',
#    'Deletion in Binary Search Tree '],
#   'Graph Traversal Algorithms': ['Basics Of Graph- Simple vs Multigraph, Null vs Complete Graph, Relationship between edges and vertices in Simple Graph ',
#    'Introduction to Graph Traversal Algorithms ',
#    'Introduction to Depth First Search ',
#    'DFS Psuedocode and illustration using an example ',
#    'DFS Coding Implementation ',
#    'BFS Intro, Psuedocode and illustration using an example ',
#    'BFS Coding Implementation '],
#   'Greedy Algorithm': ['Introduction to greedy algorithm '],
#   'Application of greedy algorithm': ['Fractional Knapsack Problem ',
#    'Implementation of Fractional Knapsack Problem ',
#    'Basics Of Graph- Simple vs Multigraph, Null vs Complete Graph, Relationship between edges and vertices in Simple Graph ',
#    'Introduction to Spanning Tree and Minimum Spanning Tree ',
#    "Minimum Spanning Tree- Kruskal 's Algorithm ",
#    "Minimum Spanning Tree- Prim's Algorithm ",
#    "Single Source Shortest Path- Dijkstra's algorithm ",
#    "Single Source Shortest Path- Dijkstra's algorithm Implementation ",
#    'Huffman Coding ',
#    'Optimal Merge Pattern ',
#    'Job Sequencing with Deadline '],
#   'Dynamic Programming': ['Introduction to Dynamic Programming '],
#   'Application of Dynamic Programming': ['Fibonacci Series using Dynamic Programming ',
#    '0-1 Knapsack Problem '],
#   'Research Area- P, NP, NP-Hard and NP-Complete Problems': ['Research Area- P, NP, NP-Hard and NP-Complete Problems '],
#   'Some ending tips for all students': ['Some ending tips for all students '],
#   'Detailed Interview Process to crack FAANG Companies(SDE Roles)': ['Detailed Interview Process to crack FAANG Companies ']},
#  'Mentors': {'Priya Bhatia': 'Expertise in data structure competitive programing and solving an analytical problems and implementing data structure algorithm in multiple programing language. I have done my M.Tech in Artificial Intelligence at IIT Hyderabad and have an experience of implementation in multiple projects.'},
#  '_id': ObjectId('63ed0fc595fd5647a0e63a81')}

# %%
import mysql.connector
import logging

class sqlOperation:
    def __init__(self):
        self.host="localhost"
        self.user='root'
        self.password='srikanta'
        self.auth_plugin= 'mysql_native_password'
        self.db_name='ineuron_courses'
        self.table_name='course_name_description'
    
    def connect_db(self):
        con=mysql.connector.connect(    
            host=self.host,
            user=self.user,
            password = self.password,
            auth_plugin= self.auth_plugin,
            autocommit=True
            )
        return con


    def creat_db(self,con):
        if (con.is_connected()):
            cur=con.cursor()
            logging.info( "Database is connected")
            #if database not avaialbe create database
            try:
                db_creation_command= f'create database {self.db_name}'
                cur.execute(db_creation_command)
            except Exception as e:
                logging.info(e)
                logging.info("Database exist")
        else:
            logging.info( "Mysql is not connected")

    def create_table(self,con):
        
        if (con.is_connected()):
            cur=con.cursor()
            use_database_command=f'use {self.db_name}'
            cur.execute(use_database_command)
            try:
                create_table_command= f'create table {self.table_name} (course_name  varchar(1000),  course_description varchar(5000))'
                cur.execute(create_table_command)
            except Exception as e:
                logging.info(e)
                logging.info("Table exist")
        else:
            logging.info( "Mysql is not connected")


    
    def insert(self,con, course_name, course_description):
        if (con.is_connected()):
            cur=con.cursor()
            use_database_command=f'use {self.db_name}'
            cur.execute(use_database_command)
            try:
                insert_command= f'insert into {self.table_name} values ( "{course_name}", "{course_description}")'
                cur.execute(insert_command)
            except Exception as e:
                logging.info("Unable insert the element: ",e)
        else:
            logging.info( "Mysql is not connected")

# %%
obj=sqlOperation()
con=obj.connect_db()

# %%
con.is_connected()
# Out:
# True

# %%
obj.insert(con, 'TEST', 'TEST2')

# %%
obj.insert(con, info['Course Name'], info['Course About'])

# %%
# FOR S3 BUCKET
import boto3

session = boto3.Session(
    aws_access_key_id='AWS_ACCESS_KEY_ID',
    aws_secret_access_key='AWS_SECRET_ACCESS_KEY',
)
s3 = session.resource('s3')
# Filename - File to upload
# Bucket - Bucket to upload to (the top level directory under AWS S3)
# Key - S3 object name (can contain subdirectories). If not specified then file_name is used
s3.meta.client.upload_file(Filename='input_file_path', Bucket='bucket_name', Key='s3_output_key')

# %%
info
# Out:
# {'Course Name': 'Complete DSA in Python',
#  'Course About': 'A comprehensive chase to excel any intreview for the Data Structures and Algorithms. This course has been specifically designed to provide resources that would assist you in cracking problem-solving interviews. The presented problems in the course would suffice to look on to positive outcomes in the interviews.',
#  'course_image_link': 'https://cdn.ineuron.ai/assets/uploads/thumbnails/63bbd0863d8c5c05632becbc.jpg',
#  "What you'll learn": ['Introduction to Algorithms',
#   'Analysis in Algorithms',
#   'Array Data Structure',
#   'Heap Data Structure',
#   'Recursion',
#   'Divide and Conquer',
#   'Linked List Data Structure',
#   'Stack and Queue',
#   'Hashing Data Structure',
#   'Tree Data Structure',
#   'Binary Search Tree',
#   'Graph Traversal Algorithms',
#   'Application of greedy algorithm',
#   'Dynamic Programming',
#   'Research Area- P, NP, NP-Hard and NP-Complete Problems'],
#  'Course Curriculum': {'Introduction to Algorithms': ['Complete DSA Roadmap ',
#    'Why DSA required ',
#    'Algorithms Introduction ',
#    'Steps to construct an algo '],
#   'Analysis in Algorithms': ['Types of Analysis ',
#    'Asymptotic Notation - Big O Time Complexity ',
#    'Asymptotic Notation - Omega Time Complexity ',
#    'Asymptotic Notation - Theta Time Complexity ',
#    'Apriori Analysis - Time Complexity Analysis Part1 ',
#    'Apriori Analysis - Time Complexity Analysis Part2 ',
#    'Apriori Analysis - Time Complexity Analysis Part3 ',
#    'Practice Set - Asymptotic Notations ',
#    'Complexity Classes ',
#    'Recurrence Relation Introduction ',
#    'Substitution Method - Problem 1 ',
#    'Substitution Method - Problem 2 ',
#    'Substitution Method - Problem 3 ',
#    'Recursive Tree Approach - Problem 1 ',
#    'Recursive Tree Approach - Problem 2 ',
#    'Recursive Tree Approach - Problem 3 ',
#    'Practice Set - Substitution and Recursive Tree Approach ',
#    'Masters Theorem Case 1 ',
#    'Masters Theorem Case 2 ',
#    'Masters Theorem Case 3 ',
#    'Practice Set - Masters Theorem '],
#   'Array Data Structure': ['Introduction to Array Data Structure ',
#    'Array Data Structure Implementation ',
#    'Address of an element in 1D array ',
#    'Address of an element in 2D array ',
#    'Searching of an element - Linear Search ',
#    'Searching of an element - Binary Search ',
#    'Recurrence Relation of Binary Search ',
#    'Implementation of Binary Search ',
#    'Binary Search Interview Problem ',
#    'Search a 2D Matrix ',
#    'Searching of an element - Ternary Search ',
#    'Recurrence Relation of Ternary Search ',
#    'Implementation of Ternary Search ',
#    'Sorting in an array - Comparison and Non-Comparison ',
#    'Stable and Unstable sorting algorithms ',
#    'Inplace and Outplace Sorting algorithms ',
#    'Comparison Sort - Bubble Sort ',
#    'Comparison Sort - Bubble Sort Implementation ',
#    'Comparison Sort - Selection Sort ',
#    'Comparison Sort - Selection Sort Implementation ',
#    'Comparison Sort - Insertion Sort ',
#    'Comparison Sort - Insertion Sort Implementation ',
#    'FAANG Interview Question on Arrays - Best Time to Buy and Sell Stock ',
#    'FAANG Interview Question on Arrays - Collinear Points ',
#    'FAANG Interview Question on Arrays - Majority Element ',
#    'FAANG Interview Question on Arrays - Sort Colors '],
#   'Heap Data Structure': ['Basics of Heap Sort - Full Binary Tree vs Complete Binary Tree vs Almost Complete Binary Tree ',
#    'Concept of Minheap and Maxheap Tree ',
#    'Insertion in Minheap or Maxheap Tree ',
#    'Deletion in Minheap or Maxheap Tree ',
#    'Creation of Minheap or Maxheap Tree ',
#    'Time Complexity Derivation to build minheap or maxheap ',
#    'Comparison Sort - Heap Sort ',
#    'FAANG Interview Question on Heap - Top K frequent elements ',
#    'FAANG Interview Question on Heap - K Closest Points to Origin '],
#   'Recursion': ['Introduction to Recursion ',
#    'Factorial Finding using Recursion with its Implementation ',
#    'Fibonacci Series using Recursion with its Implementation ',
#    'Count Of number of ways to reach upstairs '],
#   'Divide and Conquer': ['Introduction to Divide and Conquer ',
#    'Applications of Divide and Conquer - Finding of maxima and minima ',
#    'Applications of Divide and Conquer - Implementation of finding of maxima and minima ',
#    'Applications of Divide and Conquer - Finding of power of an element with its Implementation ',
#    'Applications of Divide and Conquer - Binary Search ',
#    'Applications of Divide and Conquer - Recurrence relation of Binary Search ',
#    'Applications of Divide and Conquer - Implementation of Binary Search ',
#    'FAANG Interview Question- Two Pointers Problem ',
#    'Applications of Divide and Conquer - Merge Sort ',
#    'Applications of Divide and Conquer - Implementation of Merge Sort ',
#    'FAANG Interview Question on MergeSort - Finding of single sorted array complexity ',
#    'Applications of Divide and Conquer - Quick Sort ',
#    'Applications of Divide and Conquer - Implementation of Quick Sort ',
#    'FAANG Interview Scenario Based Question on QuickSort complexity ',
#    'Applications of Divide and Conquer - Randomized QuickSort ',
#    'Applications of Divide and Conquer - Selection Procedure ',
#    'Applications of Divide and Conquer - Implementation of Selection Procedure ',
#    'Applications of Divide and Conquer - Count Of number of an inversions ',
#    "Applications of Divide and Conquer - Strassen's Matrix Multiplication "],
#   'Linked List Data Structure': ['Introduction to Linked List ',
#    'Insertion of a node in Linked List - Front ',
#    'Insertion of a node in Linked List - After a given node ',
#    'Insertion of a node in Linked List - End ',
#    'Deletion of a node in Linked List ',
#    'Searching of a node in Linked List ',
#    'FAANG Interview Question - Reversal of a node in Linked List ',
#    'FAANG Interview Question - Count of all nodes in Linked List ',
#    "FAANG Interview Question - Floyd's Cycle Detection Algorithm ",
#    'FAANG Interview Question - Merge Of two Sorted Linked List '],
#   'Skip List Data Structure': ['Skip List- Motivation, Build-in, Search, Insertion and Deletion skip list '],
#   'Stack and Queue': ['Introduction to Stack Data Structure and Push Operation in depth ',
#    'Stack- Pop operation ',
#    'Implementation of Stack using array and linked list ',
#    'Queue- Insertion and Deletion operation ',
#    'Implementation of Queue using array and linked list ',
#    'FAANG Interview Question - Valid Parenthesis '],
#   'Hashing Data Structure': ['Introduction to Hashing Data Structure ',
#    'Hash Function and its types ',
#    'Implementation of Hash Functions ',
#    'Open addressing - Linear Probing and Primary Clustering ',
#    'Open addressing - Quadratic Probing and Secondary Clustering ',
#    'Open addressing - Double Hashing ',
#    'Chaining ',
#    'Load Factor and Rehashing '],
#   'Tree Data Structure': ['Basics of Tree - Full Binary Tree vs Complete Binary Tree vs Almost Complete Binary Tree '],
#   'Tree Traversal Algorithms': ['Tree Traversal Algorithms- Inorder, Preorder and PostOrder ',
#    'FAANG Interview Questions on Tree Traversal Algorithm '],
#   'Binary Search Tree': ['Introduction to Binary Search Tree ',
#    'Insertion and Inorder Traversal in BST ',
#    'FAANG Interview Question- Minimum value in BST ',
#    "FAANG Interview Question- Find unique possible BST's ",
#    'Searching in Binary Search Tree ',
#    'Deletion in Binary Search Tree '],
#   'Graph Traversal Algorithms': ['Basics Of Graph- Simple vs Multigraph, Null vs Complete Graph, Relationship between edges and vertices in Simple Graph ',
#    'Introduction to Graph Traversal Algorithms ',
#    'Introduction to Depth First Search ',
#    'DFS Psuedocode and illustration using an example ',
#    'DFS Coding Implementation ',
#    'BFS Intro, Psuedocode and illustration using an example ',
#    'BFS Coding Implementation '],
#   'Greedy Algorithm': ['Introduction to greedy algorithm '],
#   'Application of greedy algorithm': ['Fractional Knapsack Problem ',
#    'Implementation of Fractional Knapsack Problem ',
#    'Basics Of Graph- Simple vs Multigraph, Null vs Complete Graph, Relationship between edges and vertices in Simple Graph ',
#    'Introduction to Spanning Tree and Minimum Spanning Tree ',
#    "Minimum Spanning Tree- Kruskal 's Algorithm ",
#    "Minimum Spanning Tree- Prim's Algorithm ",
#    "Single Source Shortest Path- Dijkstra's algorithm ",
#    "Single Source Shortest Path- Dijkstra's algorithm Implementation ",
#    'Huffman Coding ',
#    'Optimal Merge Pattern ',
#    'Job Sequencing with Deadline '],
#   'Dynamic Programming': ['Introduction to Dynamic Programming '],
#   'Application of Dynamic Programming': ['Fibonacci Series using Dynamic Programming ',
#    '0-1 Knapsack Problem '],
#   'Research Area- P, NP, NP-Hard and NP-Complete Problems': ['Research Area- P, NP, NP-Hard and NP-Complete Problems '],
#   'Some ending tips for all students': ['Some ending tips for all students '],
#   'Detailed Interview Process to crack FAANG Companies(SDE Roles)': ['Detailed Interview Process to crack FAANG Companies ']},
#  'Mentors': {'Priya Bhatia': 'Expertise in data structure competitive programing and solving an analytical problems and implementing data structure algorithm in multiple programing language. I have done my M.Tech in Artificial Intelligence at IIT Hyderabad and have an experience of implementation in multiple projects.'},
#  '_id': ObjectId('63ed0fc595fd5647a0e63a81')}

# %%
for course in result[:5]:
    print(course["URL"])
    info=course_detail(course["URL"],wd)
    create_pdf_file(info)
# Out:
# https://ineuron.ai//course/Complete-DSA-in-Python
# C:\Users\Srikanta\AppData\Local\Temp\ipykernel_17508\1825710665.py:19: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=wb)
# https://ineuron.ai//course/Tableau-Foundation-Course
# https://ineuron.ai//course/Complete-Excel-Course
# https://ineuron.ai//course/Automatic-Number-Plate-Recognition
# https://ineuron.ai//course/Build-Modern-ETL-Data-Pipeline-using-Informatica-cloud

# %%
def create_text_file(info: dict):
    file_name=info['Course Name'] + '.txt'
    with open(file_name, 'w') as f:
        f.write('Course Name')
        f.write(info['Course Name'])
        f.write('\n')
        f.write('Course About')
        f.write(info['Course About'])
        f.write('\n')
        f.write("What you'll learn")
        for ele in info["What you'll learn"]:
            f.write(ele)
            f.write('\n')
        f.write("Course Curriculum")
        f.write('\n')
        for key in info["Course Curriculum"].keys():
            f.write(key)
            f.write('\n')
            for ele in info["Course Curriculum"][key]:
                f.write(ele)
                f.write('\n')
        f.write('Mentors')
        f.write('\n')
        for key in info['Mentors'].keys():
            f.write(key)
            f.write('\n')
            for ele in info['Mentors'][key]:
                f.write(ele)
            f.write('\n')

# %%
create_text_file(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 create_text_file(x)
#
# NameError: name 'x' is not defined

# %%
def create_pdf_file(info: dict):
    file_name=info['Course Name'] + '.pdf'
    # save FPDF() class into a
    # variable pdf
    pdf = FPDF()
    # Add a page
    pdf.add_page()
    # set style and size of font
    pdf.set_font("Arial", size = 12)# create a cell
    pdf.cell(200, 10, txt = "Course Name:", ln = 1, align = 'C')
    pdf.cell(200, 10, txt = info['Course Name'],ln = 2, align = 'C')
    pdf.cell(200, 10, txt = 'Course About:',ln = 2, align = 'L')
    #pdf.cell(200, 10, txt =info['Course About'] ,ln = 2, align = 'L')
    pdf.write(5,info['Course About'])
    #pdf.cell(0, 12, txt ="What you'll learn:" ,ln = 2, align = 'L')
    pdf.write(5,"\n")
    pdf.write(10,"What you'll learn:")
    pdf.write(10,"\n")
    for ele in info["What you'll learn"]:
        pdf.write(5, txt ="-" + ele)
        pdf.write(10,"\n")
    pdf.cell(200, 10, txt = "Course Curriculum:",ln = 2, align = 'L')
    for key in info["Course Curriculum"].keys():
        pdf.write(5, txt =key+':')
        pdf.write(10,"\n")
        for ele in info["Course Curriculum"][key]:
            pdf.write(5,txt ="*" +ele)
            pdf.write(10,"\n")
    pdf.cell(200, 10, txt ='Mentors:' ,ln = 2, align = 'L')
    for key in info['Mentors'].keys():
        pdf.cell(200, 10, txt =key ,ln = 2, align = 'L')
        #print(key)
        for ele in info['Mentors'].values():
            pdf.write(5,ele)
            #print(ele)
            
    pdf.output(file_name)

# %%
create_pdf_file(x)

# %%
def create_pdf_file(info: dict):
        try:
            file_name=info['Course Name'].replace(' ','_') + '.pdf'
            # save FPDF() class into a
            # variable pdf
            pdf = FPDF()
            # Add a page
            pdf.add_page()
            # set style and size of font
            pdf.set_font("Arial", size = 12)# create a cell
            pdf.cell(200, 10, txt = "Course Name:", ln = 1, align = 'C')
            pdf.cell(200, 10, txt = info['Course Name'],ln = 2, align = 'C')
            pdf.cell(200, 10, txt = 'Course About:',ln = 2, align = 'L')
            #pdf.cell(200, 10, txt =info['Course About'] ,ln = 2, align = 'L')
            pdf.write(5,info['Course About'])
            #pdf.cell(0, 12, txt ="What you'll learn:" ,ln = 2, align = 'L')
            pdf.write(5,"\n")
            pdf.write(10,"What you'll learn:")
            pdf.write(10,"\n")
            for ele in info["What you'll learn"]:
                pdf.write(5, txt ="-" + ele)
                pdf.write(10,"\n")
            pdf.cell(200, 10, txt = "Course Curriculum:",ln = 2, align = 'L')
            for key in info["Course Curriculum"].keys():
                pdf.write(5, txt =key+':')
                pdf.write(10,"\n")
                for ele in info["Course Curriculum"][key]:
                    pdf.write(5,txt ="*" +ele)
                    pdf.write(10,"\n")
            pdf.cell(200, 10, txt ='Mentors:' ,ln = 2, align = 'L')
            for key in info['Mentors'].keys():
                pdf.cell(200, 10, txt =key ,ln = 2, align = 'L')
                #print(key)
                for ele in info['Mentors'].values():
                    pdf.write(5,ele)
                    #print(ele)
             
            pdf.output(file_name)
            return file_name
        except  Exception as e:
            logging.error(e)
            logging.info("Unable to create the pdf files")

# %%
create_pdf_file(info)
# Out:
# 'Complete_DSA_in_Python.pdf'

# %%
import boto3

session = boto3.Session(
    aws_access_key_id='AKIAZ5OFBRB2XMUOQ7UU',
    aws_secret_access_key='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',
)
s3 = session.resource('s3')
# Filename - File to upload
# Bucket - Bucket to upload to (the top level directory under AWS S3)
# Key - S3 object name (can contain subdirectories). If not specified then file_name is used
s3.meta.client.upload_file(Filename='Complete_DSA_in_Python.pdf', Bucket='ineuron-scrapper-bucket', Key='Complete_DSA_in_Python.pdf')

# %%
#Import packages
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
from fpdf import FPDF
import logging

class scrapper:
    def __init__(self,base_url:str,driver_path):
        self.base_url = base_url
        self.driver_path=driver_path

    def run_driver(self):
        try:
            option = webdriver.ChromeOptions()
#             option.add_argument('--headless')
#             option.add_argument('-no-sandbox')
#             option.add_argument("--mute-audio")
#             option.add_argument("--disable-extensions")
#             option.add_argument('-disable-dev-shm-usage')
            driver = webdriver.Chrome(self.driver_path, options=option)
            logging.info('Web driver path:', self.driver_path)
            logging.info(" Driver is working ")
            return driver
        except Exception as e:
            logging.error(e)
            logging.info("Driver is not working")




    def course_name_and_link(self):
        try:
            driver= self.run_driver()
            driver.implicitly_wait(0.5)
            print(driver)
        except:
            logging.info("run_driver function is not working")
        
        try:
            url_courses=self.base_url+'/courses'
            driver.get(url_courses)
            
            time.sleep(5)
        except:
            logging.info("Incorrect course URL",url_courses)

        ## NOTE Some time infinte scoll stops before completing the scrolling, to avoid this we need give more time or good internet spped
        ## so that it can load. But in for looping the chances of stop before end of page is less.
        #infinity scroll
        try:
            current_height=driver.execute_script('return document.body.scrollHeight;')
            while True:
                driver.execute_script('window.scrollTo(0,arguments[0]);',current_height)
                time.sleep(30)
                new_height=driver.execute_script('return document.body.scrollHeight;')
                #print(current_height,new_height)
                logging.info('Current height:',current_height,'New height:', new_height)
                if new_height == current_height:
                    break
                current_height = new_height
        except:
            logging.info("Infinity scroll is not working")


        #     for i in range(100):
        #         driver.execute_script('window.scrollBy(0,3000);')
        #         time.sleep(20)
        html_content=driver.page_source
            
        try:
            #Data extraction using beautifulsoup
            data = BeautifulSoup(html_content, "html.parser")
        except:
            logging.info("Beautiful soup is not working")


        try:
            all_courses=data.find_all(class_="Course_right-area__JqFFV")
            course_names = []
            course_links = []
            result=[]
            name_link={}
            for course in all_courses:
                course_links.append(self.base_url + course.find('a')['href'])
                course_names.append(course.find(class_="Course_course-title__219gJ").text)
                name_link['Name'] = course.find(class_="Course_course-title__219gJ").text
                name_link['URL']=self.base_url + course.find('a')['href']
                result.append(name_link)
        except:
            logging.info('Beautiful soup data extraction is not working')
        
        driver.close()
    
        logging.info("Website scrapped successfully and returning course name and links")
        return result,course_names,course_links


    def course_detail(self,course_url: str):
        #Below are the information, need to extract from the course url
        course_name=''
        course_about=''
        course_image_link=''
        course_WYL=[]
        requirements=[]
        course_curriculam_dict={}
        mentors_detail={}
        all_data_dict={}
        
        try:
            driver=self.run_drive()
            driver.implicitly_wait(0.5)
        except:
            logging.info("run_driver function is not working")
        
        try:
            driver.get(course_url)
        except:
            logging.info('Incorrect url:', course_url)

        try:   
        # view more
            view_more=driver.find_element(By.CLASS_NAME,"CurriculumAndProjects_view-more-btn__iZ72A")
            view_more.click()
            driver.implicitly_wait(2)
        except Exception as e:
            logging.error(e)
            logging.info(" View more not in webpage")

        html_content=driver.page_source
            
        try:
            #Data extraction using beautifulsoup
            data = BeautifulSoup(html_content, "html.parser")
        except:
            logging.info("Beautiful soup is not working")

        try:    
            #Course Name
            course_name=data.find(class_ = "Hero_course-title__4JX81").text
        except:
            logging.warning('Course name class not found in webpage')
        try: 
        #Course About
            course_about=data.find(class_ = "Hero_course-desc__lcACM").text
        except:
            logging.warning('Course about class not found in webpage')
        
        try:
            #Course Image Link
            course_image_link = data.find(class_ = "Hero_right___0PvZ").img['src']
        except:
            logging.warning('Course image class not found in webpage')
        
        try:
            #What you will learn
            course_WYL_li=data.find(class_ = "CourseLearning_card__0SWov card").find_all('li')
            for li in course_WYL_li:
                course_WYL.append(li.text)
        except:
            logging.warning("Course What you'll learn class not found in webpage")
        
        try:
            #Requirements
            requirements_li=data.find(class_ = "CourseRequirement_card__lKmHf requirements card").find_all('li')
            for li in requirements_li:
                requirements.append(li.text)
        except:
            logging.warning("Course requirement class not found in webpage")
        
        try:
            #Curriculam title and detail
            big_boxes=data.find_all(class_ = "CurriculumAndProjects_curriculum-accordion__fI8wj CurriculumAndProjects_card__rF6YN card")
            for big_box in big_boxes:
                title=big_box.find(class_ = "CurriculumAndProjects_accordion-header__ux_yj CurriculumAndProjects_flex__KmWUD flex").text
                big_box_list=big_box.find(class_ = "CurriculumAndProjects_accordion-body__qQaIR").find_all('li')
                temp_list=[]
                for li in big_box_list:
                    temp_list.append(li.text)
                #Dict format
                course_curriculam_dict[title]=temp_list
        except:
            logging.warning("Course curriculam class not found in webpage")
        
        try:
            mentors_li=data.find_all(class_="InstructorDetails_mentor__P07Cj InstructorDetails_card__mwVrB InstructorDetails_flex__g8BFa card flex")
            for mentor in mentors_li:
                #dict
                mentors_detail[mentor.h5.text]=mentor.p.text
        except:
             logging.warning("Course mentor detail class not found in webpage")
        
        try:
            #convert all the data dictionary format
            all_data_dict['Course Name']=course_name
            all_data_dict['Course About']=course_about
            all_data_dict['course_image_link']=course_image_link
            all_data_dict["What you'll learn"]=course_WYL
            all_data_dict['Course Curriculum']=course_curriculam_dict
            all_data_dict['Mentors']=mentors_detail
            logging.info('Website scrapped sucessfull')
        except:
            logging.warning("Some data is missing during the making of dictionary")

        
        driver.close
        logging.info("Website scrapped successfully and returning course info in dictionary format")   
        return all_data_dict


    @staticmethod
    def create_pdf_file(info: dict):
        try:
            file_name=info['Course Name'] + '.pdf'
            # save FPDF() class into a
            # variable pdf
            pdf = FPDF()
            # Add a page
            pdf.add_page()
            # set style and size of font
            pdf.set_font("Arial", size = 12)# create a cell
            pdf.cell(200, 10, txt = "Course Name:", ln = 1, align = 'C')
            pdf.cell(200, 10, txt = info['Course Name'],ln = 2, align = 'C')
            pdf.cell(200, 10, txt = 'Course About:',ln = 2, align = 'L')
            #pdf.cell(200, 10, txt =info['Course About'] ,ln = 2, align = 'L')
            pdf.write(5,info['Course About'])
            #pdf.cell(0, 12, txt ="What you'll learn:" ,ln = 2, align = 'L')
            pdf.write(5,"\n")
            pdf.write(10,"What you'll learn:")
            pdf.write(10,"\n")
            for ele in info["What you'll learn"]:
                pdf.write(5, txt ="-" + ele)
                pdf.write(10,"\n")
            pdf.cell(200, 10, txt = "Course Curriculum:",ln = 2, align = 'L')
            for key in info["Course Curriculum"].keys():
                pdf.write(5, txt =key+':')
                pdf.write(10,"\n")
                for ele in info["Course Curriculum"][key]:
                    pdf.write(5,txt ="*" +ele)
                    pdf.write(10,"\n")
            pdf.cell(200, 10, txt ='Mentors:' ,ln = 2, align = 'L')
            for key in info['Mentors'].keys():
                pdf.cell(200, 10, txt =key ,ln = 2, align = 'L')
                #print(key)
                for ele in info['Mentors'].values():
                    pdf.write(5,ele)
                    #print(ele)
                    
            pdf.output(file_name)
        except  Exception as e:
            logging.error(e)
            logging.info("Unable to create the pdf files")

# %%
base_url='https://ineuron.ai'
ineuron_scrapper_obj=scrapper(base_url, driver_path=r'C:\Users\Srikanta\Desktop\FullStackDataScience\Challenges\IneuronScrapper\chromedriver.exe')
reviews,X,Y= ineuron_scrapper_obj.course_name_and_link()
# Out:
# C:\Users\Srikanta\AppData\Local\Temp\ipykernel_17508\991137629.py:22: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(self.driver_path, options=option)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Srikanta\anaconda3\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "C:\Users\Srikanta\anaconda3\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "C:\Users\Srikanta\anaconda3\lib\logging\__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "C:\Users\Srikanta\anaconda3\lib\logging\__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\Users\Srikanta\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Srikanta\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Srikanta\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\Srikanta\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\Srikanta\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 460, in process_one
#     await dispatch(*args)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 367, in dispatch_shell
#     await result
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 662, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 360, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 532, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Srikanta\AppData\Local\Temp\ipykernel_17508\3404397213.py", line 3, in <cell line: 3>
#     reviews,X,Y= ineuron_scrapper_obj.course_name_and_link()
#   File "C:\Users\Srikanta\AppData\Local\Temp\ipykernel_17508\991137629.py", line 35, in course_name_and_link
#     driver= self.run_driver()
#   File "C:\Users\Srikanta\AppData\Local\Temp\ipykernel_17508\991137629.py", line 23, in run_driver
#     logging.info('Web driver path:', self.driver_path)
# Message: 'Web driver path:'
# Arguments: ('C:\\Users\\Srikanta\\Desktop\\FullStackDataScience\\Challenges\\IneuronScrapper\\chromedriver.exe',)
# <selenium.webdriver.chrome.webdriver.WebDriver (session="207ae604326b71e3d59b3552fce671fc")>
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Srikanta\anaconda3\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "C:\Users\Srikanta\anaconda3\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "C:\Users\Srikanta\anaconda3\lib\logging\__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "C:\Users\Srikanta\anaconda3\lib\logging\__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\Users\Srikanta\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Srikanta\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Srikanta\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\Srikanta\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\Srikanta\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 460, in process_one
#     await dispatch(*args)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 367, in dispatch_shell
#     await result
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 662, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 360, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 532, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Srikanta\AppData\Local\Temp\ipykernel_17508\3404397213.py", line 3, in <cell line: 3>
#     reviews,X,Y= ineuron_scrapper_obj.course_name_and_link()
#   File "C:\Users\Srikanta\AppData\Local\Temp\ipykernel_17508\991137629.py", line 59, in course_name_and_link
#     logging.info('Current height:',current_height,'New height:', new_height)
# Message: 'Current height:'
# Arguments: (2324, 'New height:', 8387)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Srikanta\anaconda3\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "C:\Users\Srikanta\anaconda3\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "C:\Users\Srikanta\anaconda3\lib\logging\__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "C:\Users\Srikanta\anaconda3\lib\logging\__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\Users\Srikanta\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Srikanta\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Srikanta\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\Srikanta\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\Srikanta\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 460, in process_one
#     await dispatch(*args)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 367, in dispatch_shell
#     await result
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 662, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 360, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 532, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Srikanta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Srikanta\AppData\Local\Temp\ipykernel_17508\3404397213.py", line 3, in <cell line: 3>
#     reviews,X,Y= ineuron_scrapper_obj.course_name_and_link()
#   File "C:\Users\Srikanta\AppData\Local\Temp\ipykernel_17508\991137629.py", line 59, in course_name_and_link
#     logging.info('Current height:',current_height,'New height:', new_height)
# Message: 'Current height:'
# Arguments: (8387, 'New height:', 8387)

# %%
reviews
# Out:
# [{'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'},
#  {'Name': 'Machine Learning Bootcamp Tech Neuron',
#   'URL': 'https://ineuron.ai/course/Machine-Learning-Bootcamp-Tech-Neuron'}]
